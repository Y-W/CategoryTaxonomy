# %% [markdown]
# Clustering Visual Categories, using Descriptions
# ===========================

# %%
from heapq import *
import numpy as np
import csv
from collections import Counter, defaultdict
import multiprocessing as mp
from math import log
from heapq import *
from functools import partial
import pickle
import gzip

# %%
# Load files
catDescFile = 'data/cat_desc.csv'
catDescHeaders = None
catDescCnt = defaultdict(Counter)
descCnt = Counter()
with open(catDescFile) as fin:
    r = csv.reader(fin)
    for row in r:
        if catDescHeaders is None:
            catDescHeaders = row
            print catDescHeaders
        else:
            catDescCnt[int(row[0]) - 1][row[1]] += int(row[-1])
            descCnt[row[1]] += int(row[-1])

catNameFile = 'data/categoryKey.csv'
catName = {}
with open(catNameFile) as fin:
    r = csv.reader(fin)
    for row in r:
        catName[int(row[0]) - 1] = row[1]

print sorted(catDescCnt.keys()) == sorted(catName.keys()) and sorted(catDescCnt.keys()) == range(len(catName))
# Out:
# ['category_id', 'description', 'count']
# True

# %%
# Filter out description of occurance < $threshold$, replace description with id, and normalize distribution
threshold = 10
descList = [d for d, c in descCnt.most_common() if c >= threshold]
descId = {d:i for i, d in enumerate(descList)}
catDist = defaultdict(Counter)
for cat, dist in catDescCnt.iteritems():
    s = 0.0
    for d, v in dist.iteritems():
        if d in descId:
            s += v
    for d, v in dist.iteritems():
        if d in descId:
            catDist[cat][descId[d]] += v / s

# %%
def computeEntropy(itr):
    s = 0.0
    ans = 0.0
    for x in itr:
        s += x
        ans += x * log(x)
    return log(s) - ans / s

def mergeCandidiate(nodeInfo, s1, s2):
    s = nodeInfo[s1][0] + nodeInfo[s2][0]
    dist = nodeInfo[s1][1] + nodeInfo[s2][1]
    sumLeafEntropy = nodeInfo[s1][2] + nodeInfo[s2][2]
    return (computeEntropy(dist.itervalues()) - sumLeafEntropy / s, s1, s2)
    
def addCandidate(nodeInfo, newS, activeNodes, candidatePool, mpPool):
    mpKernel = partial(mergeCandidiate, nodeInfo, newS)
    newCandidates = mpPool.map(mpKernel, activeNodes)
    for c in newCandidates:
        heappush(candidatePool, c)
    activeNodes.add(newS)

def distHC1(catDist):
    mpPool = mp.Pool(processes=2)
    leafNum = len(catDist)
    activeNodes = set()
    nodeInfo = []
    candidatePool = []
    heapify(candidatePool)
    nextId = 0
    
    for leaf in xrange(leafNum):
        nodeInfo.append((1, catDist[leaf], computeEntropy(catDist[leaf].itervalues()), None, None, 0.0))
        addCandidate(nodeInfo, nextId, activeNodes, candidatePool, mpPool)
        nextId += 1
        if leaf % 10 == 0:
            print 'Adding leaf #', leaf
    
    while len(activeNodes) > 1:
        jsd, s1, s2 = heappop(candidatePool)
        while s1 not in activeNodes or s2 not in activeNodes:
            jsd, s1, s2 = heappop(candidatePool)
        nodeInfo.append((nodeInfo[s1][0] + nodeInfo[s2][0], 
                        nodeInfo[s1][1] + nodeInfo[s2][1], 
                        nodeInfo[s1][2] + nodeInfo[s2][2], 
                        s1, s2, jsd))
        activeNodes.remove(s1)
        activeNodes.remove(s2)
        addCandidate(nodeInfo, nextId, activeNodes, candidatePool, mpPool)
        nextId += 1
        if len(activeNodes) % 10 == 0:
            print 'Remaining active nodes #', len(activeNodes)
    
    mpPool.close()
    rootId = activeNodes.pop()
    return rootId, nodeInfo

# %%
rootId, nodeInfo = distHC1(catDist)
toStore = [(x[0],) + x[2:] for x in nodeInfo]
outputFileName = 'model/hcTree1_original.pickle.gz'
with gzip.open(outputFileName, 'wb') as fout:
    pickle.dump(toStore, fout)
# Out:
# Adding leaf # 0
# Adding leaf # 10
# Adding leaf # 20
# Adding leaf # 30
# Adding leaf # 40
# Adding leaf # 50
# Adding leaf # 60
# Adding leaf # 70
# Adding leaf # 80
# Adding leaf # 90
# Adding leaf # 100
# Adding leaf # 110
# Adding leaf # 120
# Adding leaf # 130
# Adding leaf # 140
# Adding leaf # 150
# Adding leaf # 160
# Adding leaf # 170
# Adding leaf # 180
# Adding leaf # 190
# Adding leaf # 200
# Adding leaf # 210
# Adding leaf # 220
# Adding leaf # 230
# Adding leaf # 240
# Adding leaf # 250
# Adding leaf # 260
# Adding leaf # 270
# Adding leaf # 280
# Adding leaf # 290
# Adding leaf # 300
# Adding leaf # 310
# Adding leaf # 320
# Adding leaf # 330
# Adding leaf # 340
# Adding leaf # 350
# Adding leaf # 360
# Adding leaf # 370
# Adding leaf # 380
# Adding leaf # 390
# Adding leaf # 400
# Adding leaf # 410
# Adding leaf # 420
# Adding leaf # 430
# Adding leaf # 440
# Adding leaf # 450
# Adding leaf # 460
# Adding leaf # 470
# Adding leaf # 480
# Adding leaf # 490
# Adding leaf # 500
# Adding leaf # 510
# Adding leaf # 520
# Adding leaf # 530
# Adding leaf # 540
# Adding leaf # 550
# Adding leaf # 560
# Adding leaf # 570
# Adding leaf # 580
# Adding leaf # 590
# Adding leaf # 600
# Adding leaf # 610
# Adding leaf # 620
# Adding leaf # 630
# Adding leaf # 640
# Adding leaf # 650
# Adding leaf # 660
# Adding leaf # 670
# Adding leaf # 680
# Adding leaf # 690
# Adding leaf # 700
# Adding leaf # 710
# Adding leaf # 720
# Adding leaf # 730
# Adding leaf # 740
# Adding leaf # 750
# Adding leaf # 760
# Adding leaf # 770
# Adding leaf # 780
# Adding leaf # 790
# Adding leaf # 800
# Adding leaf # 810
# Adding leaf # 820
# Adding leaf # 830
# Adding leaf # 840
# Adding leaf # 850
# Adding leaf # 860
# Adding leaf # 870
# Adding leaf # 880
# Adding leaf # 890
# Adding leaf # 900
# Adding leaf # 910
# Adding leaf # 920
# Adding leaf # 930
# Adding leaf # 940
# Adding leaf # 950
# Adding leaf # 960
# Adding leaf # 970
# Adding leaf # 980
# Adding leaf # 990
# Adding leaf # 1000
# Adding leaf # 1010
# Adding leaf # 1020
# Adding leaf # 1030
# Adding leaf # 1040
# Adding leaf # 1050
# Remaining active nodes # 1050
# Remaining active nodes # 1040
# Remaining active nodes # 1030
# Remaining active nodes # 1020
# Remaining active nodes # 1010
# Remaining active nodes # 1000
# Remaining active nodes # 990
# Remaining active nodes # 980
# Remaining active nodes # 970
# Remaining active nodes # 960
# Remaining active nodes # 950
# Remaining active nodes # 940
# Remaining active nodes # 930
# Remaining active nodes # 920
# Remaining active nodes # 910
# Remaining active nodes # 900
# Remaining active nodes # 890
# Remaining active nodes # 880
# Remaining active nodes # 870
# Remaining active nodes # 860
# Remaining active nodes # 850
# Remaining active nodes # 840
# Remaining active nodes # 830
# Remaining active nodes # 820
# Remaining active nodes # 810
# Remaining active nodes # 800
# Remaining active nodes # 790
# Remaining active nodes # 780
# Remaining active nodes # 770
# Remaining active nodes # 760
# Remaining active nodes # 750
# Remaining active nodes # 740
# Remaining active nodes # 730
# Remaining active nodes # 720
# Remaining active nodes # 710
# Remaining active nodes # 700
# Remaining active nodes # 690
# Remaining active nodes # 680
# Remaining active nodes # 670
# Remaining active nodes # 660
# Remaining active nodes # 650
# Remaining active nodes # 640
# Remaining active nodes # 630
# Remaining active nodes # 620
# Remaining active nodes # 610
# Remaining active nodes # 600
# Remaining active nodes # 590
# Remaining active nodes # 580
# Remaining active nodes # 570
# Remaining active nodes # 560
# Remaining active nodes # 550
# Remaining active nodes # 540
# Remaining active nodes # 530
# Remaining active nodes # 520
# Remaining active nodes # 510
# Remaining active nodes # 500
# Remaining active nodes # 490
# Remaining active nodes # 480
# Remaining active nodes # 470
# Remaining active nodes # 460
# Remaining active nodes # 450
# Remaining active nodes # 440
# Remaining active nodes # 430
# Remaining active nodes # 420
# Remaining active nodes # 410
# Remaining active nodes # 400
# Remaining active nodes # 390
# Remaining active nodes # 380
# Remaining active nodes # 370
# Remaining active nodes # 360
# Remaining active nodes # 350
# Remaining active nodes # 340
# Remaining active nodes # 330
# Remaining active nodes # 320
# Remaining active nodes # 310
# Remaining active nodes # 300
# Remaining active nodes # 290
# Remaining active nodes # 280
# Remaining active nodes # 270
# Remaining active nodes # 260
# Remaining active nodes # 250
# Remaining active nodes # 240
# Remaining active nodes # 230
# Remaining active nodes # 220
# Remaining active nodes # 210
# Remaining active nodes # 200
# Remaining active nodes # 190
# Remaining active nodes # 180
# Remaining active nodes # 170
# Remaining active nodes # 160
# Remaining active nodes # 150
# Remaining active nodes # 140
# Remaining active nodes # 130
# Remaining active nodes # 120
# Remaining active nodes # 110
# Remaining active nodes # 100
# Remaining active nodes # 90
# Remaining active nodes # 80
# Remaining active nodes # 70
# Remaining active nodes # 60
# Remaining active nodes # 50
# Remaining active nodes # 40
# Remaining active nodes # 30
# Remaining active nodes # 20
# Remaining active nodes # 10

# %%
# def parseTree(nodeInfo, headNode):
#     tree = {}
#     if nodeInfo[headNode][3] is None or nodeInfo[headNode][4] is None:
#         tree['name'] = catName[headNode]
#         tree['children'] = []
#     else:
#         s1, s2 = nodeInfo[headNode][3], nodeInfo[headNode][4]
#         tree['name'] = str(nodeInfo[headNode][-1])[:6] + ' - ' \
#             + str(nodeInfo[headNode][-1] - nodeInfo[s1][-1] - nodeInfo[s2][-1])[:6]
#         tree['children'] = [parseTree(nodeInfo, s1), parseTree(nodeInfo, s2)]
#     return tree

# %%
# import json
# catTree = parseTree(nodeInfo, rootId)
# with open('vis/hcTree1.json', 'w') as fout:
#     json.dump(catTree, fout)
