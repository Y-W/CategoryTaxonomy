# %% [markdown]
# Finding basic level categoies
# ================

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.colors as pltColors
import numpy as np
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import svds
from scipy.spatial.distance import cosine
import csv
from collections import Counter, defaultdict
from sklearn.preprocessing import normalize
from numpy.linalg import norm
from numpy.linalg import pinv
from scipy.stats import linregress

# %%
# Load files
inputFile = 'data/cat_desc.csv'
headers = None
descCnt = Counter()
catCnt = Counter()
descCatCnt = defaultdict(Counter)
with open(inputFile) as fin:
    r = csv.reader(fin)
    for row in r:
        if headers is None:
            headers = row
            print headers
        else:
            cat, desc, cnt = row
            cat = int(cat) - 1
            cnt = int(cnt)
            descCnt[desc] += cnt
            catCnt[cat] += cnt
            descCatCnt[desc][cat] += cnt

catNameFile = 'data/categoryKey.csv'
catName = {}
with open(catNameFile) as fin:
    r = csv.reader(fin)
    for row in r:
        catName[int(row[0]) - 1] = row[1]

print range(len(catName)) == catName.keys() and range(len(catName)) == catCnt.keys()
# Out:
# ['category_id', 'description', 'count']
# True

# %%
# filter descriptions
threshold = 100
descList = [d for d, c in descCnt.most_common() if c >= threshold]
descId = {i:d for i, d in enumerate(descList)}
print len(descList), len(descCnt)
print sum(descCnt[d] for d in descList), sum(descCnt.itervalues())
# Out:
# 1922 84922
# 4801096 5115137

# %%
# Build sparse matrix
rowIdx = []
colIdx = []
dataLst = []
for i, desc in enumerate(descList):
    for j in sorted(descCatCnt[desc].keys()):
        rowIdx.append(i)
        colIdx.append(j)
        dataLst.append(descCatCnt[desc][j])
mtx = csr_matrix((dataLst, (rowIdx, colIdx)), shape=(len(descList), len(catName)), dtype=np.float)
_ = normalize(mtx, norm='l1', axis=0, copy=False)

# %%
reconErr1 = []
reconVar1 = []
reconErr2 = []
reconVar2 = []
numComponent = range(1, 1001)
for k in numComponent:
    if k % 10 == 0:
        print 'Working on component count', k, reconVar1[-1], reconVar2[-1]
    U, S, Vt = svds(mtx, k=k)
    pc = np.flipud(Vt)
    normalize(pc, norm='l2', axis=1, copy=False)
    normalize(mtx, norm='l2', axis=1, copy=False)
    simMtx = np.absolute(mtx.dot(pc.T).T)
    bestMatch = np.argmax(simMtx, axis=1)
    wordPC = np.zeros(pc.shape)
    for i in xrange(k):
        wordPC[i] = mtx.getrow(bestMatch[i]).toarray()
    recon1 = (mtx.dot(pc.T)).dot(pc)
    recon2 = (mtx.dot(pinv(wordPC))).dot(wordPC)
    mtxArray = mtx.toarray()
    reconErr1.append(norm(mtxArray - recon1))
    reconErr2.append(norm(mtxArray - recon2))
    reconVar1.append(linregress(recon1.reshape(-1), mtxArray.reshape(-1))[2]**2)
    reconVar2.append(linregress(recon2.reshape(-1), mtxArray.reshape(-1))[2]**2)
# Out:
# Working on component count 10 0.107632635624 0.0778531567442
# Working on component count 20 0.188032839059 0.14229218156
# Working on component count 30 0.250192410894 0.181837468715
# Working on component count 40 0.301384438606 0.211319973314
# Working on component count 50 0.346727905072 0.238477690456
# Working on component count 60 0.3876046276 0.263864521883
# Working on component count 70 0.424869308046 0.287392287126
# Working on component count 80 0.458966837022 0.309515593505
# Working on component count 90 0.490379937959 0.330070446537
# Working on component count 100 0.518749240641 0.350854177676
# Working on component count 110 0.545109156855 0.372331262726
# Working on component count 120 0.569954579518 0.391043841979
# Working on component count 130 0.593451202888 0.40478298244
# Working on component count 140 0.615612743657 0.416159738844
# Working on component count 150 0.636436187468 0.427997306692
# Working on component count 160 0.655685919353 0.438281900146
# Working on component count 170 0.673440896679 0.450896590025
# Working on component count 180 0.69019420535 0.463628306541
# Working on component count 190 0.706087235713 0.47194885989
# Working on component count 200 0.721028263132 0.482025440905
# Working on component count 210 0.735105895472 0.493797281346
# Working on component count 220 0.748362399841 0.501964094534
# Working on component count 230 0.760919897338 0.511303306164
# Working on component count 240 0.772840759262 0.515070098676
# Working on component count 250 0.784241919967 0.5227219382
# Working on component count 260 0.795081886263 0.529030079703
# Working on component count 270 0.805355567389 0.536222216946
# Working on component count 280 0.81516403433 0.539663334118
# Working on component count 290 0.824534720771 0.547439599615
# Working on component count 300 0.833413876137 0.554641309701
# Working on component count 310 0.841853246701 0.559455688435
# Working on component count 320 0.849926549479 0.563961591039
# Working on component count 330 0.857624892233 0.56683602608
# Working on component count 340 0.864985252017 0.572907700586
# Working on component count 350 0.872005339664 0.576180061555
# Working on component count 360 0.878685470851 0.581235401546
# Working on component count 370 0.885070239659 0.585786368007
# Working on component count 380 0.891172940548 0.589655761633
# Working on component count 390 0.897002910709 0.592939729548
# Working on component count 400 0.902575371706 0.598485010423
# Working on component count 410 0.907894177319 0.601673762098
# Working on component count 420 0.912958293521 0.604651728071
# Working on component count 430 0.917789833772 0.610402769197
# Working on component count 440 0.922399416453 0.614164117805
# Working on component count 450 0.926779757465 0.617080743965
# Working on component count 460 0.930957382466 0.621170153032
# Working on component count 470 0.934921152092 0.623515936681
# Working on component count 480 0.938704445272 0.6307602673
# Working on component count 490 0.942297687217 0.63270463797
# Working on component count 500 0.945726623175 0.637441624725
# Working on component count 510 0.948986705165 0.640446550836
# Working on component count 520 0.95207613838 0.646013283354
# Working on component count 530 0.955002947604 0.651747929901
# Working on component count 540 0.95777776436 0.657909433861
# Working on component count 550 0.960398273385 0.664093704968
# Working on component count 560 0.962889339209 0.670893880708
# Working on component count 570 0.96524068677 0.677348936689
# Working on component count 580 0.967465256385 0.684153579467
# Working on component count 590 0.969563001845 0.689237899389
# Working on component count 600 0.971549337509 0.6947171419
# Working on component count 610 0.973417372327 0.697988406228
# Working on component count 620 0.975179995531 0.70367604694
# Working on component count 630 0.976848250085 0.709570205807
# Working on component count 640 0.978421507679 0.716008893856
# Working on component count 650 0.979904388577 0.723313438002
# Working on component count 660 0.981307241536 0.729259959918
# Working on component count 670 0.982626748112 0.735404912019
# Working on component count 680 0.983869280992 0.739807029546
# Working on component count 690 0.985041334655 0.747298120298
# Working on component count 700 0.986149140423 0.751315579245
# Working on component count 710 0.98719502662 0.754328707237
# Working on component count 720 0.988176046767 0.760599150521
# Working on component count 730 0.989094078674 0.763404906869
# Working on component count 740 0.989958838308 0.768567121418
# Working on component count 750 0.990769937769 0.774622646579
# Working on component count 760 0.991531907607 0.780589630856
# Working on component count 770 0.992247204039 0.785541980459
# Working on component count 780 0.992914576737 0.788533474038
# Working on component count 790 0.993537154467 0.791006618238
# Working on component count 800 0.994118821412 0.794337722598
# Working on component count 810 0.994662083821 0.799182268204
# Working on component count 820 0.995169171454 0.802592743918
# Working on component count 830 0.995640449439 0.806952690991
# Working on component count 840 0.996077393691 0.812477167985
# Working on component count 850 0.996481158241 0.818568183854
# Working on component count 860 0.996855246456 0.82202047972
# Working on component count 870 0.997200167449 0.823794171104
# Working on component count 880 0.99751845678 0.825854978813
# Working on component count 890 0.997810382544 0.830720114314
# Working on component count 900 0.998077637064 0.834352094303
# Working on component count 910 0.99832287333 0.838211448928
# Working on component count 920 0.998546266834 0.84348592652
# Working on component count 930 0.998749607669 0.847935275158
# Working on component count 940 0.998933973145 0.851810178537
# Working on component count 950 0.999101246962 0.853853288993
# Working on component count 960 0.999250358651 0.859864513616
# Working on component count 970 0.999384263997 0.86192819551
# Working on component count 980 0.999502489548 0.864024375034
# Working on component count 990 0.999606455304 0.866767786644
# Working on component count 1000 0.999698508043 0.872340266992

# %%
varThreshold = 0.9
nComponent = min(i for i, x in enumerate(reconVar1) if x >= varThreshold)
print nComponent, reconErr1[nComponent], reconVar1[nComponent], reconErr2[nComponent], reconVar2[nComponent]
# Out:
# 394 13.7164233204 0.900380995686 27.6711056072 0.594629024641

# %%
U, S, Vt = svds(mtx, k=nComponent)
pc = np.flipud(Vt)
normalize(pc, norm='l2', axis=1, copy=False)
normalize(mtx, norm='l2', axis=1, copy=False)
simMtx = np.absolute(mtx.dot(pc.T).T)
bestMatch = np.argmax(simMtx, axis=1)
blDescSet = set()
blDesc = []
for i in bestMatch:
    if descList[i] not in blDescSet:
        blDesc.append(descList[i])
        blDescSet.add(descList[i])
        print descList[i]
print len(blDescSet)
# Out:
# place
# nature
# building
# animal
# auditoriam
# shopping
# play ground
# home
# guest room
# monument
# water
# trash
# music
# kid
# computer
# horse
# dress
# dining
# aeroplan
# hen shed
# party
# parking area
# game center
# parking
# rail
# dent
# wood gate
# wooden compound
# swimming room
# cattle farm
# electricity
# electricity board
# salon
# water pipe
# saloon shop
# parlour
# fance
# doctor
# baseball ground
# vegetable
# vehicle
# market
# harbor
# shell
# ring
# boxing
# port
# racing
# steep
# book
# entrance
# sky
# skating ground
# pet
# cycle parking
# bicycle
# massage place
# wooden room
# pool table
# model
# sheep
# tent
# sports field
# exercise room
# bridge
# board
# bus stand
# sit out
# soldier
# petrol pump
# petrol bank
# blue sky
# wel
# telephone
# drinks shop
# research
# boat deck
# laboratory
# tram
# bull fighting
# entrance place
# car racing
# cemetary
# fire
# court house
# ticket counter
# giraffe
# hat shop
# washing machine
# fish show
# hat
# van
# mini golf
# meat
# nursing home
# old age home
# dog cage
# flower
# badminton ground
# mutton stall
# bed
# meat shop
# bell room
# karate
# karate class
# bowling game
# bowling place
# bowling alley
# bee
# butcher
# mani
# lamp
# canel
# plantation
# tea estate
# saw mill
# toll booth
# podium
# museum
# maersk drilling
# fan
# locker
# windmills
# helicopter pad
# junction
# jewel shop
# jewellery
# toy shop
# voting booth
# limousine
# salt
# weapons
# salt place
# dam
# bamboo
# salt making
# observatory
# toys shop
# dentist
# parade
# eye care shop
# shoe store
# news stand
# chef
# optical shop
# maze
# marsh
# child sleep cot
# cycle race
# bamboo tree
# cloak room
# sea world
# volleyball ground
# smoke
# cafeteria
# fish tank
# rope bridge
# canteen
# circus
# telescope
# candy store
# brick
# candy shop
# mosque
# operating room
# makeup room
# tank
# water tower
# confessional
# butte
# masque
# job center
# dining car
# igloo house
# igloo
# boating
# job centre
# fall
# firepit
# army ship
# mortuary
# morgue
# confessional box
# car dicky
# trunk
# bike race
# wave
# pizza
# vending machine
# smoking
# rafting
# fire station
# motor boat
# flood water
# fish farm
# bathing
# strike
# stop
# dark room
# train berth
# illuminated building
# solar panel
# radio city
# hotel room
# laundry room
# video store
# crosswalk
# football stadium
# hiking trail
# apple
# dugout
# hay field
# cavern
# tea shop
# police station
# computer shop
# mobile home
# rainbow
# board room
# dog kennel
# neighborhood
# picnic area
# drink
# icy hills
# canning company
# steel bridge
# duck
# attic
# bleachers
# hangar
# cellar
# pawn shop
# earth
# corn field
# exercise
# water plant
# banana
# wheel
# driveway
# flood
# oast
# liquor shop
# tree farm
# bank
# covered bridge
# ferry
# steak house
# island
# food court
# motel
# tennis ground
# mountain road
# tourist
# ice cream shop
# organ
# castle palace
# exam hall
# cannon
# general store
# storage shed
# donkey
# boxing court
# train tunnel
# skate park
# 264

# %%
# load json taxonomy tree
taxoTreeFile = 'model/taxoTree_2000_0.pickle.gz'
import gzip
import pickle
with gzip.open(taxoTreeFile) as fin:
    taxoTreeNodes = pickle.load(fin)
print taxoTreeNodes[0][0]
# Out:
# place

# %%
taxoTreeLabels = set(t[0] for t in taxoTreeNodes if len(t[2]) > 0)

# %%
print len(taxoTreeLabels), len(blDescSet), len(taxoTreeLabels & blDescSet)
# Out:
# 352 264 82

# %%
for w in blDesc:
    if w in taxoTreeLabels:
        print w
# Out:
# place
# nature
# building
# monument
# wooden compound
# swimming room
# water pipe
# steep
# massage place
# tent
# board
# sit out
# entrance place
# car racing
# giraffe
# washing machine
# dog cage
# butcher
# canel
# saw mill
# toll booth
# museum
# maersk drilling
# helicopter pad
# voting booth
# salt place
# observatory
# eye care shop
# chef
# marsh
# cycle race
# candy shop
# water tower
# butte
# igloo house
# job centre
# car dicky
# pizza
# fire station
# flood water
# fish farm
# strike
# illuminated building
# solar panel
# radio city
# hotel room
# crosswalk
# football stadium
# dugout
# hay field
# cavern
# rainbow
# board room
# picnic area
# icy hills
# canning company
# attic
# bleachers
# hangar
# cellar
# pawn shop
# exercise
# water plant
# banana
# oast
# covered bridge
# ferry
# steak house
# island
# food court
# motel
# mountain road
# ice cream shop
# organ
# castle palace
# exam hall
# cannon
# general store
# storage shed
# donkey
# train tunnel
# skate park
