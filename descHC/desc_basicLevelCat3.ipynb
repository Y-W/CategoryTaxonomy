# %% [markdown]
# Finding basic level categoies
# ================

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.colors as pltColors
import numpy as np
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import svds
from scipy.spatial.distance import cosine
import csv
from collections import Counter, defaultdict
from sklearn.preprocessing import normalize
from numpy.linalg import norm
from numpy.linalg import pinv
from scipy.stats import linregress
import scipy.io as sio
from math import log
from scipy.stats import entropy
from sklearn.preprocessing import scale
log2 = lambda x: log(x, 2)
lstDiv = lambda x, y: [a / b for a, b in zip(x, y)]

# %%
# Load files
inputFile = 'data/cat_desc_wn.csv'
headers = None
descCnt = Counter()
catCnt = Counter()
descCatCnt = defaultdict(Counter)
with open(inputFile) as fin:
    r = csv.reader(fin)
    for row in r:
        if headers is None:
            headers = row
            print headers
        else:
            cat, desc, cnt = row
            cat = int(cat) - 1
            cnt = int(cnt)
            descCnt[desc] += cnt
            catCnt[cat] += cnt
            descCatCnt[desc][cat] += cnt

catNameFile = 'data/categoryKey.csv'
catName = {}
with open(catNameFile) as fin:
    r = csv.reader(fin)
    for row in r:
        catName[int(row[0]) - 1] = row[1]

print range(len(catName)) == catName.keys() and range(len(catName)) == catCnt.keys()

simMtxGTFile = 'data/largeSimMatrix.mat'
simMtxGT = sio.loadmat(simMtxGTFile)['largeSimMatrix']
print simMtxGT.shape

wordFreq = Counter()
wordFreqSum = -1
with open('data/wikipedia_wordfreq.txt') as fin:
    skipLine = 1 # Skipping first line
    for line in fin:
        line = line.strip()
        if skipLine > 0:
            skipLine -= 1
            wordFreqSum = int(line.strip().split('\t')[1])
            print line
            print wordFreqSum
        else:
            w, c = line.strip().split('\t')
            wordFreq[w.strip().lower()] = int(c)
# Out:
# ['category_id', 'description', 'count']
# True
# (1055, 1055)
# ALL	1229245740
# 1229245740

# %%
# Remove pular words in dictionary
tmpDict = Counter()
for k, v in wordFreq.iteritems():
    if k[-1] == 's' and wordFreq[k[:-1]] > v:
        tmpDict[k[:-1]] += v
    else:
        tmpDict[k] += v
wordFreq = tmpDict

# %%
# filter descriptions
threshold = 100
dictThreshold = 1000
descList = [d for d, c in descCnt.most_common() if c >= threshold and wordFreq[d] >= dictThreshold]
descId = {d:i for i, d in enumerate(descList)}
descFreq = [float(descCnt[d]) for d in descList]
print len(descList), len(descCnt)
print sum(descCnt[d] for d in descList), sum(descCnt.itervalues())
print descFreq[:10]
# Out:
# 872 3058
# 4109027 4477386
# [228830.0, 209892.0, 199302.0, 171715.0, 150931.0, 123176.0, 118045.0, 114949.0, 103442.0, 96420.0]

# %%
# Effectiveness score
descDistMtx = np.zeros((len(descList), len(catName)))
for i, desc in enumerate(descList):
    sumOccur = float(descCnt[desc])
    for c, v in descCatCnt[desc].iteritems():
        descDistMtx[i, c] = v / sumOccur
tmpMtx = descDistMtx.dot(simMtxGT)
s1_1 = []
for i, desc in enumerate(descList):
    s1_1.append(-log2(np.dot(tmpMtx[i], descDistMtx[i])))
s1_1 = scale(s1_1)

s1_2 = []
for i, desc in enumerate(descList):
    s1_2.append(entropy(descDistMtx[i]))
s1_2 = scale(s1_2)

# %%
# Cost score
s2_1 = []
for desc in descList:
    s2_1.append(float(len(desc)))
s2_1 = scale(s2_1)

s2_2 = []
charSet = set('aeiouy')
for desc in descList:
    s2_2.append(float(len([c for c in desc if c in charSet])))
s2_2 = scale(s2_2)

s2_3 = []
for desc in descList:
    s2_3.append(log2(wordFreqSum) - log2(wordFreq[desc]))
s2_3 = scale(s2_3)

# %%
fig = plt.figure(figsize=(12, 9))
ax = fig.add_subplot(1,1,1)
scat = ax.scatter(s1_1, s2_3, c=s2_1, s=5, edgecolor='') # , norm=pltColors.LogNorm())
cbar = fig.colorbar(scat, ax=ax)
# ax.set_xscale('log')
# ax.set_yscale('log')
plt.show()
fig = plt.figure(figsize=(12, 9))
ax = fig.add_subplot(1,1,1)
scat = ax.scatter(s1_2, s2_3, c=s2_1, s=5, edgecolor='') # , norm=pltColors.LogNorm())
cbar = fig.colorbar(scat, ax=ax)
# ax.set_xscale('log')
# ax.set_yscale('log')
plt.show()
slope1, intercept, r_value, p_value, std_err = linregress(s1_1, s2_3)
print slope1, r_value ** 2, p_value
slope2, intercept, r_value, p_value, std_err = linregress(s1_2, s2_3)
print slope2, r_value ** 2, p_value
# Out:
# -0.383675655543 0.147207008656 5.78399910752e-32
# -0.420728155203 0.17701218058 1.0043862591e-38

# %%
print sorted(descList, key=lambda w: s1_1[descId[w]], reverse=False)[:10]
print sorted(descList, key=lambda w: s1_1[descId[w]], reverse=True)[:10]
# Out:
# ['carousel', 'raft', 'confessional', 'vet', 'limousine', 'karate', 'veterinarian', 'bullpen', 'dentist', 'labyrinth']
# ['men', 'man', 'person', 'picture', 'image', 'none', 'unknown', 'viewpoint', 'human', 'organisation']

# %%
print sorted(descList, key=lambda w: s1_2[descId[w]], reverse=False)[:10]
print sorted(descList, key=lambda w: s1_2[descId[w]], reverse=True)[:10]
# Out:
# ['limousine', 'beehive', 'confessional', 'raft', 'carousel', 'dentist', 'vet', 'voting', 'morgue', 'veterinarian']
# ['place', 'hall', 'building', 'men', 'wall', 'house', 'company', 'room', 'person', 'tree']

# %%
print sorted(descList, key=lambda w: s2_3[descId[w]], reverse=False)[:10]
print sorted(descList, key=lambda w: s2_3[descId[w]], reverse=True)[:10]
# Out:
# ['school', 'city', 'game', 'work', 'university', 'well', 'group', 'people', 'family', 'system']
# ['pantry', 'escalator', 'stairwell', 'shona', 'cityscape', 'drugstore', 'mountainside', 'motorboat', 'greenery', 'restroom']

# %%
evalScore = [a * (-slope1) + b for a, b in zip(s1_1, s2_3)]
print sorted(descList, key=lambda w: evalScore[descId[w]], reverse=False)[:30]
print sorted(descList, key=lambda w: evalScore[descId[w]], reverse=True)[:30]
# Out:
# ['power', 'university', 'city', 'football', 'school', 'island', 'game', 'well', 'player', 'club', 'music', 'book', 'river', 'church', 'railway', 'college', 'house', 'left', 'court', 'see', 'system', 'model', 'home', 'village', 'water', 'party', 'work', 'show', 'family', 'ball']
# ['restroom', 'shona', 'greenery', 'showroom', 'workman', 'hanger', 'cupboard', 'archeology', 'bazar', 'wasteland', 'archway', 'cot', 'parlour', 'woodwork', 'sofa', 'storefront', 'watchtower', 'stairwell', 'driveway', 'cityscape', 'workstation', 'patio', 'stair', 'lorry', 'roadside', 'mountainside', 'flyover', 'riverbank', 'camper', 'spaceship']

# %%
evalScore = [a * (-slope2) + b for a, b in zip(s1_2, s2_3)]
print sorted(descList, key=lambda w: evalScore[descId[w]], reverse=False)[:30]
print sorted(descList, key=lambda w: evalScore[descId[w]], reverse=True)[:30]
# Out:
# ['power', 'well', 'school', 'university', 'left', 'football', 'music', 'game', 'city', 'body', 'winner', 'club', 'island', 'book', 'group', 'system', 'family', 'work', 'player', 'show', 'model', 'training', 'form', 'court', 'television', 'stop', 'military', 'ball', 'railway', 'guitar']
# ['greenery', 'restroom', 'mountainside', 'showroom', 'shona', 'seashore', 'archway', 'cupboard', 'riverbank', 'wasteland', 'cityscape', 'roadside', 'workstation', 'sofa', 'cot', 'bungalow', 'boathouse', 'driveway', 'storefront', 'workman', 'patio', 'flyover', 'bazar', 'iceberg', 'archeology', 'masque', 'stairwell', 'parlour', 'woodwork', 'hose']

# %%
# # load json taxonomy tree
# taxoTreeFile = 'model/taxoTree_2000_0.pickle.gz'
# import gzip
# import pickle
# with gzip.open(taxoTreeFile) as fin:
#     taxoTreeNodes = pickle.load(fin)
# print taxoTreeNodes[0][0]
# taxoTreeLabels = set(t[0] for t in taxoTreeNodes if len(t[2]) > 0)
