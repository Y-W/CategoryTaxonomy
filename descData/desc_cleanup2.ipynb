# %% [markdown]
# Description Dataset Cleanup
# ===============
# ## Splitting phrases into words in addition
# Note: the print-outs are not all rules enforced - they are only significant rules enforced

# %%
from string import letters, punctuation, whitespace, printable, digits
import csv
import re
import string
from collections import Counter, defaultdict

# %%
# Load file
wordCatCnt = defaultdict(Counter)
rawDescHeaders = None
with open('rawDesc.csv') as fin:
    csvReader = csv.reader(fin)
    for row in csvReader:
        if rawDescHeaders is None:
            rawDescHeaders = row
        else:
            wordCatCnt[row[2]][row[1]] += 1
print rawDescHeaders
# Out:
# ['image_filename', 'image_category_id', 'description']

# %%
# Make string updates faster
def applyUpdates(updateMap, warningThreshold=50):
    removalWarning = 0
    removalWarningSum = 0
    splitWarning = 0
    splitWarningSum = 0
    for w in updateMap:
        if w in wordCatCnt:
            t = updateMap[w]
            catCnt = wordCatCnt[w]
            sumCnt = sum(catCnt.itervalues())
            if w == t: continue
            if sumCnt >= warningThreshold:
                print w, sumCnt, '-->', t
            if t is None or len(t) == 0:
                removalWarning += 1
                removalWarningSum += sumCnt
                del wordCatCnt[w]
            elif type(t) is tuple or type(t) is list:
                splitWarning += 1
                splitWarningSum += sumCnt
                del wordCatCnt[w]
                for newW in t:
                    wordCatCnt[newW] += catCnt
            else:
                del wordCatCnt[w]
                wordCatCnt[t] += catCnt
        else:
            raise RuntimeError('Update rule is not applicable: ' + w + ' ' + updateMap[w])
    if removalWarning > 0:
        print 'WARNING - Removing entries:', removalWarning, removalWarningSum
    if splitWarning > 0:
        print 'WARNING - Splitting entries:', splitWarning, splitWarningSum

def getWordCnt():
    return Counter({w:sum(c.itervalues()) for w, c in wordCatCnt.iteritems()})

def fastUpdate(fn, warningThreshold=50, enforce=True):
    updateMap = {w:fn(w) for w in wordCatCnt.iterkeys()}
    if enforce: applyUpdates(updateMap, warningThreshold)

def fullUpdate(fn, warningThreshold=50, enforce=True):
    wordCnt = getWordCnt()
    updateMap = fn(wordCnt)
    if enforce: applyUpdates(updateMap, warningThreshold)

# %%
def removeNonPrintableAnswers(w):
    if all(c in printable for c in w):
        return w
    else:
        return None
fastUpdate(removeNonPrintableAnswers)

def removeNumbers(w):
    return w.translate(None, digits)
fastUpdate(removeNumbers)

def punctuationWhitespace2Space(w):
    s = [' ' if (c in whitespace or c in punctuation) else c for c in w]
    return ''.join(s)
fastUpdate(punctuationWhitespace2Space)

# Make everything lowercase, remove leading and trailing spaces/punctuations, and remove multiple spaces
def lowercaseStripMultipleSpaces(w):
    w = w.lower().strip()
    return re.sub(' +',' ', w)
fastUpdate(lowercaseStripMultipleSpaces, warningThreshold=10000)
# Out:
# WARNING - Removing entries: 45 51
# WARNING - Removing entries: 5 5
# house & garden 60 --> house   garden
# dinning room. 162 --> dinning room
# dentist's office 66 --> dentist s office
# children's park 574 --> children s park
# children's room 72 --> children s room
# multi-storeyed building 109 --> multi storeyed building
# bathroom. 50 --> bathroom
# Church 10324 --> church
# Forest 19664 --> forest
# Garden 10108 --> garden
# Hall 23573 --> hall
# Factory 20501 --> factory
# House 22415 --> house
# Sea 10379 --> sea
# Shop 11444 --> shop
# Mountain 18483 --> mountain
# Building 27362 --> building
# WARNING - Removing entries: 2 8

# %%
# Remove space distinction 
# (i.e. map the set of identical answers ignoring space to the most frequent one in the set)
def removeSpaceDistinction(wordCnt):
    answersSet = defaultdict(Counter)
    for s, v in wordCnt.iteritems():
        s_nospace = re.sub('\\W+', '', s)
        answersSet[s_nospace][s]+=v
    updateMap = {}
    for c in answersSet.values():
        t = c.most_common(1)[0][0]
        if len(c.keys()) > 1 and sum(c.values()) - c[t] > 1000:
            print t, '<--', c.keys()
        for s in c:
            updateMap[s] = t
    return updateMap
fullUpdate(removeSpaceDistinction, warningThreshold=1000)
# Out:
# super market <-- ['super market', 'supermarket']
# waterfall <-- ['water fall', 'waterfall', 'water fa ll']
# grassland <-- ['grassland', 'grasslan d', 'grass land', 'grassla nd']
# airport <-- ['airport', 'air port', 'airp ort', 'airpo rt']
# car port <-- ['carport', 'car port']
# bedroom <-- ['bed room', 'be d room', 'bedr oom', 'bedroom', 'bedro om', 'b ed room', 'be droom']
# play ground <-- ['play ground', 'playg round', 'playground']
# wind mill <-- ['windmill', 'wind mill']
# old place <-- ['old place', 'oldplace']
# highway <-- ['high way', 'highway', 'highwa y']
# sea shore <-- ['seashore', 'sea shore']
# bathtub <-- ['bath tub', 'bathtub']
# workshop <-- ['work shop', 'workshop']
# light house <-- ['lighthouse', 'light house']
# swimming pool <-- ['swimming pool', 'swi mming pool', 'swim mingpool', 'swimmi ng pool', 'swimmin gpool', 'swimmingpool']
# bathroom <-- ['bathroom', 'ba throom', 'bath room']
# class room <-- ['classroom', 'class room', 'classr oom']
# under water <-- ['underwater', 'unde r water', 'under water']
# waterfalls <-- ['waterf alls', 'water falls', 'waterfalls']
# bath tub 1092 --> bathtub
# underwater 1784 --> under water
# supermarket 1346 --> super market
# high way 1050 --> highway
# lighthouse 1763 --> light house
# carport 1250 --> car port
# playground 11769 --> play ground
# windmill 1697 --> wind mill
# classroom 5820 --> class room
# water fall 1865 --> waterfall
# oldplace 1862 --> old place
# swimmingpool 1535 --> swimming pool
# seashore 1378 --> sea shore
# bath room 6267 --> bathroom
# water falls 3662 --> waterfalls
# work shop 1220 --> workshop
# grass land 2415 --> grassland
# bed room 26106 --> bedroom
# air port 1362 --> airport

# %%
# Remove pular words if their corresponding singular forms exist in the dataset 
# and (are more popular) or (have more than 100 occurances)
def handlePularWords(wordCnt):
    updateMap = {}
    for s in wordCnt:
        sing = s[:-1]
        if s[-1] == 's' and (wordCnt[s] <= wordCnt[sing] or wordCnt[sing] >= 100):
            updateMap[s] = sing
    return updateMap
fullUpdate(handlePularWords, warningThreshold=1000)
# Out:
# machines 2574 --> machine
# games 3093 --> game
# rocks 3096 --> rock
# players 1178 --> player
# hills 21464 --> hill
# ruins 1458 --> ruin
# clouds 1537 --> cloud
# hotels 1088 --> hotel
# sports 3002 --> sport
# cars 1882 --> car
# waterfalls 7492 --> waterfall
# palaces 3049 --> palace
# hens 1002 --> hen
# apartments 2598 --> apartment
# toys 1194 --> toy
# flowers 3269 --> flower
# houses 1408 --> house
# stairs 1114 --> stair
# trees 16837 --> tree
# plants 2375 --> plant
# peoples 16900 --> people
# steps 12584 --> step
# workers 1712 --> worker
# mountains 4456 --> mountain
# animals 2588 --> animal
# buildings 3126 --> building
# pigs 1140 --> pig
# appartments 1474 --> appartment
# homes 1128 --> home
# chairs 1735 --> chair
# childrens 1442 --> children

# %%
# Modification distance. Credit to Peter Norvig
def edits1(word):
   splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
   deletes    = [a + b[1:] for a, b in splits if b]
   transposes = [a + b[1] + b[0] + b[2:] for a, b in splits if len(b)>1]
   replaces   = [a + c + b[1:] for a, b in splits for c in string.ascii_lowercase if b]
   inserts    = [a + c + b     for a, b in splits for c in string.ascii_lowercase+' ']
   return set(deletes + transposes + replaces + inserts) - set(['', word])

def words(text): return re.findall('[a-z]+', text.lower())

def train(filename):
    model = {}
    with open(filename) as fin:
        skipLine = 1 # Skipping first line
        for line in fin:
            if skipLine > 0:
                skipLine -= 1
            else:
                w, c = line.split('\t')
                if c >= 10000:
                    model[w] = int(c)
    return model

NWORDS = train('wikipedia_wordfreq.txt') 
# Credit to http://www.monlp.com/2012/04/16/calculating-word-and-n-gram-statistics-from-a-wikipedia-corpora/

def inDict(phrase):
    return len(filter(lambda w: w not in NWORDS, words(phrase))) == 0

def scorePhrase(phrase):
    if not inDict(phrase):
        return 0
    return min([NWORDS[w] for w in words(phrase)])

# %%
# Try to correct spellings
def correctSpelling(tmp):
    updateMap = {}
    manualProcess = []
    for s, v in tmp.iteritems():
        if inDict(s):
            updateMap[s] = s
            continue
        po = edits1(s)
        bestDict = max(po, key=scorePhrase)
        if scorePhrase(bestDict) == 0:
            bestDict = None
        bestRef = max(po, key=tmp.get)
        if tmp[bestRef] < 100:
            bestDict = None
        if bestDict == bestRef and bestDict is not None:
            updateMap[s] = bestDict
            if v >= 1000:
                print 'Convert', s, v, '-->', bestDict, tmp[bestDict]
        else:
            if v < 20:
                updateMap[s] = s # gives up rare entries
            else:
                po2 = set([s2 for s1 in po for s2 in edits1(s1)]) or po
                bestRef = max(po2, key=tmp.get)
                if bestRef != s and tmp[bestRef] >= 1000:
                    updateMap[s] = bestRef
                    print 'Convert-2', s, v, '-->', bestRef, tmp[bestRef]
                else:
                    updateMap[s] = s
                    if v >= 100:
                        manualProcess.append((s, v))
    print '-- Manual Process --'
    for s, v in manualProcess:
        print s
    return updateMap
fullUpdate(correctSpelling)
# Out:
# Convert-2 bulinding 4871 --> building 189999
# Convert-2 computeroom 29 --> computer room 1493
# Convert-2 aerplane 36 --> aeroplane 9292
# Convert-2 tolite 29 --> toilet 6954
# Convert-2 acurium 171 --> aquarium 4244
# Convert-2 graveyred 65 --> graveyard 1536
# Convert-2 swming pool 130 --> swimming pool 20049
# Convert-2 prayroom 43 --> play room 3145
# Convert-2 horserideing 44 --> horse riding 1035
# Convert-2 daining hall 879 --> dinning hall 6092
# Convert-2 wattinghall 20 --> waiting hall 5717
# Convert-2 billiats 41 --> billiards 1264
# Convert-2 gamesroom 206 --> game room 1146
# Convert resturant 6548 --> restaurant 54018
# Convert-2 exclator 32 --> escalator 3910
# Convert-2 soffaa 97 --> sofa 1464
# Convert-2 rainage 46 --> drainage 1052
# Convert-2 airoplaine 24 --> aeroplane 9292
# Convert-2 carage 90 --> cage 3778
# Convert-2 gudown 27 --> godown 5288
# Convert-2 reasturant 96 --> restaurant 54018
# Convert-2 daining hal 23 --> dining hall 3711
# Convert restuarant 4089 --> restaurant 54018
# Convert-2 mounament 78 --> monument 6584
# Convert-2 appartsments 58 --> appartment 3592
# Convert-2 cloulds 29 --> cloud 3516
# Convert-2 airopline 88 --> aeroplane 9292
# Convert-2 restarent 545 --> restaurant 54018
# Convert-2 restrarent 21 --> restaurent 4173
# Convert-2 scating 178 --> boating 4510
# Convert-2 resturent 197 --> restaurant 54018
# Convert-2 gesthouse 298 --> guest house 15269
# Convert-2 peopels 79 --> people 31824
# Convert-2 toriest place 30 --> tourist place 2120
# Convert-2 volcona 74 --> volcano 1732
# Convert-2 ariplan 138 --> airplane 3687
# Convert-2 airplain 38 --> airplane 3687
# Convert-2 playgrond 50 --> play ground 51486
# Convert-2 horseridding 31 --> horse riding 1035
# Convert-2 auditouriam 22 --> auditorium 17654
# Convert-2 muesium 41 --> museum 7495
# Convert-2 pathroom 44 --> bathroom 16912
# Convert-2 tailet 39 --> toilet 6954
# Convert-2 music instrumement 49 --> music instrument 1821
# Convert-2 hellicapter 51 --> helicopter 3240
# Convert-2 studiam 27 --> stadium 46461
# Convert-2 musiume 21 --> museum 7495
# Convert-2 barkery 55 --> bakery 11484
# Convert-2 mechinary 64 --> machinery 3014
# Convert-2 waittinghall 111 --> waiting hall 5717
# Convert-2 grenary 38 --> scenary 1149
# Convert-2 telephonbooth 23 --> telephone booth 4684
# Convert-2 oldbuildings 1462 --> old building 6647
# Convert-2 helicafter 38 --> helicopter 3240
# Convert-2 escaleter 31 --> escalator 3910
# Convert-2 restorent 29 --> resturant 6548
# Convert-2 facctorys 31 --> factory 197686
# Convert-2 washpasin 21 --> wash basin 1905
# Convert-2 fortiko 32 --> portico 1025
# Convert-2 billding 248 --> building 189999
# Convert-2 hourbour 63 --> harbour 3701
# Convert-2 dyningtable 53 --> dining table 2141
# Convert-2 vastage 85 --> stage 5058
# Convert-2 auditorm 60 --> auditorium 17654
# Convert-2 playgound 80 --> play ground 51486
# Convert-2 airoplan 68 --> aeroplane 9292
# Convert-2 balgany 44 --> balcony 2166
# Convert-2 valcono 59 --> balcony 2166
# Convert-2 chitchen 33 --> kitchen 20670
# Convert mechine 2476 --> machine 28709
# Convert-2 kicten 22 --> kitchen 20670
# Convert-2 windmil 76 --> wind mill 4081
# Convert-2 reastarunt 26 --> restarant 1385
# Convert-2 playgorund 71 --> play ground 51486
# Convert-2 masage 61 --> garage 1955
# Convert-2 computersroom 23 --> computer room 1493
# Convert-2 moution 38 --> mountion 4929
# Convert-2 fountion 75 --> mountion 4929
# Convert-2 mechaine 223 --> machine 28709
# Convert-2 appartsment 54 --> apartment 9169
# Convert-2 hillls 30 --> hill 30919
# Convert-2 resturaint 20 --> restaurant 54018
# Convert-2 clothset 75 --> closet 5738
# Convert-2 muusium 25 --> museum 7495
# Convert-2 apportment 51 --> apartment 9169
# Convert-2 oldouse 43 --> old house 1497
# Convert-2 alecopter 63 --> alecoopter 1003
# Convert-2 stpes 30 --> step 14297
# Convert-2 restaraunt 448 --> restaurant 54018
# Convert-2 hourserace 83 --> horse race 2605
# Convert-2 polutary 41 --> poultry 1362
# Convert-2 restrant 98 --> restaurant 54018
# Convert-2 enternce 20 --> entrance 6426
# Convert-2 betroom 82 --> bedroom 54392
# Convert-2 railywaytrack 97 --> railway track 5673
# Convert-2 appatment 30 --> apartment 9169
# Convert-2 srore 29 --> store 8531
# Convert-2 statuim 20 --> stadium 46461
# Convert-2 aeroplain 95 --> aeroplane 9292
# Convert-2 musiem 229 --> museum 7495
# Convert-2 histrocial place 51 --> historical place 2247
# Convert-2 musiuem 43 --> museum 7495
# Convert-2 daining 90 --> painting 1263
# Convert-2 washbasion 28 --> wash basin 1905
# Convert-2 trainage 33 --> drainage 1052
# Convert-2 polcony 28 --> balcony 2166
# Convert-2 helicaptor 47 --> helicopter 3240
# Convert-2 carsparking 29 --> car parking 5413
# Convert-2 mouantian 22 --> mountain 165633
# Convert-2 picknic place 182 --> piknic place 2894
# Convert-2 goodown 77 --> godown 5288
# Convert-2 backry 23 --> bakery 11484
# Convert-2 comercialbuilding 51 --> commercial building 3007
# Convert-2 restarunt 533 --> restaurant 54018
# Convert-2 shlls 20 --> falls 12466
# Convert-2 playgrouad 42 --> play ground 51486
# -- Manual Process --
# veichile
# planatorium
# confrancehall
# tallbuildings
# animalshome
# kitchenroom
# sportsroom
# archbuilding
# accurium
# damagedbuilding
# restarea
# trainroute
# pitshop
# photoview
# sushishop
# liviningroom
# grassshapes
# damagedthings
# publicsplace
# damagedarticles
# swimmingful
# hourbor
# kittar
# roadview
# waranta
# alecoopter
# playcourt
# bigbuildings
# woodenframes
# searesearch
# frontviewofbuildings
# riverarea
# liabery
# fueal station
# rocksview
# fogplace
# restround
# damagedstructures
# olderbuliding
# steelstructures
# sandroad
# indoorstadium
# foreat 105 --> forest
# bulinding 4871 --> building
# labratory 57 --> laboratory
# librery 73 --> library
# dyningtable 53 --> dining table
# acurium 171 --> aquarium
# haspital 57 --> hospital
# graveyred 65 --> graveyard
# aroplane 87 --> aeroplane
# swming pool 130 --> swimming pool
# vastage 85 --> stage
# daining hall 879 --> dinning hall
# planetorium 199 --> planetarium
# restaturant 126 --> restaurant
# ainmal 184 --> animal
# hourserace 83 --> horse race
# gamesroom 206 --> game room
# resturant 6548 --> restaurant
# soffaa 97 --> sofa
# machince 717 --> machine
# karathe 93 --> karate
# aircarft 57 --> aircraft
# carage 90 --> cage
# stonehendge 60 --> stonehenge
# reasturant 96 --> restaurant
# piono 63 --> piano
# restuarant 4089 --> restaurant
# mounament 78 --> monument
# appartsments 58 --> appartment
# airopline 88 --> aeroplane
# restarent 545 --> restaurant
# apportment 51 --> apartment
# auditorm 60 --> auditorium
# aiecraft 57 --> aircraft
# memoriel 131 --> memorial
# scating 178 --> boating
# resturent 197 --> restaurant
# peopels 79 --> people
# volcona 74 --> volcano
# ariplan 138 --> airplane
# playgrond 50 --> play ground
# histrocial place 51 --> historical place
# vehile 148 --> vehicle
# machlneries 77 --> machineries
# restrarunt 158 --> restraunt
# hellicapter 51 --> helicopter
# exhipition 67 --> exhibition
# builiding 70 --> building
# barkery 55 --> bakery
# mechinary 64 --> machinery
# waittinghall 111 --> waiting hall
# washing mechine 71 --> washing machine
# kitchne 100 --> kitchen
# oldbuildings 1462 --> old building
# laboratry 62 --> laboratory
# foctory 241 --> factory
# restaraunt 448 --> restaurant
# pationt 72 --> patient
# hourbour 63 --> harbour
# escelator 91 --> escalator
# appartsment 54 --> apartment
# playgound 80 --> play ground
# carosuel 57 --> carousel
# gesthouse 298 --> guest house
# valcono 59 --> balcony
# swamming pool 83 --> swimming pool
# cyckle 88 --> cycle
# mechine 2476 --> machine
# billding 248 --> building
# airoplan 68 --> aeroplane
# hospiatal 57 --> hospital
# windmil 76 --> wind mill
# auditourium 85 --> auditorium
# auiditorium 68 --> auditorium
# meachine 183 --> machine
# playgorund 71 --> play ground
# masquie 52 --> masque
# fountion 75 --> mountion
# mechaine 223 --> machine
# clothset 75 --> closet
# viwepoint 247 --> viewpoint
# factary 105 --> factory
# alecopter 63 --> alecoopter
# ateium 151 --> atrium
# factry 71 --> factory
# masage 61 --> garage
# restrant 98 --> restaurant
# facrory 153 --> factory
# helicapter 57 --> helicopter
# bedrrom 239 --> bedroom
# bungalaw 80 --> bungalow
# stedium 422 --> stadium
# bakkery 81 --> bakery
# betroom 82 --> bedroom
# railywaytrack 97 --> railway track
# buildig 54 --> building
# aeroplain 95 --> aeroplane
# barthroom 786 --> bathroom
# musiem 229 --> museum
# daining 90 --> painting
# curcus 241 --> circus
# horbour 101 --> harbour
# factroy 297 --> factory
# picknic place 182 --> piknic place
# libary 86 --> library
# cookling 79 --> cooking
# goodown 77 --> godown
# comercialbuilding 51 --> commercial building
# restarunt 533 --> restaurant
# aeropline 72 --> aeroplane
# stadiume 100 --> stadium

# %%
handConvert = '''
veichile|vehicle
planatorium|planetarium
confrancehall|conference hall
kitchenroom|kitchen
accurium|aquarium
animalshome|animal home
liviningroom|living room
swimmingful|swimming pool
alecoopter|helicopter
liabery|library
frontviewofbuilding|front view of building
fogplace|foggy place
olderbuliding|older building
tallbuildings|tall building
photoview|photo view
sportsroom|sports room
archbuilding|arch building
damagedbuilding|damaged building
trainroute|train route
searesearch|sea research
sushishop|sushi shop
grassshapes|grass shape
damagedarticles|damaged article
damagedthings|damaged thing
roadview|road view
playcourt|play court
woodenframes|wooden frame
riverarea|river area
pitshop|pit shop
rocksview|rock view
damagedstructure|damaged structure
steelstructures|steel structure
sandroad|sand road
indoorstadium|indoor stadium
no image|
unknown|
mountion|mountain
buliding|building
bulding|building
smallhouse|small house
restaurent|restaurant
shope|shop
meating hall|meeting hall
restarant|restaurant
restaruant|restaurant
restraunt|restaurant
chruch|church
hospitel|hospital
hoispatl|hospital
swiming pool|swimming pool
smimming place|swimming place
smimming pool|swimming pool
smimming room|swimming room
parliment|parliament
kichen room|kitchen room
kichen|kitchen
kicthen|kitchen
brige|bridge
restauant|restaurant
railwaybalm|railway balm
charch|church
chirch|church
moutain|mountain
goverment building|government building
seminor class|seminar class
lakh|lake
appartment|apartment
multi storey building|multi story building
bed rooms|bed room
bed rooom|bed room
mountan|mountain
shoping center|shopping center
airplan|airplane
machinary|machinery
machineries|machinery
laboratary|laboratory
lobi|lobby
coridoor|corridor
hallview|hall view
delux car|deluxe car
histrorical place|historical place
rockfort|rock fort
multi storeyed building|multi story building
book centre|book center
liberay|library
tant|tent
hutview|hut view
information centre|information center
swimmimg pool|swimming pool
swimmingfull|swimming pool
cinema theature|cinema theater
theator|theater
theatre|theater
game centre|game center
construciton|construction
musiam|museum
muzium|museum
musem|museum
museiam|museum
statium|stadium
galary|gallery
stedum|stadium
computersoffice|computer office
bouth room|booth room
both room|booth room
bathshower|bath shower
bustand|bus stand
light kouse|light house
secutity place|security place
digg|dig
gargen|garden
archbridge|arch bridge
haiway road|highway road
shipview|ship view
shoping|shopping
men|man
women|woman
natural|nature
tallbuildings|tall building
restround|restaurant
animalshome|animal home
kitchenroom|kitchen room
restarea|rest area
circu|circus
damagedstructure|damaged structure
publicsplace|public place
kittar|gittar
bigbuildings|big building
seminor|seminar
hourbor|harbour
fueal station|fuel station
damagedstructures|damaged structure
frontviewofbuildings|front view of building
'''
tmp = getWordCnt()
updateMap = {}
rules = handConvert.split('\n')
for r in rules:
    if r == '': continue
    s, t = r.split('|')
    if s == t:
        raise RuntimeError('Do not change anything: ' + s + '|' + t)
    if s not in tmp:
        print 'WARNING - rule not used: ', r
    else:
        updateMap[s] = t
applyUpdates(updateMap)
# Out:
# WARNING - rule not used:  circu|circus
# appartment 3667 --> apartment
# tallbuildings 289 --> tall building
# no image 427 -->
# confrancehall 411 --> conference hall
# chruch 12522 --> church
# lakh 147 --> lake
# smallhouse 601 --> small house
# woodenframes 158 --> wooden frame
# brige 189 --> bridge
# sushishop 506 --> sushi shop
# archbuilding 404 --> arch building
# mountan 283 --> mountain
# frontviewofbuildings 154 --> front view of building
# bulding 11998 --> building
# airplan 270 --> airplane
# hospitel 127 --> hospital
# parliment 340 --> parliament
# indoorstadium 431 --> indoor stadium
# riverarea 124 --> river area
# frontviewofbuilding 90 --> front view of building
# book centre 63 --> book center
# liabery 162 --> library
# machineries 729 --> machinery
# hourbor 124 --> harbour
# liviningroom 145 --> living room
# playcourt 342 --> play court
# theator 144 --> theater
# multi storey building 62 --> multi story building
# planatorium 141 --> planetarium
# meating hall 384 --> meeting hall
# swiming pool 872 --> swimming pool
# smimming pool 1621 --> swimming pool
# trainroute 142 --> train route
# roadview 128 --> road view
# publicsplace 137 --> public place
# restarea 173 --> rest area
# restauant 391 --> restaurant
# sportsroom 106 --> sports room
# restaurent 4239 --> restaurant
# accurium 173 --> aquarium
# men 4444 --> man
# shoping 599 --> shopping
# sandroad 101 --> sand road
# rocksview 124 --> rock view
# kitchenroom 551 --> kitchen room
# chirch 195 --> church
# statium 422 --> stadium
# women 1755 --> woman
# restaruant 989 --> restaurant
# hallview 107 --> hall view
# olderbuliding 131 --> older building
# swimmimg pool 178 --> swimming pool
# swimmingful 165 --> swimming pool
# animalshome 157 --> animal home
# photoview 121 --> photo view
# searesearch 194 --> sea research
# damagedthings 127 --> damaged thing
# swimmingfull 80 --> swimming pool
# unknown 1299 -->
# both room 368 --> booth room
# musiam 823 --> museum
# charch 309 --> church
# kichen room 64 --> kitchen room
# kichen 171 --> kitchen
# bigbuildings 195 --> big building
# kittar 177 --> gittar
# steelstructures 200 --> steel structure
# fueal station 182 --> fuel station
# shoping center 1668 --> shopping center
# game centre 412 --> game center
# goverment building 253 --> government building
# veichile 408 --> vehicle
# multi storeyed building 134 --> multi story building
# restarant 1411 --> restaurant
# archbridge 80 --> arch bridge
# fogplace 141 --> foggy place
# shope 352 --> shop
# buliding 5614 --> building
# rockfort 94 --> rock fort
# moutain 364 --> mountain
# alecoopter 1066 --> helicopter
# damagedstructures 126 --> damaged structure
# damagedarticles 149 --> damaged article
# pitshop 650 --> pit shop
# machinary 166 --> machinery
# restround 397 --> restaurant
# galary 61 --> gallery
# theatre 4735 --> theater
# smimming room 228 --> swimming room
# restraunt 724 --> restaurant
# smimming place 173 --> swimming place
# natural 2146 --> nature
# mountion 5042 --> mountain
# damagedbuilding 375 --> damaged building
# grassshapes 112 --> grass shape
# WARNING - Removing entries: 2 1726

# %%
# Handles common long sentences
tmp = getWordCnt()
prefixRemovalS = '''
i am giong to
i am going to
iam going to
i am seeing
i am watching
i want to live
iam seeing
seeing
this is
it is
look like
looks like
'''
prefixBan = set(tuple(l.split()) for l in prefixRemovalS.split('\n') if l != '')
updateMap = {}
for s, v in tmp.iteritems():
    phrase = s.split()
    trunc = 0
    for pattern in prefixBan:
        if tuple(phrase[:len(pattern)]) == pattern:
            trunc = max(trunc, len(pattern))
    if trunc > 0:
        updateMap[s]=' '.join(phrase[trunc:])
        if v > 10:
            print s, v, '-->', updateMap[s]
    else:
        updateMap[s] = s
applyUpdates(updateMap)
# Out:
# i am going to the cinema hall 17 --> the cinema hall
# seeing a arch 31 --> a arch
# this is a room 29 --> a room
# this is factory 12 --> factory
# i am going to the farm land 17 --> the farm land
# iam seeing the chruch 11 --> the chruch
# iam seeing the playground 27 --> the playground
# iam seeing the road 25 --> the road
# this is house 11 --> house
# this is a tree 12 --> a tree
# seeing a play station 16 --> a play station
# this is a factory 23 --> a factory
# i am going to the meeting hall 67 --> the meeting hall
# i am going to the baseball 12 --> the baseball
# this is a shop 36 --> a shop
# iam seeing the church 62 --> the church
# i am going to the railway station 32 --> the railway station
# i am going to the closet 17 --> the closet
# i am going to the church 384 --> the church
# iam seeing the hall 26 --> the hall
# i am going to church 35 --> church
# this is a sea 28 --> a sea
# iam seeing the carshed 11 --> the carshed
# this is a machine 21 --> a machine
# iam seeing the hotel 13 --> the hotel
# i am going to the stadium 70 --> the stadium
# iam seeing the river 46 --> the river
# this is a hotel 15 --> a hotel
# iam seeing the things 12 --> the things
# i am going to the garden 69 --> the garden
# seeing a airpoort 20 --> a airpoort
# i am going to the skating 12 --> the skating
# iam seeing the train 11 --> the train
# i am going to the party hall 12 --> the party hall
# seeing a bus station 20 --> a bus station
# iam seeing the fam house 19 --> the fam house
# i am going to the home 32 --> the home
# this is a forest 18 --> a forest
# i am going to the library 20 --> the library
# i am going to the mountain 12 --> the mountain
# this is building 52 --> building
# iam seeing the man 20 --> the man
# iam seeing the airoplane 14 --> the airoplane
# iam seeing the sea 20 --> the sea
# iam seeing the ship 13 --> the ship
# iam seeing the kugai 11 --> the kugai
# iam seeing the room 14 --> the room
# this is a road 24 --> a road
# i am going to the temple 17 --> the temple
# this is a building 85 --> a building
# i am going to the sea 16 --> the sea
# iam seeing the factory 15 --> the factory
# i am going to the park 192 --> the park
# this is people 11 --> people
# i am going to the bakery 23 --> the bakery
# iam seeing the historic building 120 --> the historic building
# this is a bridge 22 --> a bridge
# iam seeing the building 78 --> the building
# iam seeing the boat 11 --> the boat
# iam seeing the complex 12 --> the complex
# iam seeing the lot of trees 12 --> the lot of trees
# this is a people 14 --> a people
# iam seeing the tree 12 --> the tree
# i am watching a nice construction 20 --> a nice construction
# this is a mount 12 --> a mount
# seeing a rock mountain 32 --> a rock mountain
# iam seeing the bedroom 31 --> the bedroom
# i am going to play 11 --> play
# i am going to the forest 19 --> the forest
# seeing 17 -->
# iam seeing the shopping mall 21 --> the shopping mall
# this is a house 37 --> a house
# this is a church 27 --> a church
# i am going to the music hall 13 --> the music hall
# i am going to the swimming pool 25 --> the swimming pool
# iam seeing the garden 11 --> the garden
# this is shop 11 --> shop
# it is building 1586 --> building
# i am going to the restaurant 38 --> the restaurant
# iam seeing the autumn 12 --> the autumn
# iam seeing the machines 11 --> the machines
# iam seeing the many peoples 25 --> the many peoples
# i am going to the museum 67 --> the museum
# iam seeing the park 16 --> the park
# iam seeing the restaurant 32 --> the restaurant
# this is a rock 21 --> a rock
# i am going to the factory 121 --> the factory
# iam seeing the car 24 --> the car
# i am going to the office 21 --> the office
# iam seeing the house 96 --> the house
# it is bulding 44 --> bulding
# i am going to the shopping center 25 --> the shopping center
# this is a garden 36 --> a garden
# i am going to the falls 11 --> the falls
# this is a river 12 --> a river
# i am going to the hotel 232 --> the hotel
# i am going to the shopping mall 60 --> the shopping mall
# iam seeing the nature 54 --> the nature
# seeing a building 65 --> a building
# this is sea 21 --> sea
# iam seeing the mountain 70 --> the mountain
# this is a stadium 11 --> a stadium
# iam seeing the many things 11 --> the many things
# iam seeing the palace 14 --> the palace
# i am going to the meeting hall 67 --> the meeting hall
# iam seeing the church 62 --> the church
# i am going to the church 384 --> the church
# i am going to the stadium 70 --> the stadium
# i am going to the garden 69 --> the garden
# iam seeing the historic building 120 --> the historic building
# this is a building 85 --> a building
# i am going to the park 192 --> the park
# iam seeing the building 78 --> the building
# this is building 52 --> building
# it is building 1586 --> building
# i am going to the museum 67 --> the museum
# i am going to the factory 121 --> the factory
# iam seeing the house 96 --> the house
# i am going to the hotel 232 --> the hotel
# i am going to the shopping mall 60 --> the shopping mall
# seeing a building 65 --> a building
# iam seeing the nature 54 --> the nature
# iam seeing the mountain 70 --> the mountain
# WARNING - Removing entries: 1 17

# %%
# Remove confident stop words
tmp = getWordCnt()
stopWordsS='a,an,the,some' # only include very confident ones
stopWords = set([w.lower().strip() for w in stopWordsS.split(',')])
updateMap = {}
for s, v in tmp.iteritems():
    phrase = s.split()
    phraseOut = filter(lambda w: w not in stopWords, phrase)
    updateMap[s] = ' '.join(phraseOut)
    if v > 100 and len(phrase) > len(phraseOut):
        print s, v, '-->', updateMap[s]
applyUpdates(updateMap)
# Out:
# under the sea 399 --> under sea
# the house 140 --> house
# the church 449 --> church
# the hotel 245 --> hotel
# the factory 150 --> factory
# a building 229 --> building
# the historic building 120 --> historic building
# the park 212 --> park
# the museum 67 --> museum
# under the sea 399 --> under sea
# the mountain 85 --> mountain
# a house 76 --> house
# a shop 55 --> shop
# the garden 80 --> garden
# the building 79 --> building
# the church 449 --> church
# the restaurant 71 --> restaurant
# a room 64 --> room
# the meeting hall 77 --> meeting hall
# the road 69 --> road
# the hotel 245 --> hotel
# the factory 150 --> factory
# the stadium 71 --> stadium
# the home 63 --> home
# a building 229 --> building
# the music hall 56 --> music hall
# the shopping mall 82 --> shopping mall
# the river 55 --> river
# the historic building 120 --> historic building
# the house 140 --> house
# the park 212 --> park
# the nature 54 --> nature
# WARNING - Removing entries: 2 35

# %%
# Combine identical terms if we ignore less confident stop words
stopWordsS2='a,able,about,across,after,all,almost,also,am,among,an,and,any,are,as,at,be,because,been,but,by,can,\
cannot,could,dear,did,do,does,either,else,ever,every,for,from,get,got,had,has,have,he,her,hers,him,his,how,however,\
i,if,in,into,is,it,its,just,least,let,like,likely,may,me,might,most,must,my,neither,nor,of,off,often,on,\
only,or,other,our,own,rather,said,say,says,she,should,since,so,some,than,that,the,their,them,then,there,these,they,\
this,tis,to,too,twas,us,want,wants,was,we,were,what,when,where,which,while,who,whom,why,will,with,would,yet,you,\
your,iam'
# Credit to http://www.textfixer.com/resources/common-english-words.txt
def removeStopwordDistinction(tmp):
    stopWords2 = set([w.lower().strip() for w in stopWordsS2.split(',')]) - stopWords
    unorderedDesc = defaultdict(Counter)
    updateMap = {}
    for s, v in tmp.iteritems():
        phrase = s.split()
        phraseOut = filter(lambda w: w not in stopWords2, phrase)
        unorderedDesc[' '.join(sorted(phraseOut))][s]+=v
    for k, c in unorderedDesc.iteritems():
        if k == '':
            for s in c.keys():
                updateMap[s] = ''
        else:
            target_s, target_v = c.most_common(1)[0]
            for s in c.keys():
                updateMap[s] = target_s
            if len(c.keys()) > 1 and sum(c.values()) - c.most_common(1)[0][1] > 50:
                print c.most_common(1)[0], '<--', c.most_common()[1:], sum(c.values()) - c.most_common(1)[0][1]
    return updateMap
fullUpdate(removeStopwordDistinction)
# Out:
# ('exterior house', 370) <-- [('house exterior', 49), ('exterior of house', 7), ('exterior in house', 1)] 57
# ('exterior building', 604) <-- [('building exterior', 479), ('exterior of building', 4)] 483
# ('room', 62412) <-- [('room in', 123), ('was room', 2), ('other room', 2), ('so room', 1), ('room is', 1), ('any room', 1), ('its room', 1)] 131
# ('conference', 939) <-- [('conference all', 51)] 51
# ('car race', 2506) <-- [('race car', 495)] 495
# ('table chair', 322) <-- [('table and chair', 71), ('chair table', 17), ('chair and table', 16)] 104
# ('place of worship', 464) <-- [('worship place', 140), ('place to worship', 6)] 146
# ('garden house', 309) <-- [('house garden', 148), ('house with garden', 16), ('garden and house', 13), ('house in garden', 6), ('house and garden', 5), ('garden with house', 2), ('house to garden', 1)] 191
# ('mountain with sea', 57) <-- [('mountain sea', 21), ('sea with mountain', 19), ('sea mountain', 17), ('mountain and sea', 7), ('sea and mountain', 1)] 65
# ('church', 117959) <-- [('church in', 68), ('in church', 7), ('these are church', 1)] 76
# ('building interior', 62) <-- [('interior building', 60), ('interior of building', 11)] 71
# ('car racing', 137) <-- [('racing car', 60)] 60
# ('mountain river', 77) <-- [('mountain with river', 50), ('river with mountain', 9), ('river mountain', 8), ('mountain and river', 3), ('river and mountain', 3), ('river by mountain', 1)] 74
# ('park', 46541) <-- [('it park', 38), ('them park', 29), ('i am in park', 1)] 68
# ('train', 16691) <-- [('in train', 36), ('train in', 15), ('its train', 1)] 52
# ('building front', 54) <-- [('front building', 46), ('front of building', 17), ('in front of building', 4)] 67
# ('house hall', 142) <-- [('hall in house', 132), ('hall house', 1), ('hall for house', 1)] 134
# ('building', 214920) <-- [('other building', 38), ('all building', 21), ('building in', 5), ('us building', 3), ('its building', 1), ('it building', 1)] 69
# ('house room', 71) <-- [('house in room', 36), ('room in house', 15), ('room of house', 1)] 52
# ('house', 228768) <-- [('house in', 202), ('in house', 4), ('house get', 3), ('my house', 2), ('house from', 1), ('from house', 1), ('would house', 1), ('on house', 1), ('he house', 1), ('said house', 1), ('too house', 1)] 218
# ('house front', 1226) <-- [('front of house', 27), ('front house', 21), ('in front house', 1), ('house in front', 1), ('in front of house', 1)] 51
# racing car 60 --> car racing
# like 68 -->
# hall in house 132 --> house hall
# house in 202 --> house
# table and chair 71 --> table chair
# conference all 51 --> conference
# building exterior 479 --> exterior building
# worship place 140 --> place of worship
# interior building 60 --> building interior
# room in 123 --> room
# race car 495 --> car race
# house garden 148 --> garden house
# church in 68 --> church
# mountain with river 50 --> mountain river
# WARNING - Removing entries: 31 253

# %%
# Redo: Remove space distinction
# (i.e. map the set of identical answers ignoring space to the most frequent one in the set)
fullUpdate(removeSpaceDistinction)
# Out:
# rockview 54 --> rock view

# %%
# Redo: Remove pular words if their corresponding singular forms exist in the dataset 
# and (are more popular) or (have more than 100 occurances)
fullUpdate(handlePularWords)

# %%
# Redo: spelling correction
fullUpdate(correctSpelling)
# Out:
# -- Manual Process --
# waranta

# %%
# Split phrases into words in addition
wordCnt = getWordCnt()
def splitPhrases(w):
    s = w.split()
    if len(s) == 1:
        if len(w) <= 6: return w
        score, spI = max((min(wordCnt[w[:i]], wordCnt[w[i:]]), i) for i in xrange(3, len(w) - 2))
        w1, w2 = w[:spI], w[spI:]
        if score >= 1000:
            return [w, w1, w2]
        else:
            return w
    else:
        return s + [w]
fastUpdate(splitPhrases, warningThreshold=10000)
# Out:
# guest house 15574 --> ['guest', 'house', 'guest house']
# living room 19768 --> ['living', 'room', 'living room']
# meeting hall 10887 --> ['meeting', 'hall', 'meeting hall']
# play ground 51802 --> ['play', 'ground', 'play ground']
# swimming pool 23269 --> ['swimming', 'pool', 'swimming pool']
# class room 14819 --> ['class', 'room', 'class room']
# old place 23535 --> ['old', 'place', 'old place']
# bedroom 55311 --> ['bedroom', 'bed', 'room']
# WARNING - Splitting entries: 66908 1019655

# %%
# Redo: clean up stopwords
fullUpdate(removeStopwordDistinction)
# Out:
# with 2195 -->
# like 131 -->
# from 248 -->
# at 546 -->
# is 116 -->
# it 59 -->
# in 2810 -->
# of 3709 -->
# or 216 -->
# and 2405 -->
# on 913 -->
# for 339 -->
# by 122 -->
# i 85 -->
# to 259 -->
# are 125 -->
# WARNING - Removing entries: 83 14875

# %%
# Redo: Remove space distinction
# (i.e. map the set of identical answers ignoring space to the most frequent one in the set)
fullUpdate(removeSpaceDistinction)
# Out:
# show room <-- ['showroom', 'show room']
# workplace 54 --> work place
# basket ball 261 --> basketball
# sub station 74 --> substation
# sinkhole 62 --> sink hole
# playground 73 --> play ground
# railroad 365 --> rail road
# windmill 51 --> wind mill
# underground 142 --> under ground
# volley ball 382 --> volleyball
# roadside 55 --> road side
# showroom 1324 --> show room
# classroom 157 --> class room
# underwater 484 --> under water

# %%
# Redo: Remove pular words if their corresponding singular forms exist in the dataset 
# and (are more popular) or (have more than 100 occurances)
fullUpdate(handlePularWords)
# Out:
# woods 99 --> wood
# tickets 307 --> ticket
# machines 126 --> machine
# lights 71 --> light
# kids 3941 --> kid
# items 228 --> item
# boats 54 --> boat
# pianos 453 --> piano
# rocks 215 --> rock
# steeps 109 --> steep
# girls 119 --> girl
# dogs 172 --> dog
# doors 72 --> door
# fields 162 --> field
# ruins 129 --> ruin
# pets 78 --> pet
# news 505 --> new
# games 754 --> game
# bottles 151 --> bottle
# things 1652 --> thing
# materials 89 --> material
# hills 1607 --> hill
# steps 552 --> step
# garments 208 --> garment
# beds 137 --> bed
# clouds 123 --> cloud
# cleaners 656 --> cleaner
# shirts 110 --> shirt
# drinks 1043 --> drink
# passengers 63 --> passenger
# sports 2888 --> sport
# rays 52 --> ray
# birds 131 --> bird
# cars 178 --> car
# plains 113 --> plain
# flowers 329 --> flower
# fruits 303 --> fruit
# cards 51 --> card
# jewels 81 --> jewel
# falls 12761 --> fall
# stilts 54 --> stilt
# ways 59 --> way
# weapons 85 --> weapon
# entrances 277 --> entrance
# bricks 145 --> brick
# arts 219 --> art
# hens 147 --> hen
# persons 77 --> person
# images 100 --> image
# instruments 180 --> instrument
# sales 489 --> sale
# students 438 --> student
# tracks 200 --> track
# houses 204 --> house
# toys 356 --> toy
# horses 65 --> horse
# cows 88 --> cow
# waves 215 --> wave
# athletics 308 --> athletic
# barrels 174 --> barrel
# upstairs 490 --> upstair
# stairs 121 --> stair
# windows 87 --> window
# stones 149 --> stone
# beams 106 --> beam
# trees 1013 --> tree
# plants 196 --> plant
# peoples 178 --> people
# tables 135 --> table
# workers 113 --> worker
# pillars 65 --> pillar
# opticals 225 --> optical
# mountains 232 --> mountain
# boys 70 --> boy
# turbines 83 --> turbine
# pipes 116 --> pipe
# tools 304 --> tool
# balls 104 --> ball
# animals 2242 --> animal
# pieces 85 --> piece
# bones 126 --> bone
# winners 61 --> winner
# buildings 233 --> building
# blocks 70 --> block
# pigs 86 --> pig
# lines 101 --> line
# books 253 --> book
# electronics 127 --> electronic
# billiards 1713 --> billiard
# soldiers 64 --> soldier
# controls 59 --> control
# players 190 --> player
# parts 144 --> part
# rooms 66 --> room
# seats 216 --> seat
# chairs 284 --> chair
# childrens 1423 --> children
# vegetables 84 --> vegetable

# %%
# Redo: hand convert
tmp = getWordCnt()
updateMap = {}
rules = handConvert.split('\n')
for r in rules:
    if r == '': continue
    s, t = r.split('|')
    if s == t:
        raise RuntimeError('Do not change anything: ' + s + '|' + t)
    if s not in tmp:
#         print 'WARNING - rule not used: ', r
        pass
    else:
        updateMap[s] = t
applyUpdates(updateMap)
# Out:
# appartment 54 --> apartment
# moutain 71 --> mountain
# seminor 62 --> seminar
# theator 190 --> theater
# kittar 56 --> gittar
# bulding 208 --> building
# restaurent 447 --> restaurant
# theatre 3483 --> theater
# men 455 --> man
# shoping 860 --> shopping
# women 252 --> woman
# natural 495 --> nature
# statium 59 --> stadium
# shope 71 --> shop
# buliding 247 --> building
# WARNING - Removing entries: 1 27

# %%
# Check popular misspelled entry (our dictionary is not perfect)
tmp = getWordCnt()
occ = 0
for s, v in tmp.most_common():
    if len(filter(lambda w: w not in NWORDS, words(s))) > 0:
        occ += v
        if v >= 100:
            print s, v
print occ
# Out:
# waranta 298
# kuthrai 181
# 33039

# %%
# Check most common ones
tmp = getWordCnt()
for s, v in tmp.most_common(20):
    print s, v
# Out:
# house 278702
# building 251142
# room 244145
# factory 202529
# hall 200021
# mountain 184807
# shop 153133
# ground 127000
# church 119911
# forest 119108
# road 108276
# garden 107490
# sea 88706
# office 79940
# water 76835
# restaurant 76524
# place 68907
# play 67444
# bridge 66270
# bed 64246

# %%
# Check frequency==100
tmp = getWordCnt()
for s, v in tmp.iteritems():
    if v == 100:
        print s, v
# Out:
# robo 100
# lumber 100
# putting green 100
# tele booth 100
# bell tower 100
# japanese 100
# vast land 100
# snow road 100
# nature trail 100
# groud 100

# %%
# Check frequency==50
tmp = getWordCnt()
for s, v in tmp.iteritems():
    if v == 50:
        print s, v
# Out:
# queue 50
# pilgrimage 50
# swan 50
# factory area 50
# wooden cabin 50
# cruise ship deck 50
# football game 50
# agrifield 50
# sun rays 50
# very 50
# telecast 50
# topiary garden 50
# parkway 50
# iron bridge 50
# cauge 50
# bonestructures 50
# school house 50
# gap 50
# stock market 50
# bottling 50
# o 50
# ambulance 50
# coaboard 50
# derrick 50
# brasserie 50
# clouds with sky 50
# fumes 50
# coca 50
# prision 50
# relax 50
# snow fort 50
# greek 50
# cotton 50
# cycle sports 50
# pilot house 50
# opera house 50
# fam 50
# sweet shop 50
# microscope 50

# %%
# Saving file
headers = ['category_id', 'description', 'count']
with open('cat_desc_2.csv', 'w') as fout:
    csvWriter = csv.writer(fout)
    csvWriter.writerow(headers)
    for word, dist in wordCatCnt.iteritems():
        for cat, v in dist.iteritems():
            csvWriter.writerow((cat, word, v))
