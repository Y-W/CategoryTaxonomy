# %% [markdown]
# Description Dataset Cleanup
# ===============
# Note: the print-outs are not all rules enforced - they are only significant rules enforced

# %%
import os
import sys
import subprocess
import csv
import re
import collections
import string

# %%
# Load file
rawDesc = [] # list of tuples of (image_filename, image_category_id, description)
rawDescHeaders = None
with open('rawDesc.csv') as fin:
    csvReader = csv.reader(fin)
    for row in csvReader:
        if rawDescHeaders is None:
            rawDescHeaders = row
        else:
            rawDesc.append(row)
print rawDescHeaders
# Out:
# ['image_filename', 'image_category_id', 'description']

# %%
# Make string updates faster
def applyUpdates(desc, updateMap):
    madeEmpty = set()
    for data in desc:
        if data[2] in updateMap:
            if len(updateMap[data[2]]) == 0 and data[2] not in madeEmpty:
                print 'WARNING - Removing', data[2]
                madeEmpty.add(data[2])
            data[2] = updateMap[data[2]]
        else:
            raise RuntimeError('Undefined updates')
    if len(madeEmpty) > 0:
        desc[:] = [data for data in desc if len(data[2]) > 0]
def collectDesc(desc):
    ret = collections.Counter()
    for data in desc:
        ret[data[2]]+=1
    return ret

# %%
# Remove all entries that contains numbers and non-English characters
updateMap = {}
tmp = collectDesc(rawDesc);
for s, v in tmp.iteritems():
    if all([c in string.letters+string.punctuation+' ' for c in s]):
        updateMap[s] = s
    else:
        updateMap[s] = ''
        if v >=5 :
            print s, v
applyUpdates(rawDesc, updateMap)
# Out:
# AK 47 7
# route 66 7
# 2 men 6
# ctf - 70 5
# caf� 6
# ak 47 10
# car4 8
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/186/sun_apaplhfunbgmrlmi.jpg
# WARNING - Removing childrens��� palace
# WARNING - Removing Cupboard��_
# WARNING - Removing route 66
# WARNING - Removing mountion4
# WARNING - Removing 1 hockey arena
# WARNING - Removing image1 didn't display
# WARNING - Removing Ch̢teau d'Angers
# WARNING - Removing formula1
# WARNING - Removing 4 wheeler
# WARNING - Removing 3 level home
# WARNING - Removing b00k store
# WARNING - Removing image2 didn't display
# WARNING - Removing 4-wheeler
# WARNING - Removing 2 MALES
# WARNING - Removing 0can bottom
# WARNING - Removing 2 man standing for riffle shooting
# WARNING - Removing 2 men seeing at the sky
# WARNING - Removing F1 Race
# WARNING - Removing Adler75
# WARNING - Removing f1 car
# WARNING - Removing 3-story building
# WARNING - Removing ho0use
# WARNING - Removing boat1
# WARNING - Removing 2 men
# WARNING - Removing 2 men walking on the road
# WARNING - Removing computer center 0r office
# WARNING - Removing pati0
# WARNING - Removing 2 ladies having tea or coffee
# WARNING - Removing 3 story house
# WARNING - Removing 3 wheelers
# WARNING - Removing 1st floor of house
# WARNING - Removing cathedral fa_�ade
# WARNING - Removing old house fa_�ade
# WARNING - Removing 3d
# WARNING - Removing house's fa_�ade
# WARNING - Removing wooden fa_�ade
# WARNING - Removing beautiful pink brick fa_�ade
# WARNING - Removing 2 story house
# WARNING - Removing old 2 story building
# WARNING - Removing 3 story building
# WARNING - Removing 2 old men
# WARNING - Removing 2 girls learning
# WARNING - Removing 3 women
# WARNING - Removing 3 men painting
# WARNING - Removing stone fa��ade with exquisite windows
# WARNING - Removing caf��
# WARNING - Removing 4 member
# WARNING - Removing 11-Sep
# WARNING - Removing f1 car race
# WARNING - Removing urban fa��ade
# WARNING - Removing 911
# WARNING - Removing f1  race
# WARNING - Removing me3ting room
# WARNING - Removing 6 people
# WARNING - Removing 3 men
# WARNING - Removing wrestlers in a 2 against 2 match
# WARNING - Removing o2 world company
# WARNING - Removing ba6th room
# WARNING - Removing wo0rk shop of cars
# WARNING - Removing a8uction shop
# WARNING - Removing an office entrance ro0m
# WARNING - Removing 2 ladies
# WARNING - Removing sc4enary
# WARNING - Removing laborat6ory
# WARNING - Removing Pra��a do Imp��rio
# WARNING - Removing Dani��l Stalpaert
# WARNING - Removing M8
# WARNING - Removing ak 47
# WARNING - Removing AK 47
# WARNING - Removing H0USES
# WARNING - Removing antana 3
# WARNING - Removing la4ke
# WARNING - Removing World Trade Center 9/11
# WARNING - Removing 6
# WARNING - Removing americas 1st theme park
# WARNING - Removing 2 Womens
# WARNING - Removing 2 kids
# WARNING - Removing ctf - 70
# WARNING - Removing stotei 3
# WARNING - Removing calvo 2007
# WARNING - Removing water district plant no. 1
# WARNING - Removing 2 couples in under deep sea
# WARNING - Removing window 3
# WARNING - Removing fu-110
# WARNING - Removing 50  % reductiopm
# WARNING - Removing dg yuengling 8
# WARNING - Removing house3
# WARNING - Removing bu8ilding
# WARNING - Removing advertisement boar4d
# WARNING - Removing 3starhotel
# WARNING - Removing buildings 7 cars
# WARNING - Removing 7528 coach
# WARNING - Removing number 3
# WARNING - Removing 4DSD
# WARNING - Removing 13108588
# WARNING - Removing comp0any
# WARNING - Removing MSD6
# WARNING - Removing e - 10
# WARNING - Removing 51number player
# WARNING - Removing grandiose tower with meurtri��res
# WARNING - Removing win 3 piple
# WARNING - Removing 55 john
# WARNING - Removing sho9p
# WARNING - Removing n143 flight
# WARNING - Removing 2008 meeting
# WARNING - Removing state deuce bigalow 2
# WARNING - Removing ce 90
# WARNING - Removing adler 75
# WARNING - Removing bridg3e
# WARNING - Removing factory1
# WARNING - Removing 2 person
# WARNING - Removing 5 star hotel
# WARNING - Removing 4 person
# WARNING - Removing Amber�__Fort
# WARNING - Removing rooms 75
# WARNING - Removing American pavilion in 1967 Montreal universal exhibition
# WARNING - Removing AA-4753 boat
# WARNING - Removing no 3 gate
# WARNING - Removing 320 frent place
# WARNING - Removing copyright 2003 rog
# WARNING - Removing agra�__fort
# WARNING - Removing o2world
# WARNING - Removing water district plant no.1
# WARNING - Removing 1st floor
# WARNING - Removing �_achine
# WARNING - Removing janjira�__fort.
# WARNING - Removing 74 ale house
# WARNING - Removing STATE DEUCE BIGALOW 2 WEDDING CRASHERS NEXT PENGUINS
# WARNING - Removing 2 people near cave
# WARNING - Removing tenn0s court
# WARNING - Removing 41
# WARNING - Removing game 1 2 3 win
# WARNING - Removing 80- BEND
# WARNING - Removing arena cam 2 fn jun 12
# WARNING - Removing mehran�__gar�__fort
# WARNING - Removing railw3ay station
# WARNING - Removing khandar�__fort
# WARNING - Removing fenced ch��teau
# WARNING - Removing 3d hall
# WARNING - Removing 5 platform
# WARNING - Removing 4 persons
# WARNING - Removing www.LDLY818 arch
# WARNING - Removing ADLER 75 PHOTO
# WARNING - Removing BERPETTI 1899
# WARNING - Removing montebello filtration plant 2
# WARNING - Removing building with Greek temple fa��ade
# WARNING - Removing Southern house with Greek-like fa��ade
# WARNING - Removing 8 7 6 5 4 3 2 1 brigade of cavalry
# WARNING - Removing 3g games
# WARNING - Removing hous3e
# WARNING - Removing Hotel roo0m
# WARNING - Removing 0ffice
# WARNING - Removing melbourne 2006
# WARNING - Removing f1 race ceter
# WARNING - Removing 4clip
# WARNING - Removing restaurant fa��ade with menu
# WARNING - Removing A3PONOPT storey
# WARNING - Removing OPEN SHIP WED FRI SAT 13-18
# WARNING - Removing 2 storyed house
# WARNING - Removing JCB 3
# WARNING - Removing 19th century New York houses
# WARNING - Removing 21519
# WARNING - Removing 2-car garage
# WARNING - Removing ROOMS 75 building
# WARNING - Removing 4friends
# WARNING - Removing 3d picture
# WARNING - Removing hi8ll
# WARNING - Removing pub fa��ade
# WARNING - Removing round 3
# WARNING - Removing fo9rest
# WARNING - Removing O2 world
# WARNING - Removing 3 kids
# WARNING - Removing 3 persons
# WARNING - Removing 3 people
# WARNING - Removing 3 winners
# WARNING - Removing 16th room
# WARNING - Removing m0untain
# WARNING - Removing good bui9lding
# WARNING - Removing 3 GUYS
# WARNING - Removing 2 people eating in a sunroom
# WARNING - Removing 3floor building
# WARNING - Removing washing machi8ne
# WARNING - Removing f1 race
# WARNING - Removing 3d painting
# WARNING - Removing 3star Big Hotel
# WARNING - Removing thai 747 first class Airways
# WARNING - Removing ��n the corridor
# WARNING - Removing North 40 Vet hosp & Bunkhouse Boarding
# WARNING - Removing straightforward fa�_ade
# WARNING - Removing f1 track
# WARNING - Removing a3ponopt
# WARNING - Removing 02 nos washing machines
# WARNING - Removing f1 pit
# WARNING - Removing Plant No:1
# WARNING - Removing 3 tier sleepers
# WARNING - Removing munich airport terminal 1
# WARNING - Removing afyon hamamlar�
# WARNING - Removing 3D room
# WARNING - Removing T0URIST PLACE
# WARNING - Removing 801 THOMSON RD
# WARNING - Removing car4
# WARNING - Removing dresing	room
# WARNING - Removing grand 10 cinemas theatre
# WARNING - Removing 2 persons
# WARNING - Removing 2 cars
# WARNING - Removing shiptn22
# WARNING - Removing commerce fa�_ade
# WARNING - Removing 3 wheeler transport
# WARNING - Removing F1 car
# WARNING - Removing chicken 65
# WARNING - Removing 2 level house
# WARNING - Removing 138 �� 103 Schmap Leeds Neighborhood Guide
# WARNING - Removing o2 world building
# WARNING - Removing F1 race
# WARNING - Removing weastage3
# WARNING - Removing 2304 � 3072 Escalator Cleaning Company
# WARNING - Removing artistic fa�_ade
# WARNING - Removing 2 persons in factory
# WARNING - Removing kids scho0l
# WARNING - Removing cathedral fa�_ade
# WARNING - Removing 2 story building
# WARNING - Removing hill1
# WARNING - Removing cave3
# WARNING - Removing 3 storey home
# WARNING - Removing 2 buses
# WARNING - Removing ARCHIVO FOTOGR�FICO
# WARNING - Removing 1920's street corner
# WARNING - Removing Kamov Ka-27
# WARNING - Removing plant2
# WARNING - Removing cu18r
# WARNING - Removing 6 mountain climbers
# WARNING - Removing 95 nokia
# WARNING - Removing msd6
# WARNING - Removing caf� terrace
# WARNING - Removing caf�
# WARNING - Removing 5 story building
# WARNING - Removing 2-story building
# WARNING - Removing motel 6
# WARNING - Removing 3 people on a hill
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/835/sun_bjcrvneccnmacpji.jpg
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/573/sun_bqkjxefuvrhtmcnr.jpg
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/3/sun_apgxafscsgkhdiqa.jpg
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/346/sun_bqxoatnezwwbikky.jpg
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/734/n04000592_2082.JPEG
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/676/n03878963_13361.JPEG
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/192/n02983357_2310.JPEG
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/732/n09398677_7191.JPEG
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/2/n02669442_1505.JPEG
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/619/sun_bvpgnxmdlzxdwmte.jpg
# WARNING - Removing 3 children and a woman posed around a geodesic play dome
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/1011/sun_bpxemdubkrnswxbx.jpg
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/28/sun_ahrukfbiwpsgdzkg.jpg
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/368/sun_aojyyodkbbummncy.jpg
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/896/n04325208_5273.JPEG
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/918/sun_dcgxmokdgeayhqzc.jpg
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/607/sun_bnjieisnyvioykla.jpg
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/659/sun_btsjasjcprocjdpo.jpg
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/459/sun_aduslxfzlbxlllnz.jpg
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/499/sun_bxyiojnchjudkygt.jpg
# WARNING - Removing http://stanford.edu/~mrgreene/SCENE_CATEGORIES/827/sun_bxzhqzcclxyzwygm.jpg
# WARNING - Removing mus�e d'orsay
# WARNING - Removing sydney opera house 3d
# WARNING - Removing mitsubishi mu 2b
# WARNING - Removing salvador dal�_ santiago el grande
# WARNING - Removing drillmec hh 350
# WARNING - Removing 1200 � 798 SAN FRANCISCO - FUN IS FANNY ...
# WARNING - Removing toilette ext�rieure
# WARNING - Removing saskatchewan��
# WARNING - Removing 2 car garage
# WARNING - Removing 2 door garage
# WARNING - Removing expo 67
# WARNING - Removing Interior Aerolite Cub 23BH
# WARNING - Removing 5T Ranch - Argyle. Texas
# WARNING - Removing alc��zar of seville
# WARNING - Removing ch�teau de vincennes paris
# WARNING - Removing airbus a400m
# WARNING - Removing formula 1 car
# WARNING - Removing s��rmell�ki rep�_l��t�r
# WARNING - Removing produ�_�o de frutas
# WARNING - Removing asus x71sl
# WARNING - Removing 3D games

# %%
# Make everything lowercase, remove leading and trailing spaces/punctuations, and remove multiple spaces
updateMap = {}
for s in collectDesc(rawDesc):
    updateMap[s] = re.sub(' +',' ',s.lower().strip(string.punctuation+string.whitespace))
applyUpdates(rawDesc, updateMap)
# Out:
# WARNING - Removing ?
# WARNING - Removing -
# WARNING - Removing [[

# %%
# Remove space/punctuation distinction (i.e. map the set of identical answers ignoring space to the most frequent one in the set)
tmp = collectDesc(rawDesc)
answersSet = collections.defaultdict(collections.Counter)
for s, v in tmp.iteritems():
    s_nospace = re.sub('\\W+', '', s)
    answersSet[s_nospace][s]+=v
updateMap = {}
for c in answersSet.values():
    t = c.most_common(1)[0][0]
    if len(c.keys()) > 1 and sum(c.values()) - c[t] > 100:
        print t, '<--', c.keys()
    for s in c:
        updateMap[s] = t
applyUpdates(rawDesc, updateMap)
# Out:
# work place <-- ['work place', 'workplace']
# old building <-- ['oldbuilding', 'old building']
# confrancehall <-- ['confrance hall', 'confrancehall']
# fashion show <-- ['fashion show', 'fashionshow']
# night club <-- ['night club', 'nightclub']
# wash basin <-- ['wash basin', 'washbasin']
# car showroom <-- ['car show room', 'car showroom', 'carshowroom']
# railway track <-- ['railway track', 'rail way track', 'rail;way track', 'railwaytrack']
# front yard <-- ['front yard', 'frontyard']
# baseball ground <-- ['base ball ground', 'baseball ground', 'baseballground']
# kitchenroom <-- ['kitchenroom', 'kitchen room']
# prayer hall <-- ['prayer hall', 'prayerhall']
# sports ground <-- ['sportsground', 'sports ground']
# sky scrapers <-- ['sky scrapers', 'skyscrapers']
# pipe line <-- ['pipe-line', 'pipe line', 'pipeline']
# phone booth <-- ['phonebooth', 'phone booth']
# archbuilding <-- ['archbuilding', 'arch building']
# super market <-- ['super market', 'supermarket']
# wooden house <-- ['woodenhouse', 'wooden house']
# river bank <-- ['river bank', 'riverbank']
# backyard <-- ['backyard', 'back yard']
# space ship <-- ['space ship', 'spaceship']
# wine shop <-- ['wine shop', 'wineshop']
# pitshop <-- ['pit shop', 'pitshop']
# under sea <-- ['under sea', 'undersea']
# greenhouse <-- ['greenhouse', 'green house']
# staircase <-- ['stair-case', 'staircase', 'stair case']
# waiting room <-- ['waiting room', 'waitingroom']
# pathway <-- ['path way', 'pathway']
# dinning room <-- ['dinning room', 'dinningroom']
# waterfall <-- ['water fa;ll', 'water fall', 'waterfall']
# book shop <-- ['book shop', 'bookshop']
# grassland <-- ['grassland', 'grasslan d', 'grass land', 'grass & land', 'grassla nd']
# graveyard <-- ['grave yard', 'graveyard']
# bus stand <-- ['bus stand', 'busstand', 'bussta nd']
# airport <-- ['airp[ort', 'airport', 'air port', 'airpo rt']
# book stall <-- ['bookstall', 'book stall']
# snow mountain <-- ['snowmountain', 'snow mountain']
# snow hill <-- ['snowhill', 'snow hill']
# basketball ground <-- ['basket ball ground', 'basket ballground', 'basketball ground']
# telephone booth <-- ['telephonebooth', 'telephone booth', 'tele phone booth']
# aeroplane <-- ['aeroplan e', 'aero plane', 'aeropla ne', 'aeroplane', 'aeropl ane']
# basket ball <-- ['basketball', 'basket ball']
# ice hills <-- ['ice hills', 'ic e hills', 'icehills']
# ice berg <-- ['ice berg', 'ice b erg', 'iceberg']
# play area <-- ['play area', 'playarea']
# boat house <-- ['boathouse', 'boat house']
# ice land <-- ['iceland', 'ice land']
# play school <-- ['playschool', 'play school']
# sushishop <-- ['sushishop', 'sushi shop']
# car shed <-- ['car shed', 'car-shed', 'cars hed', 'carshed']
# courtroom <-- ['court room', 'courtroom']
# submarine <-- ['submarine', 'sub marine']
# shopping mall <-- ['shoppingmall', 'shopping mall']
# control room <-- ['contro;l room', 'control room', 'controlroom']
# daining hall <-- ['daining hall', 'daininghall']
# waiting hall <-- ['waiting hal;l', 'waiting hall', 'waitinghall']
# car port <-- ['carport', 'car port']
# office room <-- ['office room', 'officeroom', 'offic eroom', 'office roo m', 'office-room']
# wood house <-- ['woodhouse', 'wood house']
# tree house <-- ['tree house', 'treehouse', 'tree & house']
# smallhouse <-- ['smallhouse', 'small house']
# house front <-- ['house front', 'housefront']
# bathtub <-- ['bath tub', 'bathtub']
# bedroom <-- ['bed room', 'be d room', 'bedr oom', 'bedroom', 'bedro om', 'b ed room', 'be droom']
# courtyard <-- ['courtyard', 'court yard']
# deep sea <-- ['deepsea', 'deep sea']
# car parking <-- ['car parking', 'car parkin g', 'carparking']
# play ground <-- ['play ground', 'playg round', 'playground']
# oldbuildings <-- ['oldbuildings', 'old buildings']
# landscape <-- ['land scape', 'landscape']
# grass field <-- ['grassfield', 'grass field']
# dining hall <-- ['dininghall', 'dining hall']
# sit out <-- ['sit - out', 'sit-out', 'sitout', 'sit out']
# rail road <-- ['railroad', 'rail road']
# aircraft <-- ['aircraft', 'air craft']
# wastage area <-- ['wastage area', 'wastagearea']
# farm field <-- ['farmfield', 'farm field']
# worksite <-- ['worksite', 'work site']
# corn field <-- ['cornfield', 'corn field']
# both room <-- ['bothroom', 'both room']
# show room <-- ['showroom', 'sho wroom', 'show room', 'show ro om']
# old house <-- ['oldhouse', 'old house']
# earthquake <-- ['earth quake', 'earthquake', 'earth-quake']
# readymade shop <-- ['readymade shop', 'ready made shop', 'readymadeshop']
# washing machine <-- ['washingmachine', 'washing m.achine', 'washing machine']
# photo shoot <-- ['photo shoot', 'photoshoot']
# pawn shop <-- ['pawn shop', 'pawnshop', 'pawn sh op']
# playing court <-- ['playing court', 'playingcourt']
# outhouse <-- ['outhouse', 'out house']
# river side <-- ['riverside', 'river side']
# rest room <-- ['rest room', 'rest roo.m', 'restroom']
# fly over <-- ['fly-over', 'fly over', 'flyover']
# wind mill <-- ['windmill', 'wind mill']
# old age home <-- ['oldagehome', 'oldage home', 'old age home']
# it is building <-- ['it isbuilding', 'it is building']
# show case <-- ['show case', 'showcase']
# flower garden <-- ['flower garden', 'flowergarden']
# old place <-- ['old place', 'oldplace']
# store room <-- ['storeroom', 'store room', 'store-room']
# subway <-- ['sub way', 'sub-way', 'subway']
# job centre <-- ['jobcentre', 'job centre']
# highway <-- ['high way', 'highway', 'high-way', 'highwa y']
# highway road <-- ['highwayroad', 'highway road', 'high way road']
# playcourt <-- ['play court', 'playcourt']
# sea shore <-- ['sea-shore', 'seashore', 'sea shore']
# under way <-- ['under way', 'underway']
# horse race <-- ['horserace', 'horse race', 'horse ra ce']
# guest house <-- ['gues thouse', 'guesthouse', 'guest house']
# wash room <-- ['washroom', 'wash room']
# smimming pool <-- ['smimmingpool', 'smimming pool']
# play station <-- ['playstation', 'play station']
# book store <-- ['book store', 'bookstore']
# meeting hall <-- ['meetinghall', 'meeting hall', 'meetin g hall']
# court house <-- ['courthouse', 'court house']
# basketball court <-- ['basket ball court', 'basketball court', 'basketballcourt', 'basket ballcourt']
# cloak room <-- ['cloakroom', 'cloak room']
# volley ball <-- ['volley ball', 'volleyball']
# glasshouse <-- ['glasshouse', 'glass house']
# highways <-- ['highways', 'high ways']
# living room <-- ['living-room', 'living room', 'livingroom']
# snowfall <-- ['snow fall', 'snowfall']
# race track <-- ['race track', 'racetrack']
# under ground <-- ['underground', 'under ground']
# barber shop <-- ['barber shop', 'bar ber shop', 'barbershop']
# picnic spot <-- ['picnicspot', 'picnic spot']
# workshop <-- ['work shop', 'workshop']
# bus stop <-- ['bu sstop', 'busstop', 'bus stop']
# railway station <-- ['rail way station', 'railway station', 'railwaystation']
# gateway <-- ['gate way', 'gateway']
# saw mill <-- ['saw mill', 'sawmill', 'saw mi;ll']
# farm land <-- ['farm land', 'farmland']
# outside <-- ['outside', 'out side']
# game room <-- ['gameroom', 'game room']
# tourist spot <-- ['touristspot', 'tourist spot']
# dinning hall <-- ['dinninghall', 'dinning hall']
# light house <-- ['lighthouse', 'light house']
# road side <-- ['road side', 'roadside']
# conference hall <-- ['conference hall', 'conferencehall']
# old monument <-- ['oldmonument', 'old monument']
# tollgate <-- ['tollgate', 'toll gate']
# mountainside <-- ['mountain side', 'mountainside']
# skyscraper <-- ['sky-scraper', 'sky scraper', 'sky -scraper', 'skyscraper']
# hill station <-- ['hillstation', 'hill station']
# shipyard <-- ['shipyard', 'ship yard']
# swimming pool <-- ['swimming pool', 'swi mming pool', 'swim mingpool', 'swimmi ng pool', 'swimmin gpool', 'swimmingpool']
# walkway <-- ['walk way', 'walkway']
# baseball <-- ['baseball', 'base ball']
# news stand <-- ['newsstand', 'news stand']
# fire place <-- ['fireplace', 'fire place']
# bathroom <-- ['bathroom', 'ba throom', 'bath room']
# play room <-- ['playroom', 'play room']
# class room <-- ['classroom', 'class room', 'class ?room', 'classr oom']
# reception hall <-- ['reception hall', 'receptionhall']
# under water <-- ['underwater', 'unde r water', 'under water', 'under-water']
# study room <-- ['study room', 'studyroom']
# waterfalls <-- ['waterf alls', 'water falls', 'waterfalls']
# farm house <-- ['farmhouse', 'farm house']

# %%
# Remove pular words if their corresponding singular forms exist in the dataset 
# and (are more popular) or (have more than 50 occurances)
tmp = collectDesc(rawDesc)
updateMap = {}
for s, v in tmp.iteritems():
    if s in updateMap: continue
    if s[-1] == 's' and s[:-1] in tmp:
        if v <= tmp[s[:-1]] or tmp[s[:-1]] >= 50:
            if v + tmp[s[:-1]] >= 50: 
                print s, v, '-->', s[:-1], tmp[s[:-1]]
            updateMap[s] = s[:-1]
            updateMap[s[:-1]] = s[:-1]
        else:
            if v + tmp[s[:-1]] >= 50: 
                print s, v, '<--', s[:-1], tmp[s[:-1]]
            updateMap[s] = s
            updateMap[s[:-1]] = s
for s in tmp:
    if s not in updateMap:
        updateMap[s] = s
    
applyUpdates(rawDesc, updateMap)
# Out:
# woods 753 --> wood 3221
# kids 991 --> kid 230
# domes 12 --> dome 585
# palaces 3049 --> palace 51171
# selfs 16 --> self 700
# airplane seats 39 <-- airplane seat 27
# helipads 1 --> helipad 961
# gradens 1 --> graden 115
# elders 46 <-- elder 14
# mosques 10 --> mosque 2932
# mangos 3 --> mango 61
# childs 77 --> child 1795
# water pipes 4 --> water pipe 167
# sketings 1 --> sketing 274
# disasters 68 --> disaster 275
# jewels 72 <-- jewel 27
# boys 168 --> boy 634
# readings 3 --> reading 98
# photos 406 --> photo 1356
# fruits stalls 1 --> fruits stall 67
# meeting halls 2 --> meeting hall 10390
# organisations 4 --> organisation 435
# farm lands 2 --> farm land 517
# ice houses 1 --> ice house 106
# boatings 1 --> boating 4509
# columns 159 <-- column 45
# cable cars 5 --> cable car 297
# open fields 5 --> open field 46
# historical monuments 11 --> historical monument 72
# glass buildings 3 --> glass building 77
# soliders 36 --> solider 47
# banglows 3 --> banglow 441
# snacks 196 <-- snack 5
# books 751 --> book 282
# taps 9 --> tap 212
# chears 8 --> chear 42
# painting works 2 --> painting work 92
# reefs 1 --> reef 191
# gymnastics 60 <-- gymnastic 31
# basketball courts 2 --> basketball court 2200
# machines 2574 --> machine 26135
# rocky mountains 9 --> rocky mountain 62
# meachines 1 --> meachine 182
# dogs 705 --> dog 3493
# hill areas 2 --> hill area 782
# garages 16 --> garage 1939
# snowy mountains 39 --> snowy mountain 111
# public places 9 --> public place 553
# city buildings 118 --> city building 321
# monitors 18 --> monitor 52
# city streets 6 --> city street 209
# apples 37 --> apple 145
# old places 15 --> old place 23512
# agricultural fields 121 --> agricultural field 6092
# building constructions 3 --> building construction 76
# control rooms 2 --> control room 3956
# animals hospitals 12 --> animals hospital 91
# cabinets 33 --> cabinet 128
# shopping centres 1 --> shopping centre 228
# streets 57 --> street 17137
# dinning tables 22 --> dinning table 3264
# government buildings 6 --> government building 1529
# bamboo trees 59 --> bamboo tree 55
# organs 1 --> organ 120
# hot tubs 1 --> hot tub 1374
# heavens 4 --> heaven 200
# tolls 5 --> toll 92
# exterior buildings 67 --> exterior building 537
# racing cars 19 --> racing car 41
# fort walls 3 --> fort wall 49
# pillors 31 --> pillor 55
# ponds 21 --> pond 9054
# mirrors 28 --> mirror 383
# city scapes 3 --> city scape 200
# dooms 3 --> doom 196
# vegetables 504 --> vegetable 158
# wooden walls 1 --> wooden wall 78
# historic buildings 3 --> historic building 472
# valcanos 10 --> valcano 735
# battleships 1 --> battleship 51
# liquor stores 2 --> liquor store 631
# lake houses 14 --> lake house 971
# floors 13 --> floor 3163
# icy hills 102 <-- icy hill 1
# childerns 30 --> childern 59
# elephants 220 --> elephant 1062
# paint works 1 --> paint work 286
# cathedrals 2 --> cathedral 1859
# seas 15 --> sea 79300
# clock towers 1 --> clock tower 993
# agriculture fields 6 --> agriculture field 1163
# pastures 7 --> pasture 177
# rapids 64 <-- rapid 1
# groups 89 --> group 98
# hous 38 <-- hou 12
# maps 1 --> map 54
# curtains 57 --> curtain 62
# lifts 22 --> lift 3321
# eggs 17 --> egg 33
# exteriors 1 --> exterior 77
# restaurants 309 --> restaurant 53709
# river banks 8 --> river bank 205
# valleys 21 --> valley 7401
# zebras 24 --> zebra 130
# rivers 40 --> river 59052
# testing labs 1 --> testing lab 74
# arches 269 --> arche 50
# safes 1 --> safe 105
# vips 7 --> vip 47
# forest trees 30 <-- forest tree 23
# campers 18 --> camper 112
# stone structures 7 --> stone structure 99
# river houses 2 --> river house 69
# elevators 60 --> elevator 742
# grill gates 3 --> grill gate 151
# subways 10 --> subway 2268
# statues 126 --> statue 3603
# closets 20 --> closet 5718
# stores 210 --> store 8321
# church bells 7 --> church bell 55
# circus 5765 <-- circu 2
# aeroplains 2 --> aeroplain 93
# barracks 26 --> barrack 92
# car races 9 --> car race 2496
# leaves 82 <-- leave 2
# hangars 1 --> hangar 108
# meats 1 --> meat 649
# coffins 1 --> coffin 49
# donkeys 7 --> donkey 136
# pig sheds 1 --> pig shed 628
# warehouses 1 --> warehouse 1253
# tress 123 <-- tres 1
# papers 28 --> paper 70
# tanks 100 --> tank 2026
# shootings 3 --> shooting 1194
# power plants 1 --> power plant 580
# small huts 9 --> small hut 42
# teepees 21 --> teepee 314
# satues 2 --> satue 117
# prayers 2 --> prayer 80
# forest paths 1 --> forest path 61
# rail tracks 8 --> rail track 268
# aeroplanes 54 --> aeroplane 9238
# bike tracks 1 --> bike track 55
# mummies 50 <-- mummie 1
# horses 429 --> horse 8831
# photo stills 2 --> photo still 141
# dorms 2 --> dorm 83
# hils 77 <-- hil 32
# roofs 22 --> roof 3386
# stors 5 --> stor 229
# architects 2 --> architect 273
# baby beds 2 --> baby bed 59
# table chairs 67 --> table chair 255
# beautys 1 --> beauty 85
# wastages 150 --> wastage 767
# sports 3002 --> sport 379
# catwalks 1 --> catwalk 137
# village houses 4 --> village house 76
# reservoirs 1 --> reservoir 97
# amusements 2 --> amusement 78
# sheds 45 --> shed 30167
# video games 464 --> video game 209
# oil wells 1 --> oil well 104
# sidewalks 1 --> sidewalk 358
# villas 61 --> villa 330
# houes 24 --> houe 28
# volleyball courts 1 --> volleyball court 560
# snookers 10 --> snooker 181
# trunks 1 --> trunk 127
# buildigs 1 --> buildig 53
# picnic tables 25 --> picnic table 35
# machins 24 --> machin 78
# street shops 35 --> street shop 890
# grasslands 31 --> grassland 4974
# clothes 908 <-- clothe 2
# legs 22 --> leg 31
# mens 231 --> men 4204
# music shops 1 --> music shop 367
# estates 3 --> estate 895
# white water raftings 1 --> white water rafting 50
# shelters 12 --> shelter 613
# workshops 4 --> workshop 5925
# runners 37 --> runner 46
# archs 9 --> arch 10582
# trains 95 --> train 16574
# shrines 9 --> shrine 114
# jewellery shops 1 --> jewellery shop 167
# sea shores 1 --> sea shore 3137
# hospital beds 35 --> hospital bed 220
# cellars 2 --> cellar 135
# factory buildings 9 --> factory building 48
# waste materials 48 <-- waste material 24
# entrances places 1 --> entrances place 232
# condos 31 <-- condo 28
# escelators 3 --> escelator 88
# stables 102 --> stable 896
# snow forts 1 --> snow fort 49
# pin balls 3 --> pin ball 66
# construction works 1 --> construction work 688
# window seats 1 --> window seat 68
# bykes 6 --> byke 57
# fire escapes 7 --> fire escape 403
# fields 674 --> field 14919
# group of peoples 10 --> group of people 70
# glass windows 23 --> glass window 123
# ancient buildings 38 --> ancient building 445
# military aircrafts 1 --> military aircraft 82
# apple trees 4 --> apple tree 85
# seeds 30 <-- seed 21
# swimmers 42 --> swimmer 473
# vechiles 80 --> vechile 119
# saunas 1 --> sauna 674
# ice mountains 28 --> ice mountain 3545
# excavations 1 --> excavation 55
# forts 11 --> fort 38714
# vessels 18 --> vessel 51
# plain lands 1 --> plain land 69
# mechines 16 --> mechine 2460
# construction sites 2 --> construction site 905
# train tracks 659 --> train track 2466
# skys 1 --> sky 10855
# country houses 5 --> country house 254
# share markets 1 --> share market 60
# sofa sets 3 --> sofa set 56
# wood homes 1 --> wood home 118
# sun rays 49 <-- sun ray 7
# islands 14 --> island 576
# candles 50 --> candle 101
# birds 402 --> bird 138
# shows 9 --> show 714
# garments 160 <-- garment 8
# sales 31 --> sale 45
# breads 4 --> bread 81
# trees 16836 --> tree 20582
# oxs 1 --> ox 116
# shoe stores 1 --> shoe store 421
# receptions 18 --> reception 5874
# reception areas 1 --> reception area 56
# damage buildings 10 --> damage building 239
# lakes 14 --> lake 32440
# rolls 20 --> roll 51
# bungalaws 17 --> bungalaw 63
# pools 36 --> pool 3848
# ski slopes 77 --> ski slope 254
# sands 4 --> sand 2113
# carrots 16 --> carrot 44
# builidings 1 --> builiding 69
# eatables 105 <-- eatable 3
# celebrations 1 --> celebration 179
# mechanics 17 --> mechanic 71
# water fountains 8 --> water fountain 236
# white buildings 4 --> white building 84
# orchestras 11 --> orchestra 211
# small rooms 2 --> small room 174
# barbers 6 --> barber 214
# peoples 16900 --> people 14922
# chickens 226 --> chicken 844
# pillers 288 --> piller 1166
# soils 7 --> soil 494
# bottles 388 --> bottle 383
# air wings 1 --> air wing 63
# iam seeing the buildings 1 --> iam seeing the building 77
# hikers 24 --> hiker 27
# scenarys 2 --> scenary 1146
# womens 136 --> women 1616
# convenience stores 2 --> convenience store 320
# plains 290 --> plain 200
# jewellerys 1 --> jewellery 111
# arts 108 --> art 2065
# docks 65 --> dock 1233
# ovens 5 --> oven 107
# volcanos 3 --> volcano 1729
# staircases 3 --> staircase 4793
# storage sheds 3 --> storage shed 113
# students 370 --> student 75
# hut houses 1 --> hut house 521
# stells 3 --> stell 58
# operating rooms 1 --> operating room 594
# baths 3 --> bath 292
# pens 16 --> pen 72
# walls 429 --> wall 19833
# animal farms 1 --> animal farm 121
# giraffes 14 --> giraffe 115
# rubbles 4 --> rubble 99
# rock pillars 22 --> rock pillar 37
# vaults 2 --> vault 311
# race tracks 2 --> race track 1529
# fishes 237 <-- fishe 5
# sunrises 2 --> sunrise 81
# electronics 90 <-- electronic 20
# cameras 8 --> camera 272
# seats 809 --> seat 1560
# ball games 2 --> ball game 55
# works 17 --> work 479
# bus 8305 <-- bu 8
# hilss 1 --> hils 77
# bunkers 2 --> bunker 80
# appartsments 58 --> appartsment 54
# hill houses 5 --> hill house 171
# dress shops 1 --> dress shop 660
# steeps 109 --> steep 99
# memorial buildings 2 --> memorial building 253
# light houses 4 --> light house 4769
# sinks 16 --> sink 122
# playings 1 --> playing 1333
# horse racings 1 --> horse racing 129
# aircrafts 8 --> aircraft 1962
# igloos 4 --> igloo 668
# boilers 152 --> boiler 383
# cafes 2 --> cafe 1068
# booths 20 --> booth 1357
# swiming pools 1 --> swiming pool 868
# cowboys 16 --> cowboy 57
# castles 4 --> castle 3936
# bildings 1 --> bilding 65
# guns 125 --> gun 923
# screens 35 --> screen 286
# malls 128 --> mall 5933
# motels 6 --> motel 730
# automobiles 5 --> automobile 135
# rails 41 --> rail 729
# snow mountains 151 --> snow mountain 3749
# exihibitions 27 --> exihibition 51
# stone hills 9 --> stone hill 66
# cattles 8 --> cattle 1383
# furnaces 32 --> furnace 127
# igloo houses 2 --> igloo house 183
# toilet rooms 2 --> toilet room 94
# cool drinks 88 <-- cool drink 9
# high buildings 60 --> high building 491
# highwayss 1 --> highways 671
# parachutes 1 --> parachute 68
# train stations 2 --> train station 1209
# mountains 4456 --> mountain 161177
# show cases 2 --> show case 307
# masks 3 --> mask 207
# studios 1 --> studio 5196
# rigs 1 --> rig 57
# grocerys 2 --> grocery 145
# home exteriors 2 --> home exterior 120
# mines 99 --> mine 467
# no images 6 --> no image 421
# phone booths 9 --> phone booth 1361
# hostels 1 --> hostel 924
# females 1 --> female 83
# kennels 44 --> kennel 680
# drinks 161 --> drink 78
# waste things 354 <-- waste thing 8
# baseball games 2 --> baseball game 444
# channels 2 --> channel 97
# shrubs 36 <-- shrub 20
# doors 187 --> door 6405
# wells 1 --> well 855
# rings 9 --> ring 176
# damages 116 --> damage 316
# computer stores 1 --> computer store 70
# hostel rooms 5 --> hostel room 63
# opticals 212 --> optical 65
# car sets 1 --> car set 107
# models 64 --> model 276
# palm trees 59 <-- palm tree 45
# golfers 15 --> golfer 59
# wood bridges 1 --> wood bridge 95
# beach resorts 5 --> beach resort 73
# silos 17 --> silo 80
# mans 114 --> man 8892
# meeting rooms 2 --> meeting room 5391
# government offices 2 --> government office 527
# storages 1 --> storage 590
# running tracks 1 --> running track 311
# apartment houses 4 --> apartment house 87
# grapes 79 <-- grape 8
# musicians 44 --> musician 50
# honeys 3 --> honey 91
# cruises 1 --> cruise 163
# races 14 --> race 1821
# theatres 5 --> theatre 4712
# seatings 5 --> seating 252
# slums 27 --> slum 477
# holes 144 --> hole 1341
# dental hospitals 1 --> dental hospital 52
# winners 356 --> winner 294
# skulls 259 --> skull 898
# restaturants 4 --> restaturant 122
# cafeterias 1 --> cafeteria 679
# shacks 32 --> shack 225
# company buildings 12 --> company building 117
# hedges 96 --> hedge 178
# damaged cars 31 <-- damaged car 28
# vehiles 4 --> vehile 144
# rocks 3096 --> rock 15196
# vets 8 --> vet 181
# political buildings 1 --> political building 68
# ski resorts 1 --> ski resort 245
# bushs 52 --> bush 233
# billiards 1264 --> billiard 54
# brick walls 3 --> brick wall 54
# drawings 50 --> drawing 543
# seaplants 47 <-- seaplant 44
# packings 4 --> packing 60
# wind fans 3 --> wind fan 67
# cars 1881 --> car 29585
# graves 19 --> grave 227
# guest rooms 1 --> guest room 2851
# solar panels 42 --> solar panel 65
# fruit shops 1 --> fruit shop 262
# weldings 2 --> welding 89
# hospitals 185 --> hospital 22831
# kiosks 6 --> kiosk 333
# toys 1194 --> toy 318
# telephones 2 --> telephone 480
# labs 6 --> lab 12086
# players 1178 --> player 751
# officers 187 --> officer 154
# rock walls 2 --> rock wall 97
# road shops 3 --> road shop 55
# yards 3 --> yard 1075
# cinema theaters 8 --> cinema theater 184
# fishs 9 --> fish 2121
# cribs 2 --> crib 53
# tent houses 14 --> tent house 247
# canals 8 --> canal 2680
# bakers 15 --> baker 40
# music groups 1 --> music group 143
# wind turbines 27 --> wind turbine 27
# cranes 65 --> crane 1903
# table and chairs 73 --> table and chair 68
# flea markets 1 --> flea market 187
# pets 68 --> pet 76
# exibitions 1 --> exibition 281
# bells 45 --> bell 963
# shoping malls 1 --> shoping mall 324
# voting booths 4 --> voting booth 195
# flower shows 5 --> flower show 221
# water under mans 19 --> water under man 44
# hotels 1088 --> hotel 52864
# green fields 119 --> green field 94
# speakers 8 --> speaker 94
# earth fissures 505 <-- earth fissure 4
# damaged goods 53 <-- damaged good 3
# memorials 2 --> memorial 237
# clothess 1 --> clothes 908
# turbines 77 <-- turbine 47
# coolingtowers 12 --> coolingtower 52
# stepss 1 --> steps 12583
# old mans 3 --> old man 220
# plateaus 4 --> plateau 74
# fans 47 --> fan 623
# balconys 7 --> balcony 2159
# playing games 39 <-- playing game 24
# cakes 68 --> cake 388
# chappels 3 --> chappel 51
# stone pillars 24 --> stone pillar 109
# frames 17 --> frame 34
# peples 173 <-- peple 11
# cycles 177 --> cycle 1553
# head pieces 45 <-- head piece 19
# new buildings 47 --> new building 650
# boards 3 --> board 610
# companys 4 --> company 22843
# electric trains 1 --> electric train 82
# entrances 7 --> entrance 6419
# mountain peaks 16 --> mountain peak 39
# shopping stores 1 --> shopping store 110
# antiques 15 --> antique 47
# waiting halls 1 --> waiting hall 5716
# boat houses 1 --> boat house 927
# roof homes 4 --> roof home 335
# offices 170 --> office 68492
# lamps 14 --> lamp 180
# roof rooms 1 --> roof room 85
# cubboards 8 --> cubboard 78
# clubs 1 --> club 2429
# lawns 350 --> lawn 3972
# briges 72 --> brige 117
# wood houses 12 --> wood house 2652
# corridors 2 --> corridor 833
# diners 16 --> diner 375
# champions 57 <-- champion 20
# couples 180 --> couple 163
# persons 685 --> person 1165
# dustbins 5 --> dustbin 99
# mountianss 2 --> mountians 86
# markets 41 --> market 10343
# confessionals 3 --> confessional 362
# auditoriums 13 --> auditorium 17641
# goats 212 --> goat 955
# plants 2375 --> plant 3511
# waste lands 3 --> waste land 504
# shutters 16 --> shutter 43
# historical places 19 --> historical place 2228
# toilets 79 --> toilet 6875
# billards 62 <-- billard 2
# platforms 3 --> platform 825
# entrance doors 1 --> entrance door 51
# flood waters 28 --> flood water 109
# vending machines 38 --> vending machine 161
# villes 80 --> ville 342
# chicken coops 4 --> chicken coop 394
# buss 15 --> bus 8305
# pits 13 --> pit 316
# things 496 --> thing 62
# monkeys 3 --> monkey 81
# food items 321 --> food item 207
# this is buildings 2 --> this is building 50
# terraces 11 --> terrace 673
# childrens rooms 7 --> childrens room 500
# banners 9 --> banner 62
# vans 40 --> van 2549
# graceess 33 --> gracees 38
# baseball stadiums 1 --> baseball stadium 160
# forest houses 2 --> forest house 399
# bunks 32 --> bunk 109
# scraps 11 --> scrap 76
# height buildings 21 --> height building 194
# display cases 9 --> display case 70
# roadways 129 --> roadway 3142
# restaurents 1 --> restaurent 4172
# dress 859 <-- dres 2
# salts 4 --> salt 351
# starhotels 4 --> starhotel 63
# digs 1 --> dig 934
# coral reefs 8 --> coral reef 97
# beams 96 --> beam 68
# dressing rooms 5 --> dressing room 1702
# ducks 64 --> duck 163
# signals 10 --> signal 153
# telephone booths 13 --> telephone booth 4671
# grocery shops 1 --> grocery shop 118
# balls 605 --> ball 1020
# historical forts 1 --> historical fort 61
# coops 2 --> coop 113
# animals 2588 --> animal 3473
# bamboos 8 --> bamboo 481
# pigs 1140 --> pig 1582
# picnic spots 44 --> picnic spot 707
# ski lodges 1 --> ski lodge 179
# play grounds 1 --> play ground 51485
# hallways 1 --> hallway 1118
# residences 2 --> residence 162
# roads 112 --> road 96301
# dolphins 93 --> dolphin 290
# revolving doors 39 --> revolving door 318
# tickets 81 <-- ticket 23
# casinos 1 --> casino 1256
# phones 1 --> phone 100
# ceilings 2 --> ceiling 562
# ice rinks 4 --> ice rink 581
# open lands 1 --> open land 200
# concert halls 1 --> concert hall 338
# engines 6 --> engine 207
# ancient places 1 --> ancient place 74
# altars 2 --> altar 200
# printers 16 --> printer 37
# wasts 1 --> wast 161
# buildins 3 --> buildin 219
# exhibitions 21 --> exhibition 2079
# glass rooms 3 --> glass room 144
# craters 3 --> crater 69
# hillss 1 --> hills 21464
# wines 8 --> wine 154
# bears 6 --> bear 65
# berths 4 --> berth 383
# old forts 4 --> old fort 805
# city roads 11 --> city road 59
# forests 14 --> forest 114855
# dressess 2 --> dresses 240
# cells 40 --> cell 302
# canels 3 --> canel 594
# group photos 2 --> group photo 155
# rock mountains 18 --> rock mountain 157
# ticket booths 5 --> ticket booth 201
# smokes 1 --> smoke 482
# hills stations 1 --> hills station 153
# stages 6 --> stage 5052
# pizzas 3 --> pizza 134
# interiors 1 --> interior 367
# parcels 13 --> parcel 183
# washing machines 251 --> washing machine 1861
# deers 24 --> deer 108
# tv shows 3 --> tv show 256
# mountain valleys 1 --> mountain valley 122
# keyboards 16 --> keyboard 76
# bags 86 --> bag 132
# country roads 2 --> country road 428
# highrises 8 --> highrise 154
# corals 7 --> coral 54
# pig pens 7 --> pig pen 194
# godowns 2 --> godown 5286
# buses 318 <-- buse 2
# carnivals 1 --> carnival 203
# smoke stacks 30 --> smoke stack 50
# pilots 9 --> pilot 60
# snow caves 1 --> snow cave 63
# flags 136 --> flag 1342
# art of designs 1 --> art of design 73
# wood rooms 1 --> wood room 231
# ainmals 2 --> ainmal 182
# circles 3 --> circle 85
# escalators 41 --> escalator 3869
# vehicles 142 --> vehicle 6878
# machinerys 2 --> machinery 3012
# bones 93 --> bone 75
# waters 4 --> water 58135
# robos 2 --> robo 95
# cannels 2 --> cannel 108
# boxing rings 3 --> boxing ring 885
# boulders 53 <-- boulder 40
# homes 1128 --> home 34147
# landmarks 4 --> landmark 91
# childrens 1442 --> children 2345
# general stores 13 --> general store 159
# ramps 5 --> ramp 224
# walkways 4 --> walkway 666
# cloths 59 --> cloth 181
# containers 29 --> container 112
# underwater scenes 1 --> underwater scene 58
# atriums 1 --> atrium 148
# stands 20 --> stand 232
# liquors 15 --> liquor 72
# rinks 1 --> rink 60
# green trees 59 <-- green tree 40
# factors 12 --> factor 48
# music systems 20 --> music system 40
# ways 16 --> way 3466
# steel gates 1 --> steel gate 58
# skeletons 36 --> skeleton 220
# flakes 10 --> flake 53
# stops 1 --> stop 134
# stocks 68 --> stock 171
# solars 1 --> solar 118
# palases 1 --> palase 68
# temples 11 --> temple 15963
# tables 630 --> table 4543
# windows 491 --> window 4228
# bars 72 --> bar 10486
# wooden cabins 9 --> wooden cabin 41
# lodges 8 --> lodge 797
# snow fields 1 --> snow field 56
# vechicles 14 --> vechicle 286
# cannons 50 --> cannon 158
# snow lands 1 --> snow land 310
# luxury vans 1 --> luxury van 64
# snow areas 3 --> snow area 243
# skeltons 12 --> skelton 99
# goat farms 9 --> goat farm 103
# canyons 48 --> canyon 1420
# huts 372 --> hut 13346
# store rooms 3 --> store room 3937
# wheats 3 --> wheat 127
# bike racks 1 --> bike rack 103
# natures 9 --> nature 30385
# cookers 12 --> cooker 40
# old bridges 1 --> old bridge 53
# war ships 7 --> war ship 80
# horse riders 25 --> horse rider 110
# palces 3 --> palce 97
# chalets 5 --> chalet 91
# exercise machines 82 --> exercise machine 152
# playing places 2 --> playing place 348
# army vehicles 15 --> army vehicle 73
# cooks 4 --> cook 229
# trails 6 --> trail 420
# shirts 93 --> shirt 79
# locks 4 --> lock 76
# wine stores 2 --> wine store 70
# parkings 1 --> parking 1002
# mountans 2 --> mountan 281
# lorrys 5 --> lorry 898
# furnitures 113 --> furniture 328
# wires 55 --> wire 133
# schools 24 --> school 2796
# tvs 7 --> tv 662
# botanical gardens 5 --> botanical garden 119
# small buildings 5 --> small building 45
# displays 7 --> display 180
# modern buildings 4 --> modern building 80
# resorts 78 --> resort 1266
# signs 17 --> sign 251
# boxings 1 --> boxing 2223
# cradles 2 --> cradle 74
# helicapters 1 --> helicapter 56
# pool tables 20 --> pool table 220
# feilds 5 --> feild 200
# ticket counters 27 --> ticket counter 1978
# vegetable markets 5 --> vegetable market 202
# cages 70 --> cage 3708
# motors 41 --> motor 236
# corn fields 6 --> corn field 354
# washing mechines 1 --> washing mechine 70
# cannals 1 --> cannal 63
# symbols 5 --> symbol 51
# church interiors 4 --> church interior 87
# clocks 10 --> clock 298
# church buildings 22 --> church building 127
# places 32 --> place 4071
# nurses 11 --> nurse 43
# fruit markets 1 --> fruit market 79
# gardens 116 --> garden 103116
# hourses 1 --> hourse 273
# train cars 2 --> train car 163
# bundles 38 <-- bundle 20
# gateways 1 --> gateway 597
# wastes 55 --> waste 1076
# babys 51 --> baby 704
# puplic places 13 --> puplic place 499
# wooden doors 11 --> wooden door 66
# horsess 1 --> horses 429
# beds 342 --> bed 7396
# bigs 51 --> big 366
# oast houses 8 --> oast house 63
# nos 1 --> no 60
# polices 7 --> police 358
# tinning tables 2 --> tinning table 52
# caves 270 --> cave 16203
# miltary mans 61 --> miltary man 418
# apartments 2598 --> apartment 6571
# theaters 10 --> theater 4174
# tracks 178 --> track 3594
# bicycles 85 --> bicycle 184
# grils 10 --> gril 70
# systems 44 --> system 91
# barrels 126 --> barrel 91
# houses 1408 --> house 227075
# row houses 53 <-- row house 27
# stone walls 8 --> stone wall 169
# train bridges 2 --> train bridge 76
# pictures 78 --> picture 1253
# bus seats 62 --> bus seat 90
# helicopter pads 2 --> helicopter pad 102
# wooden sheds 1 --> wooden shed 66
# water towers 3 --> water tower 156
# trucks 36 --> truck 799
# factorys 4 --> factory 197681
# balloons 14 --> balloon 73
# muds 1 --> mud 147
# tourists 89 --> tourist 189
# farm houses 6 --> farm house 2158
# fountains 13 --> fountain 2161
# functions 11 --> function 304
# bays 1 --> bay 125
# crops 269 --> crop 163
# foods 357 --> food 5102
# blanks 1 --> blank 80
# hanging bridges 1 --> hanging bridge 96
# lofts 2 --> loft 68
# soccer fields 3 --> soccer field 715
# bodys 1 --> body 62
# painting class 90 <-- painting clas 1
# tunnels 26 --> tunnel 8973
# open restaurants 2 --> open restaurant 69
# coats 10 --> coat 116
# tins 8 --> tin 65
# museums 8 --> museum 7487
# working places 1 --> working place 620
# dorm rooms 1 --> dorm room 286
# fish tanks 4 --> fish tank 202
# musical instrumentals 1 --> musical instrumental 75
# holls 1 --> holl 75
# ships 122 --> ship 27983
# lockers 165 --> locker 1237
# glass doors 20 --> glass door 186
# shoes 126 --> shoe 120
# city view buildings 2 --> city view building 264
# car seats 151 --> car seat 449
# sheets 32 --> sheet 726
# smokings 1 --> smoking 233
# boat docks 20 --> boat dock 353
# laptops 18 --> laptop 168
# images 20 --> image 394
# colleges 39 --> college 2017
# swamps 5 --> swamp 535
# sofas 40 --> sofa 1424
# ladys 48 --> lady 5465
# aquaducts 2 --> aquaduct 80
# shoppings 12 --> shopping 6385
# showers 5 --> shower 817
# poles 23 --> pole 38
# grains 43 --> grain 68
# driveways 3 --> driveway 317
# planes 30 --> plane 1724
# tombs 33 --> tomb 572
# coconut trees 23 --> coconut tree 37
# transformers 31 --> transformer 722
# mesas 20 --> mesa 95
# hotel buildings 9 --> hotel building 76
# book stores 1 --> book store 956
# fire services 6 --> fire service 101
# greenhouses 2 --> greenhouse 458
# circuss 12 --> circus 5765
# canons 24 --> canon 59
# helicopters 64 --> helicopter 3176
# waterfronts 1 --> waterfront 108
# exhipitions 13 --> exhipition 54
# sweets 88 --> sweet 126
# courtrooms 1 --> courtroom 1379
# wash basins 56 --> wash basin 1849
# trams 2 --> tram 194
# stone caves 1 --> stone cave 66
# cauges 1 --> cauge 49
# mansions 3 --> mansion 1259
# byks 1 --> byk 118
# clouds 1537 --> cloud 1979
# posts 4 --> post 145
# exams 2 --> exam 58
# vast plains 85 <-- vast plain 2
# waves 449 --> wave 129
# official buildings 3 --> official building 237
# instruments 62 --> instrument 261
# upstairs 465 --> upstair 87
# flats 317 --> flat 640
# grass 8051 <-- gras 32
# new houses 1 --> new house 78
# dreess 2 --> drees 57
# pillows 28 --> pillow 56
# sand dunes 42 --> sand dune 47
# cots 11 --> cot 95
# baseball players 76 --> baseball player 101
# vegitables 47 <-- vegitable 45
# landscapes 8 --> landscape 3381
# posters 21 --> poster 76
# winds 1 --> wind 90
# wheat fields 5 --> wheat field 166
# horse ridings 2 --> horse riding 1033
# monuments 719 --> monument 5865
# fast foods 1 --> fast food 78
# rock houses 2 --> rock house 140
# florists 1 --> florist 188
# glasss 1 --> glass 446
# music bands 1 --> music band 73
# shores 1 --> shore 381
# horse rides 1 --> horse ride 943
# historical buildings 12 --> historical building 676
# lightings 32 --> lighting 285
# tops 1 --> top 117
# swimming pools 6 --> swimming pool 20043
# halls 48 --> hall 150813
# tigers 13 --> tiger 148
# rope ways 1 --> rope way 132
# cake shops 1 --> cake shop 112
# sea waves 132 <-- sea wave 28
# tourist attractions 1 --> tourist attraction 63
# jets 11 --> jet 166
# rooftops 13 --> rooftop 122
# hill stations 2 --> hill station 967
# cycle races 6 --> cycle race 756
# indoors 2 --> indoor 248
# sky scrappers 12 --> sky scrapper 129
# sports fields 3 --> sports field 423
# horse races 48 --> horse race 2557
# lunch rooms 1 --> lunch room 134
# hen farms 12 --> hen farm 657
# pillars 907 --> pillar 2536
# bus depots 1 --> bus depot 181
# animal cages 3 --> animal cage 56
# residents 6 --> resident 123
# boxs 14 --> box 559
# designs 74 --> design 234
# whales 2 --> whale 70
# electronic systems 1 --> electronic system 65
# bikes 133 --> bike 388
# heaters 3 --> heater 47
# jail cells 10 --> jail cell 238
# high rise buildings 10 --> high rise building 47
# bananas 21 --> banana 107
# restrants 5 --> restrant 93
# water flows 26 --> water flow 69
# boats 577 --> boat 9499
# grees 286 <-- gree 5
# bamboo forests 1 --> bamboo forest 1111
# packages 25 --> package 27
# bottels 63 <-- bottel 17
# golf courses 2 --> golf course 2089
# plates 25 --> plate 49
# caps 59 --> cap 417
# naturals 11 --> natural 2129
# grass fields 87 --> grass field 2623
# towers 277 --> tower 16347
# dance programs 4 --> dance program 442
# fruits 974 --> fruit 180
# textiles 478 --> textile 187
# hens 1002 --> hen 3179
# computer rooms 4 --> computer room 1489
# scientists 63 --> scientist 962
# courtyards 6 --> courtyard 1029
# paddy fields 2 --> paddy field 542
# labours 85 <-- labour 20
# water sports 11 --> water sport 42
# grills 78 --> grill 1112
# stage shows 8 --> stage show 394
# archbridges 6 --> archbridge 74
# worship places 2 --> worship place 138
# totem poles 3 --> totem pole 303
# water tanks 11 --> water tank 659
# wooden works 5 --> wooden work 140
# jails 3 --> jail 5119
# gas stations 1 --> gas station 723
# chambers 7 --> chamber 146
# lambs 9 --> lamb 78
# views 2 --> view 126
# pathways 11 --> pathway 1026
# railways 38 --> railway 997
# forest areas 1 --> forest area 412
# diggers 6 --> digger 47
# girls 427 --> girl 1411
# villages 76 --> village 4020
# cloth stores 2 --> cloth store 69
# cinema theatres 5 --> cinema theatre 421
# stone buildings 15 --> stone building 433
# veterinarians 1 --> veterinarian 89
# show rooms 1 --> show room 2786
# work stations 23 --> work station 196
# travels 19 --> travel 179
# water plants 53 --> water plant 137
# bungalows 10 --> bungalow 1075
# old things 47 <-- old thing 3
# cracks 16 --> crack 150
# nets 31 --> net 879
# borders 11 --> border 48
# damage cars 19 --> damage car 60
# drums 141 --> drum 154
# stations 3 --> station 2691
# lands 24 --> land 13351
# alps 6 --> alp 51
# dolls 67 --> doll 420
# caravans 21 --> caravan 1222
# paths 1 --> path 1013
# motel rooms 1 --> motel room 51
# scuba divers 23 --> scuba diver 115
# desks 34 --> desk 369
# exercises 5 --> exercise 425
# log cabins 6 --> log cabin 141
# buildings 3126 --> building 186872
# industries 233 <-- industrie 2
# airports 38 --> airport 18647
# green places 1 --> green place 59
# alleys 1 --> alley 407
# pots 26 --> pot 73
# shelfs 21 --> shelf 1413
# caverns 8 --> cavern 446
# restruants 7 --> restruant 58
# airplanes 55 --> airplane 3632
# crowds 7 --> crowd 1067
# circus tents 2 --> circus tent 148
# jeeps 1 --> jeep 128
# hats 110 --> hat 497
# pagodas 3 --> pagoda 441
# vegetable shops 1 --> vegetable shop 256
# equipments 38 --> equipment 148
# cycle sports 50 <-- cycle sport 2
# exhibits 1 --> exhibit 76
# car sheets 8 --> car sheet 106
# leafs 30 --> leaf 32
# hotel rooms 38 --> hotel room 947
# ruins 1458 --> ruin 107
# ropes 28 --> rope 205
# bees 68 --> bee 150
# bike races 1 --> bike race 412
# bands 8 --> band 54
# residential buildings 3 --> residential building 55
# diggings 2 --> digging 87
# trailers 5 --> trailer 152
# storage rooms 1 --> storage room 279
# chapels 3 --> chapel 441
# big houses 3 --> big house 107
# buidings 11 --> buiding 217
# falls 12466 --> fall 90
# military mans 7 --> military man 61
# floods 139 --> flood 1201
# weapons 70 <-- weapon 32
# rest rooms 17 --> rest room 1951
# flower shops 1 --> flower shop 1823
# grounds 15 --> ground 59556
# womans 11 --> woman 763
# fights 2 --> fight 169
# animals farms 1 --> animals farm 130
# dining tables 95 --> dining table 2046
# rvs 13 --> rv 72
# orchards 3 --> orchard 460
# honey bees 50 --> honey bee 295
# athletics 288 <-- athletic 17
# cups 23 --> cup 72
# railroad tracks 173 --> railroad track 69
# pianos 102 --> piano 676
# apartment buildings 40 --> apartment building 803
# institutions 2 --> institution 277
# stones 899 --> stone 4084
# deserts 11 --> desert 10085
# dry cleaners 132 --> dry cleaner 67
# tends 1 --> tend 1057
# benchs 4 --> bench 309
# massages 1 --> massage 1821
# patients 7 --> patient 155
# rafts 5 --> raft 60
# army mans 8 --> army man 99
# large buildings 8 --> large building 105
# cross 246 <-- cros 1
# pumps 10 --> pump 592
# irons 3 --> iron 144
# meadows 42 --> meadow 912
# oceans 10 --> ocean 12484
# trainroutes 1 --> trainroute 141
# car sheds 1 --> car shed 6580
# old monuments 94 --> old monument 315
# bleachers 139 <-- bleacher 8
# insects 52 <-- insect 21
# meetings 8 --> meeting 2317
# lions 19 --> lion 33
# departmental stores 52 --> departmental store 557
# passengers 46 <-- passenger 9
# televisions 10 --> television 417
# mountain tops 7 --> mountain top 110
# compounds 1 --> compound 452
# hay fields 4 --> hay field 298
# storage places 1 --> storage place 99
# crop fields 6 --> crop field 68
# slopes 18 --> slope 145
# grocery stores 1 --> grocery store 813
# bakerys 1 --> bakery 11483
# taxis 2 --> taxi 64
# cabins 91 --> cabin 3912
# broken buildings 2 --> broken building 112
# children rooms 6 --> children room 373
# astronauts 16 --> astronaut 60
# classs 2 --> class 892
# tents 304 --> tent 16086
# dog houses 1 --> dog house 61
# luggages 6 --> luggage 62
# mountain views 2 --> mountain view 200
# hilly areas 1 --> hilly area 58
# lines 9 --> line 41
# mills 17 --> mill 657
# streams 6 --> stream 1085
# shopping malls 4 --> shopping mall 7488
# rooms 131 --> room 62185
# stairways 7 --> stairway 665
# chairs 1735 --> chair 3189
# office buildings 207 --> office building 2597
# bulidings 11 --> buliding 5603
# pig farms 10 --> pig farm 984
# glaciers 36 --> glacier 1009
# palas 511 <-- pala 7
# townhouses 26 --> townhouse 73
# vegatables 45 <-- vegatable 9
# stalls 108 --> stall 475
# bee hives 45 --> bee hive 105
# boxes 203 <-- boxe 3
# complexs 1 --> complex 955
# horse stables 4 --> horse stable 107
# tree houses 5 --> tree house 1199
# department stores 8 --> department store 542
# storage areas 1 --> storage area 105
# dining rooms 2 --> dining room 3502
# forms 8 --> form 165
# bowling games 1 --> bowling game 109
# snow hills 971 --> snow hill 1018
# vegtables 64 <-- vegtable 5
# hotel receptions 1 --> hotel reception 76
# tankers 9 --> tanker 85
# cows 721 --> cow 2583
# farm fields 10 --> farm field 317
# banks 2 --> bank 935
# damagedbuildings 117 --> damagedbuilding 258
# constructions 22 --> construction 2349
# granes 1 --> grane 100
# sets 2 --> set 110
# shopes 1 --> shope 351
# dalls 13 --> dall 44
# dams 12 --> dam 5656
# car shops 1 --> car shop 151
# cocks 21 --> cock 1212
# old age homes 1 --> old age home 666
# old houses 17 --> old house 1480
# dry lands 1 --> dry land 307
# shuttle courts 5 --> shuttle court 50
# desserts 14 --> dessert 205
# paintings 203 --> painting 1060
# rock hills 90 --> rock hill 55
# hands 34 --> hand 69
# old cars 19 --> old car 177
# dining areas 1 --> dining area 609
# natural scenes 16 --> natural scene 105
# humans 206 --> human 885
# huge buildings 10 --> huge building 99
# net pratices 8 --> net pratice 108
# buldings 18 --> bulding 11966
# music instruments 639 --> music instrument 1182
# gods 1 --> god 127
# office cabins 128 --> office cabin 212
# meeting tables 7 --> meeting table 61
# friends 250 <-- friend 2
# hiking trails 1 --> hiking trail 226
# montains 2 --> montain 59
# yachts 1 --> yacht 184
# tiles 66 <-- tile 45
# electric towers 4 --> electric tower 94
# buttes 4 --> butte 173
# materials 17 --> material 188
# transforms 1 --> transform 354
# cleaners 242 <-- cleaner 31
# plots 24 --> plot 55
# parks 4 --> park 46292
# plantations 4 --> plantation 500
# bunk beds 97 <-- bunk bed 29
# brooks 1 --> brook 75
# restaruants 1 --> restaruant 985
# pizza huts 1 --> pizza hut 51
# resturants 11 --> resturant 6537
# pipes 252 --> pipe 1025
# shells 7 --> shell 261
# planets 19 --> planet 79
# book shelfs 2 --> book shelf 182
# power lines 77 <-- power line 19
# computers 555 --> computer 4423
# doctors 161 --> doctor 659
# bull fights 1 --> bull fight 1143
# wooden houses 17 --> wooden house 2415
# archways 47 --> archway 1279
# sheeps 100 --> sheep 1315
# publics 60 --> public 81
# ornaments 57 <-- ornament 8
# office spaces 1 --> office space 81
# freeways 1 --> freeway 136
# festivals 2 --> festival 201
# appartments 1474 --> appartment 2118
# toll booths 33 --> toll booth 494
# brick buildings 5 --> brick building 226
# bins 4 --> bin 171
# plantings 1 --> planting 57
# shipyards 1 --> shipyard 778
# gift shops 1 --> gift shop 309
# sea houses 1 --> sea house 82
# bull fightings 4 --> bull fighting 113
# controls 48 <-- control 20
# snow houses 1 --> snow house 268
# forest ways 1 --> forest way 125
# swings 4 --> swing 79
# medicals 19 --> medical 302
# martial arts 256 --> martial art 498
# commercial buildings 3 --> commercial building 3004
# ice caps 25 --> ice cap 34
# enterances 3 --> enterance 490
# cottages 40 --> cottage 3495
# chandeliers 10 --> chandelier 44
# games 3093 --> game 2203
# mounds 4 --> mound 257
# arcade machines 1 --> arcade machine 56
# shopping complexs 1 --> shopping complex 1290
# waiting rooms 1 --> waiting room 4988
# amusement parks 1 --> amusement park 878
# boat decks 1 --> boat deck 250
# farmers 22 --> farmer 35
# bricks 707 --> brick 208
# toys shops 1 --> toys shop 155
# wood walls 1 --> wood wall 115
# transports 1 --> transport 88
# ladders 5 --> ladder 328
# bluffs 29 --> bluff 133
# catacombs 116 <-- catacomb 24
# office cubicles 53 --> office cubicle 54
# tractors 8 --> tractor 186
# outdoors 21 --> outdoor 520
# medicines 27 --> medicine 88
# retail shops 3 --> retail shop 155
# workers 1712 --> worker 4572
# loading docks 3 --> loading dock 73
# control panels 5 --> control panel 124
# rockets 5 --> rocket 390
# iam seeing the mountains 16 --> iam seeing the mountain 54
# race cars 55 --> race car 439
# courts 5 --> court 3752
# mountain roads 1 --> mountain road 120
# motor bikes 19 --> motor bike 55
# audiences 40 --> audience 141
# ice rocks 9 --> ice rock 66
# railway tracks 106 --> railway track 5567
# camels 20 --> camel 150
# dog kennels 7 --> dog kennel 105
# shelves 341 <-- shelve 9
# restarents 2 --> restarent 543
# greens 10 --> green 825
# peopels 79 <-- peopel 10
# moutains 20 --> moutain 344
# office rooms 7 --> office room 4300
# treess 1 --> trees 16836
# green parks 1 --> green park 95
# hosues 1 --> hosue 120
# market places 4 --> market place 165
# stone houses 7 --> stone house 267
# bowling alleys 2 --> bowling alley 1114
# parades 1 --> parade 756
# fire engines 6 --> fire engine 84
# wood doors 2 --> wood door 83
# structures 95 --> structure 262
# military camps 4 --> military camp 124
# tennis courts 75 --> tennis court 1838
# airlines 59 <-- airline 29
# factory machines 8 --> factory machine 60
# squares 1 --> square 100
# newstands 2 --> newstand 92
# shops 273 --> shop 121869
# armys 4 --> army 3008
# hangers 39 --> hanger 99
# stairs 1114 --> stair 114
# fashions 1 --> fashion 163
# cow farms 7 --> cow farm 316
# clothings 1 --> clothing 50
# damagedstructures 126 <-- damagedstructure 3
# airoplanes 2 --> airoplane 848
# damagedhomes 2 --> damagedhome 62
# rope bridges 1 --> rope bridge 150
# musical instruments 220 --> musical instrument 271
# tools 198 <-- tool 17
# wood works 9 --> wood work 383
# vineyards 1 --> vineyard 120
# racks 344 --> rack 2318
# pyramids 39 --> pyramid 241
# exterior houses 99 --> exterior house 271
# gatherings 3 --> gathering 59
# decorations 57 --> decoration 96
# conference rooms 3 --> conference room 2335
# hoses 3 --> hose 239
# tourist places 5 --> tourist place 2115
# car services 7 --> car service 124
# wardrobes 3 --> wardrobe 226
# buidlings 2 --> buidling 86
# fruits shops 3 --> fruits shop 95
# agri lands 1 --> agri land 58
# dyningtables 3 --> dyningtable 50
# cinemas 17 --> cinema 335
# store fronts 13 --> store front 249
# snow roads 2 --> snow road 95
# house buildings 11 --> house building 202
# batting cages 161 --> batting cage 1363
# snows 31 --> snow 9114
# fire works 45 --> fire work 235
# guitars 31 --> guitar 100
# dinner tables 39 --> dinner table 83
# grasss 3 --> grass 8051
# cliffs 371 --> cliff 1083
# flowers 3269 --> flower 1648
# rock formations 195 --> rock formation 1149
# wheels 46 --> wheel 291
# cubicles 70 --> cubicle 167
# chefs 11 --> chef 108
# grates 3 --> grate 63
# house rooms 7 --> house room 64
# cats 1 --> cat 305
# street lights 7 --> street light 65
# totems 1 --> totem 53
# car interiors 1 --> car interior 355
# shoping centers 6 --> shoping center 1662
# fridges 1 --> fridge 105
# flights 30 --> flight 3600
# steels 13 --> steel 501
# oasts 6 --> oast 137
# ancient ruins 259 --> ancient ruin 108
# tickets counters 3 --> tickets counter 163
# tv rooms 1 --> tv room 191
# metals 10 --> metal 85
# farms 47 --> farm 15368
# trolleys 3 --> trolley 69
# plays 4 --> play 3334
# dentists 7 --> dentist 348
# soldiers 519 --> soldier 251
# industrials 1 --> industrial 247
# doorways 11 --> doorway 549
# rice fields 16 --> rice field 43
# steeples 2 --> steeple 94
# artists 3 --> artist 66
# fightings 2 --> fighting 61
# prisons 1 --> prison 3671
# lights 356 --> light 1909
# art works 3 --> art work 161
# waitings 1 --> waiting 90
# nature trails 1 --> nature trail 99
# mountain ranges 4 --> mountain range 229
# partys 3 --> party 2949
# music programs 1 --> music program 392
# counters 30 --> counter 936
# tyres 39 --> tyre 89
# cotteges 15 --> cottege 97
# garbages 9 --> garbage 3003
# railway stations 1 --> railway station 6706
# tea estates 8 --> tea estate 368
# train tunnels 1 --> train tunnel 139
# baby rooms 1 --> baby room 142
# scaffoldings 1 --> scaffolding 68
# steppes 66 <-- steppe 3
# gates 46 --> gate 6518
# building exteriors 9 --> building exterior 469
# beautiful buildings 23 --> beautiful building 37
# frontviewofbuildings 154 --> frontviewofbuilding 90
# sand hills 25 --> sand hill 209
# cow sheds 1 --> cow shed 948
# apportments 8 --> apportment 43
# conferences 2 --> conference 934
# fences 17 --> fence 2991
# ice hills 554 --> ice hill 238
# ports 2 --> port 791
# bulls 13 --> bull 274
# terminals 1 --> terminal 189
# chinese buildings 3 --> chinese building 52
# historic places 1 --> historic place 680
# dinners 1 --> dinner 329
# bridges 83 --> bridge 61364
# decks 2 --> deck 346
# laps 4 --> lap 269
# sculptures 28 --> sculpture 145
# photographs 2 --> photograph 48
# retail stores 10 --> retail store 159
# garment shops 1 --> garment shop 77
# control towers 1 --> control tower 339
# drivers 3 --> driver 60
# chimneys 57 --> chimney 182
# govt offices 1 --> govt office 65
# archbuildings 63 --> archbuilding 341
# water wheels 2 --> water wheel 76
# rides 11 --> ride 594
# camps 11 --> camp 874
# arcade games 362 <-- arcade game 7
# faces 2 --> face 55
# play schools 1 --> play school 2896
# sea divers 24 --> sea diver 52
# beers 2 --> beer 91
# toy stores 1 --> toy store 211
# mountain areas 1 --> mountain area 408
# urinals 61 --> urinal 156
# musics 4 --> music 1443
# oil rigs 2 --> oil rig 535
# dog cages 4 --> dog cage 163
# cartoons 22 --> cartoon 44
# commerical buildings 1 --> commerical building 687
# cupboards 31 --> cupboard 698
# mobile homes 4 --> mobile home 314
# barns 6 --> barn 862
# meeting places 1 --> meeting place 286
# divers 301 --> diver 774
# dens 1 --> den 344
# waterfalls 7492 --> waterfall 7153
# gazebos 12 --> gazebo 341
# butchers 13 --> butcher 143
# stadiums 4 --> stadium 46457
# kitchens 7 --> kitchen 20663
# dances 1 --> dance 719

# %%
# Modification distance. Credit to Peter Norvig
def edits1(word):
   splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
   deletes    = [a + b[1:] for a, b in splits if b]
   transposes = [a + b[1] + b[0] + b[2:] for a, b in splits if len(b)>1]
   replaces   = [a + c + b[1:] for a, b in splits for c in string.ascii_lowercase if b]
   inserts    = [a + c + b     for a, b in splits for c in string.ascii_lowercase+' ']
   return set(deletes + transposes + replaces + inserts) - set(['', word])

def words(text): return re.findall('[a-z]+', text.lower())

def train(filename):
    model = {}
    with open(filename) as fin:
        skipLine = 1 # Skipping first line
        for line in fin:
            if skipLine > 0:
                skipLine -= 1
            else:
                w, c = line.split('\t')
                if c >= 5000:
                    model[w] = int(c)
    return model

NWORDS = train('wikipedia_wordfreq.txt') 
# Credit to http://www.monlp.com/2012/04/16/calculating-word-and-n-gram-statistics-from-a-wikipedia-corpora/

def inDict(phrase):
    return len(filter(lambda w: w not in NWORDS, words(phrase))) == 0

def scorePhrase(phrase):
    if not inDict(phrase):
        return 0
    return min([NWORDS[w] for w in words(phrase)])

# %%
# Try to correct spellings
tmp = collectDesc(rawDesc)
updateMap = {}
manualProcess = []
for s, v in tmp.iteritems():
    if inDict(s):
        updateMap[s] = s
        continue
    po = edits1(s)
    bestDict = max(po, key=scorePhrase)
    if scorePhrase(bestDict) == 0:
        bestDict = None
    bestRef = max(po, key=tmp.get)
    if tmp[bestRef] < 50:
        bestDict = None
    if bestDict == bestRef and bestDict is not None:
        updateMap[s] = bestDict
        if v >= 100:
            print 'Convert', s, v, '-->', bestDict, tmp[bestDict]
    else:
        if v < 20:
            updateMap[s] = s # gives up rare entries
        else:
            po2 = set([s2 for s1 in po for s2 in edits1(s1)]) or po
            bestRef = max(po2, key=tmp.get)
            if bestRef != s and tmp[bestRef] >= 500:
                updateMap[s] = bestRef
                print 'Convert-2', s, v, '-->', bestRef, tmp[bestRef]
            else:
                updateMap[s] = s
                if v >= 100:
                    manualProcess.append((s, v))
applyUpdates(rawDesc, updateMap)
print '-- Manual Process --'
for s, v in manualProcess:
    print s
# Out:
# Convert foreat 105 --> forest 114869
# Convert-2 bulinding 4871 --> building 189998
# Convert-2 computeroom 29 --> computer room 1493
# Convert-2 aerplane 36 --> aeroplane 9292
# Convert-2 tolite 29 --> toilet 6954
# Convert-2 dyningtable 53 --> dining table 2141
# Convert-2 acurium 171 --> aquarium 4244
# Convert-2 restarea 173 --> restarent 545
# Convert-2 graveyred 65 --> graveyard 1536
# Convert-2 kuthrai place 91 --> kuthirai place 890
# Convert-2 prayroom 43 --> play room 3145
# Convert-2 daining hall 879 --> dinning hall 6092
# Convert planetorium 199 --> planetarium 232
# Convert restaturant 126 --> restaurant 54018
# Convert-2 wattinghall 20 --> waiting hall 5717
# Convert-2 video gamescenter 34 --> video game center 640
# Convert ainmal 184 --> animal 6061
# Convert-2 billiats 41 --> billiard 1318
# Convert-2 hourserace 83 --> horse race 2605
# Convert-2 gamesroom 206 --> game room 1146
# Convert resturant 6548 --> restaurant 54018
# Convert-2 exclator 32 --> escalator 3910
# Convert-2 soffaa 97 --> sofa 1464
# Convert machince 717 --> machine 28709
# Convert-2 rainage 46 --> drainage 1052
# Convert-2 airoplaine 24 --> aeroplane 9292
# Convert-2 carage 90 --> cage 3778
# Convert-2 gudown 27 --> godown 5288
# Convert-2 reasturant 96 --> restaurant 54018
# Convert restrarunt 158 --> restraunt 566
# Convert-2 daining hal 23 --> dining hall 3711
# Convert-2 aeroplain 95 --> aeroplane 9292
# Convert-2 ariplan 138 --> airplane 3687
# Convert-2 mounament 78 --> monument 6584
# Convert-2 cubboard 86 --> cupboard 729
# Convert-2 airopline 88 --> aeroplane 9292
# Convert-2 restarent 545 --> restaurant 54018
# Convert-2 auditorm 60 --> auditorium 17654
# Convert-2 restrarent 21 --> restaurent 4173
# Convert memoriel 131 --> memorial 239
# Convert-2 scating 178 --> boating 4510
# Convert-2 resturent 197 --> restaurant 54018
# Convert-2 hellicapter 51 --> helicopter 3240
# Convert-2 peopels 89 --> people 31822
# Convert-2 balgany 44 --> balcony 2166
# Convert-2 toriest place 30 --> tourist place 2120
# Convert-2 volcona 74 --> volcano 1732
# Convert-2 muusium 25 --> museum 7495
# Convert-2 airplain 38 --> airplane 3687
# Convert-2 playgrond 50 --> play ground 51486
# Convert restuarant 4089 --> restaurant 54018
# Convert-2 cubbord 24 --> cupboard 729
# Convert-2 horseridding 31 --> horse riding 1035
# Convert-2 auditouriam 22 --> auditorium 17654
# Convert-2 comercialbuilding 51 --> commercial building 3007
# Convert-2 swming pool 130 --> swimming pool 20049
# Convert-2 muesium 41 --> museum 7495
# Convert-2 juncle 34 --> jungle 928
# Convert-2 pathroom 44 --> bathroom 16911
# Convert-2 tailet 39 --> toilet 6954
# Convert vehile 148 --> vehicle 7020
# Convert-2 restaraunt 448 --> restaurant 54018
# Convert-2 horserideing 44 --> horse riding 1035
# Convert-2 studiam 27 --> stadium 46461
# Convert-2 musiume 21 --> museum 7495
# Convert-2 cuboard 56 --> cupboard 729
# Convert-2 barkery 55 --> bakery 11484
# Convert-2 mechinary 64 --> machinery 3014
# Convert-2 publicsplace 137 --> public place 562
# Convert-2 grenary 38 --> scenary 1148
# Convert-2 telephonbooth 23 --> telephone booth 4684
# Convert-2 oldbuildings 1462 --> old building 6647
# Convert-2 helicafter 38 --> helicopter 3240
# Convert-2 escaleter 31 --> escalator 3910
# Convert-2 restround 397 --> restraunt 566
# Convert-2 facctorys 37 --> factory 197685
# Convert foctory 241 --> factory 197685
# Convert-2 coaboard 50 --> cupboard 729
# Convert-2 waittinghall 111 --> waiting hall 5717
# Convert-2 billding 248 --> building 189998
# Convert-2 foodbal ground 22 --> football ground 932
# Convert-2 hourbour 63 --> harbour 3701
# Convert-2 vastage 85 --> stage 5058
# Convert factroy 297 --> factory 197685
# Convert-2 hourbor 124 --> harbor 963
# Convert-2 appartsment 112 --> apartment 9169
# Convert-2 playgound 80 --> play ground 51486
# Convert-2 aparments 25 --> apartment 9169
# Convert-2 caboard 22 --> cupboard 729
# Convert-2 kuthrai race 89 --> kuthirai race 662
# Convert-2 gesthouse 298 --> guest house 15269
# Convert-2 valcono 59 --> balcony 2166
# Convert-2 chitchen 33 --> kitchen 20670
# Convert mechine 2476 --> machine 28709
# Convert-2 airoplan 68 --> aeroplane 9292
# Convert-2 chilrens 20 --> children 3787
# Convert-2 kicten 22 --> kitchen 20670
# Convert-2 windmil 76 --> wind mill 4081
# Convert-2 vegitables 92 --> vegetable 662
# Convert meachine 183 --> machine 28709
# Convert-2 playgorund 71 --> play ground 51486
# Convert-2 mouantian 22 --> mountain 165633
# Convert-2 fortiko 32 --> portico 1025
# Convert-2 betroom 82 --> bedroom 54392
# Convert-2 computersroom 23 --> computer room 1493
# Convert-2 moution 38 --> mountion 4928
# Convert-2 fountion 75 --> mountion 4928
# Convert-2 mechaine 223 --> machine 28709
# Convert-2 bigbuildings 195 --> big building 697
# Convert-2 billiarts 22 --> billiard 1318
# Convert-2 resturaint 20 --> restaurant 54018
# Convert-2 clothset 75 --> closet 5738
# Convert-2 washpasin 21 --> wash basin 1905
# Convert-2 restorent 29 --> resturant 6548
# Convert viwepoint 247 --> viewpoint 109
# Convert kitchne 100 --> kitchen 20670
# Convert-2 apportment 51 --> apartment 9169
# Convert-2 oldouse 43 --> old house 1497
# Convert-2 alecopter 63 --> alecoopter 1003
# Convert-2 reastarunt 26 --> restarant 1385
# Convert ateium 151 --> atrium 149
# Convert factary 105 --> factory 197685
# Convert-2 masage 61 --> garage 1955
# Convert-2 polutary 41 --> poultry 1362
# Convert fueal station 182 --> fuel station 95
# Convert-2 vegtables 69 --> vegetable 662
# Convert-2 restrant 98 --> restaurant 54018
# Convert facrory 153 --> factory 197685
# Convert-2 airoplain 43 --> airoplane 850
# Convert-2 enternce 20 --> entrance 6426
# Convert bedrrom 239 --> bedroom 54392
# Convert stedium 422 --> stadium 46461
# Convert-2 railywaytrack 97 --> railway track 5673
# Convert-2 appatment 30 --> apartment 9169
# Convert-2 srore 29 --> store 8531
# Convert-2 statuim 20 --> stadium 46461
# Convert-2 histrocial place 51 --> historical place 2247
# Convert barthroom 786 --> bathroom 16911
# Convert-2 musiem 229 --> museum 7495
# Convert-2 musiuem 43 --> museum 7495
# Convert-2 daining 90 --> painting 1263
# Convert-2 washbasion 28 --> wash basin 1905
# Convert-2 music instrumement 49 --> music instrument 1821
# Convert curcus 241 --> circus 5779
# Convert-2 trainage 33 --> drainage 1052
# Convert-2 polcony 28 --> balcony 2166
# Convert-2 shlls 21 --> hills 21465
# Convert-2 helicaptor 47 --> helicopter 3240
# Convert-2 carsparking 29 --> car parking 5413
# Convert horbour 101 --> harbour 3701
# Convert-2 picknic place 182 --> piknic place 2894
# Convert-2 goodown 77 --> godown 5288
# Convert-2 cloulds 30 --> cloud 3516
# Convert-2 backry 23 --> bakery 11484
# Convert-2 restarunt 533 --> restaurant 54018
# Convert-2 playgrouad 42 --> play ground 51486
# Convert stadiume 100 --> stadium 46461
# -- Manual Process --
# veichile
# planatorium
# confrancehall
# tallbuildings
# kitchenroom
# photoview
# sportsroom
# archbuilding
# waranta
# accurium
# damagedbuilding
# trainroute
# searesearch
# sushishop
# animalshome
# liviningroom
# grassshapes
# damagedarticles
# swimmingful
# kittar
# damagedthings
# roadview
# alecoopter
# playcourt
# woodenframes
# riverarea
# pitshop
# liabery
# rocksview
# frontviewofbuilding
# fogplace
# damagedstructures
# olderbuliding
# steelstructures
# sandroad
# indoorstadium

# %%
handConvert = '''
veichile|vehicle
planatorium|planetarium
confrancehall|conference hall
kitchenroom|kitchen
accurium|aquarium
animalshome|animal home
liviningroom|living room
swimmingful|swimming pool
alecoopter|helicopter
liabery|library
frontviewofbuilding|front view of building
fogplace|foggy place
olderbuliding|older building
tallbuildings|tall building
photoview|photo view
sportsroom|sports room
archbuilding|arch building
damagedbuilding|damaged building
trainroute|train route
searesearch|sea research
sushishop|sushi shop
grassshapes|grass shape
damagedarticles|damaged article
damagedthings|damaged thing
roadview|road view
playcourt|play court
woodenframes|wooden frame
riverarea|river area
pitshop|pit shop
rocksview|rock view
damagedstructure|damaged structure
steelstructures|steel structure
sandroad|sand road
indoorstadium|indoor stadium
no image|
unknown|
mountion|mountain
buliding|building
bulding|building
smallhouse|small house
restaurent|restaurant
shope|shop
meating hall|meeting hall
restarant|restaurant
restaruant|restaurant
restraunt|restaurant
chruch|church
hospitel|hospital
hoispatl|hospital
swiming pool|swimming pool
swimming pal|swimming pool
smimming place|swimming place
smimming pool|swimming pool
smimming room|swimming room
parliment|parliament
kichen room|kitchen room
kichen|kitchen
kicthen|kitchen
brige|bridge
restauant|restaurant
railwaybalm|railway balm
charch|church
chirch|church
moutain|mountain
goverment building|government building
seminor class|seminar class
lakh|lake
appartment|apartment
multi storey building|multi story building
bed rooms|bed room
bed rooom|bed room
mountan|mountain
shoping center|shopping center
airplan|airplane
machinary|machinery
machineries|machinery
laboratary|laboratory
lobi|lobby
coridoor|corridor
hallview|hall view
delux car|deluxe car
histrorical place|historical place
rockfort|rock fort
multi storeyed building|multi story building
book centre|book center
liberay|library
tant|tent
hutview|hut view
information centre|information center
swimmimg pool|swimming pool
swimmingfull|swimming pool
cinema theature|cinema theater
theator|theater
theatre|theater
game centre|game center
construciton|construction
musiam|museum
muzium|museum
musem|museum
museiam|museum
statium|stadium
galary|gallery
stedum|stadium
computersoffice|computer office
bouth room|bathroom
both room|bathroom
bath room|bathroom
bathshower|bath shower
bustand|bus stand
light kouse|light house
secutity place|security place
digg|dig
gargen|garden
archbridge|arch bridge
haiway road|highway road
shipview|ship view
shoping|shopping
men|man
women|woman
natural|nature
tallbuildings|tall building
restround|restaurant
animalshome|animal home
kitchenroom|kitchen room
restarea|rest area
circu|circus
damagedstructure|damaged structure
publicsplace|public place
kittar|gittar
bigbuildings|big building
seminor|seminar
hourbor|harbour
fueal station|fuel station
damagedstructures|damaged structure
frontviewofbuildings|front view of building
orch|arch
'''
tmp = collectDesc(rawDesc)
updateMap = {}
rules = handConvert.split('\n')
for r in rules:
    if r == '': continue
    s, t = r.split('|')
    updateMap[s] = t
    if s == t:
        raise RuntimeError('Do not change anything: ' + s + '|' + t)
    print s, '-->', t
for s in tmp:
    if s not in updateMap:
        updateMap[s] = s
applyUpdates(rawDesc, updateMap)
# Out:
# veichile --> vehicle
# planatorium --> planetarium
# confrancehall --> conference hall
# kitchenroom --> kitchen
# accurium --> aquarium
# animalshome --> animal home
# liviningroom --> living room
# swimmingful --> swimming pool
# alecoopter --> helicopter
# liabery --> library
# frontviewofbuilding --> front view of building
# fogplace --> foggy place
# olderbuliding --> older building
# tallbuildings --> tall building
# photoview --> photo view
# sportsroom --> sports room
# archbuilding --> arch building
# damagedbuilding --> damaged building
# trainroute --> train route
# searesearch --> sea research
# sushishop --> sushi shop
# grassshapes --> grass shape
# damagedarticles --> damaged article
# damagedthings --> damaged thing
# roadview --> road view
# playcourt --> play court
# woodenframes --> wooden frame
# riverarea --> river area
# pitshop --> pit shop
# rocksview --> rock view
# damagedstructure --> damaged structure
# steelstructures --> steel structure
# sandroad --> sand road
# indoorstadium --> indoor stadium
# no image -->
# unknown -->
# mountion --> mountain
# buliding --> building
# bulding --> building
# smallhouse --> small house
# restaurent --> restaurant
# shope --> shop
# meating hall --> meeting hall
# restarant --> restaurant
# restaruant --> restaurant
# restraunt --> restaurant
# chruch --> church
# hospitel --> hospital
# hoispatl --> hospital
# swiming pool --> swimming pool
# swimming pal --> swimming pool
# smimming place --> swimming place
# smimming pool --> swimming pool
# smimming room --> swimming room
# parliment --> parliament
# kichen room --> kitchen room
# kichen --> kitchen
# kicthen --> kitchen
# brige --> bridge
# restauant --> restaurant
# railwaybalm --> railway balm
# charch --> church
# chirch --> church
# moutain --> mountain
# goverment building --> government building
# seminor class --> seminar class
# lakh --> lake
# appartment --> apartment
# multi storey building --> multi story building
# bed rooms --> bed room
# bed rooom --> bed room
# mountan --> mountain
# shoping center --> shopping center
# airplan --> airplane
# machinary --> machinery
# machineries --> machinery
# laboratary --> laboratory
# lobi --> lobby
# coridoor --> corridor
# hallview --> hall view
# delux car --> deluxe car
# histrorical place --> historical place
# rockfort --> rock fort
# multi storeyed building --> multi story building
# book centre --> book center
# liberay --> library
# tant --> tent
# hutview --> hut view
# information centre --> information center
# swimmimg pool --> swimming pool
# swimmingfull --> swimming pool
# cinema theature --> cinema theater
# theator --> theater
# theatre --> theater
# game centre --> game center
# construciton --> construction
# musiam --> museum
# muzium --> museum
# musem --> museum
# museiam --> museum
# statium --> stadium
# galary --> gallery
# stedum --> stadium
# computersoffice --> computer office
# bouth room --> bathroom
# both room --> bathroom
# bath room --> bathroom
# bathshower --> bath shower
# bustand --> bus stand
# light kouse --> light house
# secutity place --> security place
# digg --> dig
# gargen --> garden
# archbridge --> arch bridge
# haiway road --> highway road
# shipview --> ship view
# shoping --> shopping
# men --> man
# women --> woman
# natural --> nature
# tallbuildings --> tall building
# restround --> restaurant
# animalshome --> animal home
# kitchenroom --> kitchen room
# restarea --> rest area
# circu --> circus
# damagedstructure --> damaged structure
# publicsplace --> public place
# kittar --> gittar
# bigbuildings --> big building
# seminor --> seminar
# hourbor --> harbour
# fueal station --> fuel station
# damagedstructures --> damaged structure
# frontviewofbuildings --> front view of building
# orch --> arch
# WARNING - Removing unknown
# WARNING - Removing no image

# %%
# Handles common long sentences
tmp = collectDesc(rawDesc)
prefixRemovalS = '''
i am giong to
i am going to
iam going to
i am seeing
i am watching
i want to live
iam seeing
seeing
this is
it is
look like
looks like
'''
prefixBan = set(tuple(l.split()) for l in prefixRemovalS.split('\n') if l != '')
updateMap = {}
for s, v in tmp.iteritems():
    phrase = s.split()
    trunc = 0
    for pattern in prefixBan:
        if tuple(phrase[:len(pattern)]) == pattern:
            trunc = max(trunc, len(pattern))
    if trunc > 0:
        updateMap[s]=' '.join(phrase[trunc:])
        if v > 10:
            print s, v, '-->', updateMap[s]
    else:
        updateMap[s] = s
applyUpdates(rawDesc, updateMap)
# Out:
# i am going to the cinema hall 17 --> the cinema hall
# seeing a arch 31 --> a arch
# this is a room 29 --> a room
# this is factory 12 --> factory
# i am going to the farm land 17 --> the farm land
# iam seeing the chruch 11 --> the chruch
# iam seeing the playground 27 --> the playground
# iam seeing the road 25 --> the road
# this is house 11 --> house
# this is a tree 12 --> a tree
# this is a factory 23 --> a factory
# i am going to the meeting hall 67 --> the meeting hall
# i am going to the baseball 12 --> the baseball
# iam seeing the church 62 --> the church
# i am going to the railway station 32 --> the railway station
# this is a house 37 --> a house
# i am going to the closet 17 --> the closet
# iam seeing the hall 26 --> the hall
# i am going to church 35 --> church
# this is a sea 28 --> a sea
# iam seeing the carshed 11 --> the carshed
# this is a machine 21 --> a machine
# iam seeing the hotel 13 --> the hotel
# i am going to the stadium 70 --> the stadium
# this is a hotel 15 --> a hotel
# i am going to the garden 69 --> the garden
# seeing a airpoort 20 --> a airpoort
# i am going to the skating 12 --> the skating
# iam seeing the train 11 --> the train
# iam seeing the river 46 --> the river
# i am going to the party hall 12 --> the party hall
# seeing a bus station 20 --> a bus station
# iam seeing the fam house 19 --> the fam house
# i am going to the home 32 --> the home
# this is a forest 18 --> a forest
# i am going to the library 20 --> the library
# i am going to the mountain 12 --> the mountain
# iam seeing the lot of trees 12 --> the lot of trees
# iam seeing the things 12 --> the things
# this is building 52 --> building
# iam seeing the man 20 --> the man
# iam seeing the airoplane 14 --> the airoplane
# iam seeing the sea 20 --> the sea
# iam seeing the kugai 11 --> the kugai
# iam seeing the room 14 --> the room
# this is a road 24 --> a road
# i am going to the temple 17 --> the temple
# this is a building 85 --> a building
# i am going to the sea 16 --> the sea
# this is sea 21 --> sea
# iam seeing the factory 15 --> the factory
# i am going to the park 192 --> the park
# this is people 11 --> people
# i am going to the bakery 23 --> the bakery
# iam seeing the historic building 120 --> the historic building
# seeing a play station 16 --> a play station
# this is a bridge 22 --> a bridge
# iam seeing the building 78 --> the building
# iam seeing the boat 11 --> the boat
# iam seeing the complex 12 --> the complex
# this is a people 14 --> a people
# iam seeing the tree 12 --> the tree
# i am watching a nice construction 20 --> a nice construction
# this is a mount 12 --> a mount
# seeing a rock mountain 32 --> a rock mountain
# iam seeing the bedroom 31 --> the bedroom
# i am going to the office 21 --> the office
# i am going to play 11 --> play
# iam seeing the ship 13 --> the ship
# i am going to the forest 19 --> the forest
# seeing 17 -->
# iam seeing the shopping mall 21 --> the shopping mall
# this is a church 27 --> a church
# i am going to the music hall 13 --> the music hall
# i am going to the swimming pool 25 --> the swimming pool
# iam seeing the restaurant 32 --> the restaurant
# iam seeing the garden 11 --> the garden
# this is shop 11 --> shop
# it is building 1586 --> building
# i am going to the restaurant 38 --> the restaurant
# iam seeing the autumn 12 --> the autumn
# iam seeing the machines 20 --> the machines
# i am going to the museum 67 --> the museum
# iam seeing the park 16 --> the park
# this is a rock 21 --> a rock
# i am going to the factory 121 --> the factory
# iam seeing the car 24 --> the car
# iam seeing the house 96 --> the house
# it is bulding 44 --> bulding
# i am going to the shopping center 25 --> the shopping center
# this is a garden 36 --> a garden
# i am going to the falls 11 --> the falls
# this is a river 12 --> a river
# i am going to the hotel 232 --> the hotel
# i am going to the shopping mall 60 --> the shopping mall
# seeing a building 65 --> a building
# this is a shop 36 --> a shop
# iam seeing the many peoples 29 --> the many peoples
# i am going to the church 384 --> the church
# iam seeing the nature 54 --> the nature
# iam seeing the mountain 70 --> the mountain
# this is a stadium 11 --> a stadium
# iam seeing the many things 11 --> the many things
# iam seeing the palace 14 --> the palace
# WARNING - Removing seeing

# %%
# Remove confident stop words
tmp = collectDesc(rawDesc)
stopWordsS='a,an,the,some' # only include very confident ones
stopWords = set([w.lower().strip() for w in stopWordsS.split(',')])
updateMap = {}
for s, v in tmp.iteritems():
    phrase = s.split()
    phraseOut = filter(lambda w: w not in stopWords, phrase)
    updateMap[s] = ' '.join(phraseOut)
    if v > 10 and len(phrase) > len(phraseOut):
        print s, v, '-->', updateMap[s]
applyUpdates(rawDesc, updateMap)
# Out:
# the museum 67 --> museum
# under the sea 399 --> under sea
# a airpoort 20 --> airpoort
# the complex 12 --> complex
# a man 31 --> man
# a home 26 --> home
# the house 140 --> house
# the home depot 12 --> home depot
# the many peoples 29 --> many peoples
# the railway station 33 --> railway station
# a office 14 --> office
# a living room 12 --> living room
# the swimming pool 27 --> swimming pool
# a river 15 --> river
# the bridge 22 --> bridge
# the forest 24 --> forest
# a forest 29 --> forest
# the playground 27 --> playground
# an office 13 --> office
# a house 76 --> house
# a restaurant 17 --> restaurant
# a shop 55 --> shop
# the temple 20 --> temple
# the library 23 --> library
# the shopping center 26 --> shopping center
# the garden 80 --> garden
# a mountain 20 --> mountain
# the building 79 --> building
# the tree 12 --> tree
# a stadium 26 --> stadium
# the company 13 --> company
# the people's court 13 --> people's court
# the train 15 --> train
# out of the city 24 --> out of city
# a lady 12 --> lady
# the boat 11 --> boat
# a hotel 20 --> hotel
# a fort 14 --> fort
# the bakery 26 --> bakery
# a people 14 --> people
# the cinema hall 17 --> cinema hall
# the palace 20 --> palace
# a road 37 --> road
# a ground 21 --> ground
# the fam house 19 --> fam house
# the man 20 --> man
# house in a room 36 --> house in room
# a historical place 12 --> historical place
# the church 449 --> church
# the dam 14 --> dam
# the kugai 11 --> kugai
# crack in the earth 13 --> crack in earth
# the things 12 --> things
# the restaurant 71 --> restaurant
# a room 64 --> room
# a 34 -->
# a factory 43 --> factory
# a tree 13 --> tree
# the boat house 11 --> boat house
# a bridge 36 --> bridge
# backseat of a car 28 --> backseat of car
# the road 69 --> road
# the mountain 85 --> mountain
# the shopping mall 82 --> shopping mall
# the many things 11 --> many things
# the ship 18 --> ship
# a ship 12 --> ship
# the swiming pool 14 --> swiming pool
# the hotel 245 --> hotel
# a machine 22 --> machine
# a play station 17 --> play station
# a dog 12 --> dog
# the hall 41 --> hall
# a bus station 20 --> bus station
# the bedroom 35 --> bedroom
# the chruch 11 --> chruch
# inside the church 12 --> inside church
# a garden 38 --> garden
# the party hall 12 --> party hall
# the home 63 --> home
# the airoplane 14 --> airoplane
# a mount 12 --> mount
# crack in the ground 15 --> crack in ground
# the stadium 71 --> stadium
# a lake 23 --> lake
# a building 229 --> building
# a rock 23 --> rock
# the baseball 12 --> baseball
# the music hall 56 --> music hall
# a nice construction 20 --> nice construction
# a rock mountain 32 --> rock mountain
# under the water 16 --> under water
# the meeting hall 77 --> meeting hall
# the factory 150 --> factory
# the machines 20 --> machines
# the skating 12 --> skating
# a library 13 --> library
# the river 55 --> river
# like a bunch of sheep 14 --> like bunch of sheep
# the car 24 --> car
# the historic building 120 --> historic building
# a hall 22 --> hall
# the farm land 17 --> farm land
# the falls 11 --> falls
# a arch 33 --> arch
# the lot of trees 12 --> lot of trees
# the sea 38 --> sea
# a sea 32 --> sea
# the room 16 --> room
# the peak 20 --> peak
# the lake 13 --> lake
# a church 42 --> church
# the park 212 --> park
# the closet 17 --> closet
# the carshed 11 --> carshed
# the nature 54 --> nature
# the office 22 --> office
# a bakery 11 --> bakery
# the smoking room 11 --> smoking room
# the autumn 12 --> autumn
# WARNING - Removing a
# WARNING - Removing an

# %%
# Combine identical terms if we ignore less confident stop words
tmp = collectDesc(rawDesc)
stopWordsS2='a,able,about,across,after,all,almost,also,am,among,an,and,any,are,as,at,be,because,been,but,by,can,\
cannot,could,dear,did,do,does,either,else,ever,every,for,from,get,got,had,has,have,he,her,hers,him,his,how,however,\
i,if,in,into,is,it,its,just,least,let,like,likely,may,me,might,most,must,my,neither,nor,of,off,often,on,\
only,or,other,our,own,rather,said,say,says,she,should,since,so,some,than,that,the,their,them,then,there,these,they,\
this,tis,to,too,twas,us,want,wants,was,we,were,what,when,where,which,while,who,whom,why,will,with,would,yet,you,\
your,iam'
# Credit to http://www.textfixer.com/resources/common-english-words.txt
stopWords2 = set([w.lower().strip() for w in stopWordsS2.split(',')]) - stopWords
unorderedDesc = collections.defaultdict(collections.Counter)
updateMap = {}
for s, v in tmp.iteritems():
    phrase = s.split()
    phraseOut = filter(lambda w: w not in stopWords2, phrase)
    unorderedDesc[' '.join(sorted(phraseOut))][s]+=v
for k, c in unorderedDesc.iteritems():
    if k == '':
        for s in c.keys():
            updateMap[s] = ''
    else:
        target_s, target_v = c.most_common(1)[0]
        for s in c.keys():
            updateMap[s] = target_s
        if len(c.keys()) > 1 and sum(c.values()) - c.most_common(1)[0][1] > 50:
            print c.most_common(1)[0], '<--', c.most_common()[1:], sum(c.values()) - c.most_common(1)[0][1]
applyUpdates(rawDesc, updateMap)
# Out:
# ('exterior house', 370) <-- [('house exterior', 49), ('exterior of house', 7), ('exterior in house', 1)] 57
# ('exterior building', 604) <-- [('building exterior', 479), ('exterior of building', 4)] 483
# ('room', 62410) <-- [('room in', 123), ('was room', 2), ('other room', 2), ('so room', 1), ('room is', 1), ('any room', 1), ('its room', 1)] 131
# ('conference', 939) <-- [('conference all', 51)] 51
# ('car race', 2506) <-- [('race car', 495)] 495
# ('table chair', 322) <-- [('table and chair', 144), ('chair and table', 16)] 160
# ('place of worship', 464) <-- [('worship place', 140), ('place to worship', 6)] 146
# ('garden house', 309) <-- [('house garden', 147), ('house with garden', 16), ('garden and house', 13), ('house in garden', 6), ('house and garden', 5), ('garden with house', 2), ('house to garden', 1)] 190
# ('house room', 71) <-- [('house in room', 36), ('room in house', 15), ('room of house', 1)] 52
# ('church', 117959) <-- [('church in', 68), ('in church', 7), ('these are church', 1)] 76
# ('building interior', 62) <-- [('interior building', 60), ('interior of building', 11)] 71
# ('car racing', 137) <-- [('racing car', 61)] 61
# ('mountain river', 77) <-- [('mountain with river', 50), ('river with mountain', 9), ('river mountain', 8), ('mountain and river', 3), ('river and mountain', 3), ('river by mountain', 1)] 74
# ('park', 46541) <-- [('it park', 38), ('them park', 29), ('i am in park', 1)] 68
# ('train', 16691) <-- [('in train', 36), ('train in', 15), ('its train', 1)] 52
# ('building front', 55) <-- [('front building', 46), ('front of building', 17), ('in front of building', 4)] 67
# ('mountain with sea', 57) <-- [('mountain sea', 21), ('sea with mountain', 19), ('sea mountain', 17), ('mountain and sea', 7)] 64
# ('house hall', 142) <-- [('hall in house', 132), ('hall house', 1), ('hall for house', 1)] 134
# ('building', 214919) <-- [('other building', 38), ('all building', 21), ('building in', 5), ('us building', 3), ('its building', 1), ('it building', 1)] 69
# ('house', 228765) <-- [('house in', 202), ('in house', 4), ('house get', 3), ('my house', 2), ('house from', 1), ('from house', 1), ('would house', 1), ('on house', 1), ('he house', 1), ('said house', 1), ('too house', 1)] 218
# ('house front', 1226) <-- [('front of house', 27), ('front house', 21), ('in front house', 1), ('house in front', 1), ('in front of house', 1)] 51
# WARNING - Removing in
# WARNING - Removing i
# WARNING - Removing from
# WARNING - Removing for
# WARNING - Removing like
# WARNING - Removing or
# WARNING - Removing off
# WARNING - Removing at
# WARNING - Removing other
# WARNING - Removing all
# WARNING - Removing said
# WARNING - Removing can
# WARNING - Removing got
# WARNING - Removing be
# WARNING - Removing so
# WARNING - Removing dear
# WARNING - Removing she
# WARNING - Removing how
# WARNING - Removing was
# WARNING - Removing he
# WARNING - Removing what is
# WARNING - Removing get
# WARNING - Removing of
# WARNING - Removing we
# WARNING - Removing might
# WARNING - Removing could
# WARNING - Removing and
# WARNING - Removing to
# WARNING - Removing am
# WARNING - Removing but
# WARNING - Removing me
# WARNING - Removing would

# %%
# Redo: Remove space/punctuation distinction (i.e. map the set of identical answers ignoring space to the most frequent one in the set)
tmp = collectDesc(rawDesc)
answersSet = collections.defaultdict(collections.Counter)
for s, v in tmp.iteritems():
    s_nospace = re.sub('\\W+', '', s)
    answersSet[s_nospace][s]+=v
udpateMap = {}
for c in answersSet.values():
    t = c.most_common(1)[0][0]
    if len(c.keys()) > 1 and sum(c.values()) - c[t] > 100:
        print t, '<--', c.keys()
    for s in c:
        updateMap[s] = t
applyUpdates(rawDesc, updateMap)

# %%
# Redo: Remove pular words if their corresponding singular forms exist in the dataset 
# and (are more popular) or (have more than 50 occurances)
tmp = collectDesc(rawDesc)
updateMap = {}
for s, v in tmp.iteritems():
    if s in updateMap: continue
    if s[-1] == 's' and s[:-1] in tmp:
        if v <= tmp[s[:-1]] or tmp[s[:-1]] >= 50:
            if v + tmp[s[:-1]] >= 50: 
                print s, v, '-->', s[:-1], tmp[s[:-1]]
            updateMap[s] = s[:-1]
            updateMap[s[:-1]] = s[:-1]
        else:
            if v + tmp[s[:-1]] >= 50: 
                print s, v, '<--', s[:-1], tmp[s[:-1]]
            updateMap[s] = s
            updateMap[s[:-1]] = s
for s in tmp:
    if s not in updateMap:
        updateMap[s] = s

applyUpdates(rawDesc, updateMap)
# Out:
# kids 1 --> kid 1221
# fruits 1 --> fruit 1156
# dolls 1 --> doll 487
# gymnastics 91 <-- gymnastic 1
# materials 1 --> material 205
# pictures 1 --> picture 1339
# books 2 --> book 1033
# horses 442 --> horse 8845
# coconut trees 1 --> coconut tree 61
# small houses 10 --> small house 604
# chairs 2 --> chair 4928
# steps 12643 --> step 1714
# play courts 2 --> play court 342
# pyramids 1 --> pyramid 307
# hills 21525 --> hill 9456
# caps 3 --> cap 476
# trees 16847 --> tree 20647
# students 1 --> student 448
# tables 1 --> table 5189
# drums 4 --> drum 296
# deers 1 --> deer 132
# exhibits 2 --> exhibit 77
# weapons 111 <-- weapon 1
# honey bees 1 --> honey bee 346
# mines 3 --> mine 566
# apples 1 --> apple 182
# highways 674 --> highway 17301
# cars 10 --> car 31541
# toys 6 --> toy 1512
# players 3 --> player 1930
# factory machines 6 --> factory machine 81
# rooms 1 --> room 62541
# sports 2 --> sport 3383
# farmers 1 --> farmer 59
# bricks 2 --> brick 916
# persons 3 --> person 1854
# tractors 1 --> tractor 195
# workers 2 --> worker 6290
# fountains 1 --> fountain 2212
# class 894 <-- clas 1
# things 15 --> thing 559
# food items 1 --> food item 528
# peoples 5 --> people 31951
# car sheets 1 --> car sheet 115
# mountians 88 --> mountian 195
# wood works 1 --> wood work 392
# animals 3 --> animal 6256
# pigs 2 --> pig 2725
# flowers 5 --> flower 4965
# falls 11 --> fall 12557
# childrens 3 --> children 3829
# windows 1 --> window 4729
# machines 20 --> machine 32376

# %%
# Redo: spelling correction
tmp = collectDesc(rawDesc)
updateMap = {}
manualProcess = []
for s, v in tmp.iteritems():
    if inDict(s):
        updateMap[s] = s
        continue
    po = edits1(s)
    bestDict = max(po, key=scorePhrase)
    if scorePhrase(bestDict) == 0:
        bestDict = None
    bestRef = max(po, key=tmp.get)
    if tmp[bestRef] < 50:
        bestDict = None
    if bestDict == bestRef and bestDict is not None:
        updateMap[s] = bestDict
        if v >= 100:
            print 'Convert', s, v, '-->', bestDict, tmp[bestDict]
    else:
        if v < 20:
            updateMap[s] = s # gives up rare entries
        else:
            po2 = set([s2 for s1 in po for s2 in edits1(s1)]) or po
            bestRef = max(po2, key=tmp.get)
            if bestRef != s and tmp[bestRef] >= 500:
                updateMap[s] = bestRef
                print 'Convert-2', s, v, '-->', bestRef, tmp[bestRef]
            else:
                updateMap[s] = s
                if v >= 100:
                    manualProcess.append((s, v))
applyUpdates(rawDesc, updateMap)
print '-- Manual Process --'
for s, v in manualProcess:
    print s
# Out:
# Convert-2 restarent 174 --> restaurant 75189
# Convert-2 planitorium 59 --> planetarium 578
# -- Manual Process --
# waranta

# %%
# Check popular non-alphabetical non-white characters
tmp = collectDesc(rawDesc)
occ = 0
for s, v in tmp.most_common():
    if len(filter(lambda c: (not c.isalpha()) and c != ' ', s)) > 0:
        occ += v
        if v >= 50:
            print s, v
print occ
# Out:
# children's park 688
# multi-storeyed building 133
# doctor's office 84
# hills & river 84
# dentist's office 73
# visitor's room 60
# park. garden 60
# 6099

# %%
# Check popular misspelled entry (our dictionary is not perfect)
tmp = collectDesc(rawDesc)
occ = 0
for s, v in tmp.most_common():
    if len(filter(lambda w: w not in NWORDS, words(s))) > 0:
        occ += v
        if v >= 50:
            print s, v
print occ
# Out:
# waranta 294
# oldhome 98
# oldarch 94
# marchfast 93
# towerbuildings 83
# congrete 79
# playingyard 77
# focuslight 75
# muddview 73
# partymeet 71
# archview 71
# gracees 71
# horsr ride place 69
# entranceview 69
# starhotel 69
# wardrob 67
# woodengate 65
# coolingtower 64
# ratinum 64
# damagedhome 64
# carstand 60
# scpriture 57
# washingarea 57
# oldcollege 57
# lightingarea 56
# natureview 54
# pocline 53
# almirha 52
# agrifield 50
# bonestructures 50
# 25397

# %%
# Check most common ones
tmp = collectDesc(rawDesc)
for s, v in tmp.most_common(100):
    print s, v
# Out:
# house 228983
# building 214988
# factory 199000
# mountain 171521
# hall 150940
# shop 122592
# church 118035
# forest 115086
# garden 103446
# road 96550
# sea 79436
# restaurant 75395
# office 68800
# room 62542
# bridge 61770
# ground 59648
# river 59191
# water 58199
# bedroom 54872
# palace 54275
# hotel 54250
# play ground 51801
# stadium 47681
# park 46609
# fort 38750
# tree 37494
# home 35389
# lake 32653
# nature 32633
# machine 32396
# people 31956
# car 31551
# hill 30986
# shed 30221
# ship 28166
# old place 23535
# hospital 23386
# swimming pool 23326
# company 22878
# kitchen 21123
# wall 20273
# living room 19768
# airport 18766
# rock 18332
# bathroom 18158
# auditorium 18033
# highway 17975
# street 17237
# train 16743
# tower 16646
# cave 16490
# tent 16421
# temple 16032
# field 15606
# guest house 15574
# farm 15422
# class room 14819
# waterfall 14674
# step 14357
# hut 13730
# man 13497
# land 13378
# apartment 13014
# city 12645
# fall 12568
# ocean 12513
# lab 12101
# bakery 11721
# arch 10940
# meeting hall 10887
# sky 10863
# beach 10699
# bar 10566
# library 10482
# market 10406
# desert 10160
# boat 10123
# industry 9957
# aeroplane 9808
# horse 9287
# snow 9166
# pond 9081
# theater 9074
# tunnel 9033
# museum 8839
# store 8570
# bus 8388
# old building 8129
# grass 8097
# bed 7745
# shopping mall 7617
# vehicle 7617
# water place 7552
# valley 7426
# toilet 7057
# shopping 7009
# dinning hall 6986
# railway station 6779
# monument 6678
# car shed 6604

# %%
# Check frequency==100
tmp = collectDesc(rawDesc)
for s, v in tmp.iteritems():
    if v == 100:
        print s, v
# Out:
# rock wall 100
# press 100
# bell tower 100
# esclator 100
# veterinarian 100
# helicoptor 100
# nature trail 100
# putting green 100
# shooting place 100
# esculator 100
# vast land 100
# snow road 100
# palce 100
# reservoir 100
# channel 100
# dugout 100

# %%
# Check frequency==50
tmp = collectDesc(rawDesc)
for s, v in tmp.iteritems():
    if v == 50:
        print s, v
# Out:
# hay bales 50
# heater 50
# mausoleum 50
# sitting 50
# wooden cabin 50
# chear 50
# cruise ship deck 50
# football game 50
# snow fort 50
# sep 50
# agrifield 50
# line 50
# sunroom 50
# topiary garden 50
# old things 50
# mess 50
# iron bridge 50
# cauge 50
# bonestructures 50
# crossing 50
# ofice 50
# opera house 50
# stock market 50
# sweet shop 50
# egg 50
# bride 50

# %%
# Check frequency==20
tmp = collectDesc(rawDesc)
for s, v in tmp.iteritems():
    if v == 20:
        print s, v
# Out:
# nature scence 20
# rock piece 20
# players room 20
# walk road 20
# awards 20
# s 20
# pilgrimes 20
# temple tower 20
# canning 20
# production area 20
# cycle stadium 20
# herb garden 20
# masach 20
# brasserie 20
# building in side 20
# factory farm 20
# water purifier 20
# llake 20
# rv park 20
# flooded street 20
# military people 20
# portrait 20
# college campus 20
# ocean shore 20
# art building 20
# building wall 20
# vegetable garden 20
# bridge opened 20
# health 20
# bog 20
# corprate office 20
# marine park 20
# lift gate 20
# eating room 20
# hill slope 20
# horse raid 20
# computer cafe 20
# boxing area 20
# dresser 20
# skylight 20
# pork 20
# turf 20
# taxi stand 20
# launderette 20
# brick work 20
# brownstone 20
# g 20
# aqaurium 20
# ringes 20
# rotary door 20
# main street 20
# book rack 20
# molten metal 20
# boat shed 20
# archu 20
# shopping mal 20
# space capsule 20
# child bedroom 20
# eliphant 20
# steet 20
# parcel boxes 20
# ghost town 20
# people working 20
# dinner plate 20
# book shelves 20
# stor room 20
# aeroplan machine 20
# factory unit 20
# photo shot 20
# unknown place 20
# office lobby 20
# aisle 20
# cow pen 20
# pumb 20
# horse castle 20
# beauty bar 20
# puldozers 20
# streetway 20
# airplane place 20
# cyclerideing 20
# skill room 20
# smoking man 20
# elevation 20
# cinima theater 20
# police department 20
# hotel pool 20
# roundana 20
# train interior 20
# kittar music 20
# jewlery 20
# nice construction 20
# play club 20
# shower room 20
# snow home 20
# iron door 20
# airport control tower 20
# trailor 20
# mall shop 20
# flower park 20
# gitar 20
# flooringview 20
# flying club 20
# puppies 20
# public toilet 20
# standed rack 20
# kids play station 20
# wooden rack 20
# power tower 20
# sand mountain 20
# kids toys 20
# pit stop 20
# tuspin 20
# military gun 20
# single man 20
# ampitheater 20
# open auditorium 20
# v 20
# hen storege 20
# mountain steps 20
# hand washing room 20
# tropics 20
# atm 20
# festival season 20
# animal hospital 20
# processing plant 20
# process industry 20
# children's play area 20
# flower bed 20
# grazing field 20
# aprtment 20
# beer factory 20
# rent house 20
# fully water place 20
# towerview 20
# festival time 20
# citibank 20
# fam house 20
# gaint wheel 20
# drawings room 20
# tennis players 20
# dome building 20
# sports practice 20
# green hills 20
# stadum 20
# factory machinery 20
# security cabin 20
# cow farming 20
# hockey court 20
# sail 20
# clough 20
# herd sheep 20
# din 20
# energy plant 20
# different 20
# car shelter 20
# road work 20
# under water world 20
# cycle race stadium 20
# hen and cock 20
# engineering work 20
# artch 20
# gudon 20
# boxingyard 20
# snow tent 20
# parked car 20
# shipboard 20
# steam room 20
# paper roll 20
# ark 20
# billiard club 20
# openverandah 20

# %%
# Saving file
imgCatDesc = collections.Counter()
catDesc = collections.Counter()
for img, cat, desc in rawDesc:
    imgCatDesc[(img, cat, desc)] += 1
    catDesc[(cat, desc)] += 1
headers = ['image_filename', 'category_id', 'description', 'count']
with open('img_cat_desc.csv', 'w') as fout:
    csvWriter = csv.writer(fout)
    csvWriter.writerow(headers)
    for k, v in imgCatDesc.most_common():
        csvWriter.writerow(k+(v,))
with open('cat_desc.csv', 'w') as fout:
    csvWriter = csv.writer(fout)
    csvWriter.writerow(headers[1:])
    for k, v in catDesc.most_common():
        csvWriter.writerow(k+(v,))
